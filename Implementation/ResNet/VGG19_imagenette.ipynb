# %%
from google.colab import drive
drive.mount('/content/gdrive')

#MODELPATH = '/content/gdrive/My Drive/Colab Notebooks/yai7_CV1/modelsave/'

#IMAGEWOOFPATH = '/content/gdrive/My Drive/Colab Notebooks/data/imagewoof2'

IMAGENETTEPATH = '/content/gdrive/My Drive/Colab Notebooks/data/imagenette2'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

from torch.utils.data import DataLoader

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
print("torch version:", torch.__version__)
print("check device:", torch.cuda.get_device_name())
print("how many?:", torch.cuda.device_count())
print("so can i use it?", torch.cuda.is_available())

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# torch version: 1.7.0+cu101
# check device: Tesla V100-SXM2-16GB
# how many?: 1
# so can i use it? True

# %%
"""
from google.colab import output
# !mkdir "./train"
# !mkdir "./val"
# !cp 파일1 파일2 # 파일1을 파일2로 복사 붙여넣기
# !cp "/content/gdrive/My Drive/Colab Notebooks/data/imagenette2/train.zip" "train.zip"
# !cp "/content/gdrive/My Drive/Colab Notebooks/data/imagenette2/val.zip" "val.zip"
# data_2.zip을 현재 디렉터리에 압축해제
# !unzip "train.zip" -d "./train/"
# !unzip "val.zip" -d "./val/"
"""
# Out:
# '\nfrom google.colab import output\n!mkdir "./train"\n!mkdir "./val"\n# !cp 파일1 파일2 # 파일1을 파일2로 복사 붙여넣기\n!cp "/content/gdrive/My Drive/Colab Notebooks/data/imagenette2/train.zip" "train.zip"\n!cp "/content/gdrive/My Drive/Colab Notebooks/data/imagenette2/val.zip" "val.zip"\n# data_2.zip을 현재 디렉터리에 압축해제\n!unzip "train.zip" -d "./train/"\n!unzip "val.zip" -d "./val/"\n'

# %%
# transformation for CIFAR 10
# yet to implement standard color augmentation

train_transform = transforms.Compose([
                             transforms.Resize(224),
                             transforms.RandomCrop(224, padding=28),
                             transforms.RandomHorizontalFlip(p=0.5),
                             transforms.ToTensor(),
                             transforms.Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
])

test_transform = transforms.Compose([
                            transforms.Resize(224),
                            transforms.CenterCrop(224),         
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
])

# %%
train_set = torchvision.datasets.ImageFolder(root='./train', transform=train_transform)
test_set = torchvision.datasets.ImageFolder(root='./val', transform=test_transform)
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False, num_workers=4)

print(f'train_loader {len(train_loader)}')
print(f'test_loader {len(test_loader)}')
# Out:
# train_loader 296
# test_loader 123

# %%
# check on the images

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

dataiter = iter(train_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# define the basic building blocks for ResNet

# option A
class Padding(nn.Module):
    def __init__(self, in_c, out_c, stride):
        super(Padding, self).__init__()
        self.padding = F.pad
        self.pad_dim = (out_c - in_c) / 2
        self.pad_dim = int(self.pad_dim)
        self.downsample = nn.MaxPool2d(1, stride=stride)

    def forward(self, x):
        x = self.padding(x, (0,0,0,0, self.pad_dim, self.pad_dim), "constant", 0)
        x = self.downsample(x)
        return x

# option Mine
class Concat(nn.Module):
    def __init__(self, in_c, out_c, stride):
        super(Concat, self).__init__()
        
        self.dim_remainder = (out_c - in_c) % in_c
        self.concat_times = out_c // in_c
        self.downsample = nn.MaxPool2d(1, stride=stride)


    def forward(self, x):
        #print("cat 1", x.shape)
        #print(self.concat_times)
        cat_x = [x] * self.concat_times
        cat_x = torch.cat(cat_x, dim=1)
        #cat_x = torch.cat((cat_x, x[:self.dim_remainder]), dim=1)
        cat_x = self.downsample(cat_x)
        #print(cat_x.shape)

        return cat_x

class BuildingBlock(nn.Module):

    def __init__(self, in_c, out_c, stride=1, option='B'):
        super(BuildingBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)

        self.shortcut = nn.Sequential()
        if in_c != out_c:
            if option == 'A':
                self.shortcut = Padding(in_c, out_c, stride)
                # why not concantenate x instead of padding?
                # since dim increase by factor of 2 all the time

            if option == 'B':
                self.shortcut = nn.Sequential(
                    nn.Conv2d(in_c, out_c, kernel_size=1, stride=stride),
                    nn.BatchNorm2d(out_c)
                )
                # i don't like the idea of batchnormalization for projection shortcut
                # should i add BN?
            
            # additional option I thought of hehe
            if option == 'Mine':
                self.shortcut = Concat(in_c, out_c, stride)
        
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        #out += self.shortcut(x)
        # dont use shortcut
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):

    def __init__(self, in_c, process_c, stride=1, option='B'):
        super(Bottleneck, self).__init__()

        self.out_c = process_c * 4

        self.conv1 = nn.Conv2d(in_c, process_c, kernel_size=1)
        self.bn1 = nn.BatchNorm2d(process_c)

        self.conv2 = nn.Conv2d(process_c, process_c, kernel_size=3,
                               stride=stride, padding=1)
        self.bn2 = nn.BatchNorm2d(process_c)

        self.conv3 = nn.Conv2d(process_c, self.out_c, kernel_size=1)
        self.bn3 = nn.BatchNorm2d(self.out_c)

        self.shortcut = nn.Sequential()
        if in_c != self.out_c:
            if option == 'A':
                self.shortcut = Padding(in_c, self.out_c)
                # why not concantenate x instead of padding?
                # since dim increase by factor of 2 all the time

            if option == 'B':
                self.shortcut = nn.Sequential(
                    nn.Conv2d(in_c, self.out_c, kernel_size=1, stride=stride),
                    nn.BatchNorm2d(self.out_c)
                )
                # i don't like the idea of batchnormalization for projection shortcut
                # should i add BN?
            
            # additional option I thought of hehe
            if option == 'Mine':
                self.shortcut = Concat(in_c, self.out_c)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class Gate(nn.Module):
    def __init__(self):
        super(Gate, self).__init__()
        # slightly changed for CIFAR10
        # in order to have dimension 32x32 --> 16x16
        self.conv_gate = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3)
        self.bn_gate = nn.BatchNorm2d(64)
        self.maxpool_gate = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

    def forward(self, x):
        x = F.relu(self.bn_gate(self.conv_gate(x)))
        x = self.maxpool_gate(x)
        return x

# %%
class VGG(nn.Module):
    def __init__(self):
        super(VGG, self).__init__()

        self.conv1 = BuildingBlock(3, 64, 1, 'B')

        self.conv2 = BuildingBlock(64, 128, 1, 'B')

        self.conv3_1 = BuildingBlock(128, 256, 1, 'B')
        self.conv3_2 = BuildingBlock(256, 256, 1, 'B')

        self.conv4_1 = BuildingBlock(256, 512, 1, 'B')
        self.conv4_2 = BuildingBlock(512, 512, 1, 'B')

        self.conv5_1 = BuildingBlock(512, 512, 1, 'B')
        self.conv5_2 = BuildingBlock(512, 512, 1, 'B')

        self.output = nn.Linear(25088, 10)

    def forward(self, x):
        x = F.max_pool2d(self.conv1(x), kernel_size=2, stride=2)

        x = F.max_pool2d(self.conv2(x), kernel_size=2, stride=2)

        x = self.conv3_1(x)
        x = F.max_pool2d(self.conv3_2(x), kernel_size=2, stride=2)

        x = self.conv4_1(x)
        x = F.max_pool2d(self.conv4_2(x), kernel_size=2, stride=2)

        x = self.conv5_1(x)
        x = F.max_pool2d(self.conv5_2(x), kernel_size=2, stride=2)

        # 512*7*7 = 25088
        x = x.view(-1, 25088)
        
        x = self.output(x)

        return x

# %%
resnet = VGG()
resnet.to(device)
# Out:
# VGG(
#   (conv1): BuildingBlock(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): BuildingBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_1): BuildingBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_2): BuildingBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv4_1): BuildingBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_2): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv5_1): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv5_2): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (output): Linear(in_features=25088, out_features=10, bias=True)
# )

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        #print(m)
        init.kaiming_normal_(m.weight)
        #torch.nn.init.zeros_(m.bias)

    elif isinstance(m, nn.Linear):
        #print(m)
        init.kaiming_normal_(m.weight)
        init.zeros_(m.bias)

    # no initialization for BatchNorm2d

# %%
resnet.apply(weights_init)
# Out:
# VGG(
#   (conv1): BuildingBlock(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): BuildingBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_1): BuildingBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_2): BuildingBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv4_1): BuildingBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_2): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv5_1): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (conv5_2): BuildingBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (output): Linear(in_features=25088, out_features=10, bias=True)
# )

# %%
def train_one_epoch(model, train_loader, loss_function, optimizer, epoch):
    model.train()
    length = len(train_loader)
    running_loss = 0.0

    for i, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        pred = model(image)
        loss = loss_function(pred, label)
    
        loss.backward()
        
        optimizer.step()

        running_loss += loss.item()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*128} images, running_loss is {running_loss/(i+1):.4f}')

    print(f'epoch {epoch} : loss {running_loss/length:.4f}')


def eval_one_epoch(model, test_loader, epoch):
    model.eval()
    length = len(test_loader)
    running_acc = 0.0

    for i, (image, label) in enumerate(test_loader):
        image, label = image.to(device), label.numpy()

        pred = model(image)
        pred_label = pred.argmax(axis=1).detach().cpu().numpy()
        running_acc += (pred_label==label).mean()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*128} images, running_acc is {running_acc/(i+1):.4f}')

    val_acc = running_acc/length

    print(f'epoch {epoch} : acc {val_acc:.4f}')

    return val_acc

# %%
# hyperparameters from paper
# assuming same for pretraining

learning_rate = 0.01
momentum = 0.9
weight_decay = 1e-4
epochs = 100

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet.parameters(), lr=learning_rate, 
                            momentum=momentum, weight_decay=weight_decay)

milestones = [60, 80]

scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer, milestones=milestones, gamma=0.1
)

# 391 iterations per epoch
# 32k iter = 82 epochs
# 42k iter = 108 epochs
# 64k iter = 164 epochs

# %%
val_acc_list = []

for epoch in range(epochs):
    train_one_epoch(resnet, train_loader, loss_function, optimizer, epoch)
    val_acc_list.append(eval_one_epoch(resnet, test_loader, epoch))
    scheduler.step()
# Out:
# after looking at 128 images, running_loss is 3.2963
# after looking at 6528 images, running_loss is 18.5670
# after looking at 12928 images, running_loss is 15.2816
# after looking at 19328 images, running_loss is 11.4115
# after looking at 25728 images, running_loss is 9.1461
# after looking at 32128 images, running_loss is 7.7769
# epoch 0 : loss 6.9378
# after looking at 128 images, running_acc is 0.0000
# after looking at 6528 images, running_acc is 0.2286
# after looking at 12928 images, running_acc is 0.1315
# epoch 0 : acc 0.1113
# after looking at 128 images, running_loss is 2.2794
# after looking at 6528 images, running_loss is 2.3021
# after looking at 12928 images, running_loss is 2.2937
# after looking at 19328 images, running_loss is 2.2803
# after looking at 25728 images, running_loss is 2.2709
# after looking at 32128 images, running_loss is 2.2650
# epoch 1 : loss 2.2578
# after looking at 128 images, running_acc is 0.0000
# after looking at 6528 images, running_acc is 0.2230
# after looking at 12928 images, running_acc is 0.1668
# epoch 1 : acc 0.1750
# after looking at 128 images, running_loss is 2.2451
# after looking at 6528 images, running_loss is 2.2034
# after looking at 12928 images, running_loss is 2.2049
# after looking at 19328 images, running_loss is 2.2011
# after looking at 25728 images, running_loss is 2.1974
# after looking at 32128 images, running_loss is 2.1977
# epoch 2 : loss 2.1939
# after looking at 128 images, running_acc is 0.0000
# after looking at 6528 images, running_acc is 0.0380
# after looking at 12928 images, running_acc is 0.1717
# epoch 2 : acc 0.1814
# after looking at 128 images, running_loss is 2.0598
# after looking at 6528 images, running_loss is 2.1886
# after looking at 12928 images, running_loss is 2.1742
# after looking at 19328 images, running_loss is 2.1708
# after looking at 25728 images, running_loss is 2.1700
# after looking at 32128 images, running_loss is 2.1669
# epoch 3 : loss 2.1682
# after looking at 128 images, running_acc is 0.0312
# after looking at 6528 images, running_acc is 0.0699
# after looking at 12928 images, running_acc is 0.1897
# epoch 3 : acc 0.2063
# after looking at 128 images, running_loss is 2.1916
# after looking at 6528 images, running_loss is 2.1191
# after looking at 12928 images, running_loss is 2.1304
# after looking at 19328 images, running_loss is 2.1323
# after looking at 25728 images, running_loss is 2.1272
# after looking at 32128 images, running_loss is 2.1260
# epoch 4 : loss 2.1226
# after looking at 128 images, running_acc is 0.0000
# after looking at 6528 images, running_acc is 0.0833
# after looking at 12928 images, running_acc is 0.1921
# epoch 4 : acc 0.2343
# after looking at 128 images, running_loss is 2.2152
# after looking at 6528 images, running_loss is 2.1171
# after looking at 12928 images, running_loss is 2.1153
# after looking at 19328 images, running_loss is 2.1024
# after looking at 25728 images, running_loss is 2.1003
# after looking at 32128 images, running_loss is 2.0948
# epoch 5 : loss 2.0896
# after looking at 128 images, running_acc is 0.0938
# after looking at 6528 images, running_acc is 0.1330
# after looking at 12928 images, running_acc is 0.2240
# epoch 5 : acc 0.2628
# after looking at 128 images, running_loss is 2.0554
# after looking at 6528 images, running_loss is 2.0881
# after looking at 12928 images, running_loss is 2.0715
# after looking at 19328 images, running_loss is 2.0636
# after looking at 25728 images, running_loss is 2.0623
# after looking at 32128 images, running_loss is 2.0677
# epoch 6 : loss 2.0602
# after looking at 128 images, running_acc is 0.3438
# after looking at 6528 images, running_acc is 0.2757
# after looking at 12928 images, running_acc is 0.2231
# epoch 6 : acc 0.2783
# after looking at 128 images, running_loss is 2.0932
# after looking at 6528 images, running_loss is 2.0268
# after looking at 12928 images, running_loss is 2.0335
# after looking at 19328 images, running_loss is 2.0366
# after looking at 25728 images, running_loss is 2.0430
# after looking at 32128 images, running_loss is 2.0454
# epoch 7 : loss 2.0407
# after looking at 128 images, running_acc is 0.0312
# after looking at 6528 images, running_acc is 0.1844
# after looking at 12928 images, running_acc is 0.2515
# epoch 7 : acc 0.2936
# after looking at 128 images, running_loss is 2.0055
# after looking at 6528 images, running_loss is 1.9916
# after looking at 12928 images, running_loss is 1.9962
# after looking at 19328 images, running_loss is 2.0067
# after looking at 25728 images, running_loss is 2.0082
# after looking at 32128 images, running_loss is 2.0058
# epoch 8 : loss 1.9998
# after looking at 128 images, running_acc is 0.4062
# after looking at 6528 images, running_acc is 0.2721
# after looking at 12928 images, running_acc is 0.2751
# epoch 8 : acc 0.3088
# after looking at 128 images, running_loss is 2.0982
# after looking at 6528 images, running_loss is 1.9921
# after looking at 12928 images, running_loss is 1.9799
# after looking at 19328 images, running_loss is 1.9776
# after looking at 25728 images, running_loss is 1.9679
# after looking at 32128 images, running_loss is 1.9729
# epoch 9 : loss 1.9721
# after looking at 128 images, running_acc is 0.1562
# after looking at 6528 images, running_acc is 0.2776
# after looking at 12928 images, running_acc is 0.2803
# epoch 9 : acc 0.3122
# after looking at 128 images, running_loss is 2.0303
# after looking at 6528 images, running_loss is 1.9687
# after looking at 12928 images, running_loss is 1.9632
# after looking at 19328 images, running_loss is 1.9499
# after looking at 25728 images, running_loss is 1.9364
# after looking at 32128 images, running_loss is 1.9295
# epoch 10 : loss 1.9274
# after looking at 128 images, running_acc is 0.5312
# after looking at 6528 images, running_acc is 0.3082
# after looking at 12928 images, running_acc is 0.3175
# epoch 10 : acc 0.3554
# after looking at 128 images, running_loss is 1.9065
# after looking at 6528 images, running_loss is 1.8888
# after looking at 12928 images, running_loss is 1.8978
# after looking at 19328 images, running_loss is 1.8891
# after looking at 25728 images, running_loss is 1.8865
# after looking at 32128 images, running_loss is 1.8869
# epoch 11 : loss 1.8829
# after looking at 128 images, running_acc is 0.3125
# after looking at 6528 images, running_acc is 0.2353
# after looking at 12928 images, running_acc is 0.3332
# epoch 11 : acc 0.3499
# after looking at 128 images, running_loss is 1.6447
# after looking at 6528 images, running_loss is 1.8292
# after looking at 12928 images, running_loss is 1.8393
# after looking at 19328 images, running_loss is 1.8406
# after looking at 25728 images, running_loss is 1.8506
# after looking at 32128 images, running_loss is 1.8477
# epoch 12 : loss 1.8398
# after looking at 128 images, running_acc is 0.4062
# after looking at 6528 images, running_acc is 0.3254
# after looking at 12928 images, running_acc is 0.3431
# epoch 12 : acc 0.3843
# after looking at 128 images, running_loss is 1.7684
# after looking at 6528 images, running_loss is 1.8121
# after looking at 12928 images, running_loss is 1.8097
# after looking at 19328 images, running_loss is 1.8069
# after looking at 25728 images, running_loss is 1.8039
# after looking at 32128 images, running_loss is 1.8068
# epoch 13 : loss 1.8030
# after looking at 128 images, running_acc is 0.4688
# after looking at 6528 images, running_acc is 0.3388
# after looking at 12928 images, running_acc is 0.3815
# epoch 13 : acc 0.4059
# after looking at 128 images, running_loss is 1.7504
# after looking at 6528 images, running_loss is 1.7507
# after looking at 12928 images, running_loss is 1.7741
# after looking at 19328 images, running_loss is 1.7663
# after looking at 25728 images, running_loss is 1.7691
# after looking at 32128 images, running_loss is 1.7674
# epoch 14 : loss 1.7724
# after looking at 128 images, running_acc is 0.5625
# after looking at 6528 images, running_acc is 0.3683
# after looking at 12928 images, running_acc is 0.4140
# epoch 14 : acc 0.4156
# after looking at 128 images, running_loss is 1.7802
# after looking at 6528 images, running_loss is 1.7634
# after looking at 12928 images, running_loss is 1.7447
# after looking at 19328 images, running_loss is 1.7448
# after looking at 25728 images, running_loss is 1.7379
# after looking at 32128 images, running_loss is 1.7378
# epoch 15 : loss 1.7401
# after looking at 128 images, running_acc is 0.5312
# after looking at 6528 images, running_acc is 0.3738
# after looking at 12928 images, running_acc is 0.3899
# epoch 15 : acc 0.4228
# after looking at 128 images, running_loss is 1.9801
# after looking at 6528 images, running_loss is 1.6710
# after looking at 12928 images, running_loss is 1.7172
# after looking at 19328 images, running_loss is 1.7098
# after looking at 25728 images, running_loss is 1.7110
# after looking at 32128 images, running_loss is 1.7133
# epoch 16 : loss 1.7136
# after looking at 128 images, running_acc is 0.5625
# after looking at 6528 images, running_acc is 0.3382
# after looking at 12928 images, running_acc is 0.4140
# epoch 16 : acc 0.4308
# after looking at 128 images, running_loss is 1.6908
# after looking at 6528 images, running_loss is 1.6927
# after looking at 12928 images, running_loss is 1.7016
# after looking at 19328 images, running_loss is 1.6945
# after looking at 25728 images, running_loss is 1.7024
# after looking at 32128 images, running_loss is 1.7025
# epoch 17 : loss 1.7044
# after looking at 128 images, running_acc is 0.5625
# after looking at 6528 images, running_acc is 0.4222
# after looking at 12928 images, running_acc is 0.4267
# epoch 17 : acc 0.4426
# after looking at 128 images, running_loss is 1.7384
# after looking at 6528 images, running_loss is 1.7020
# after looking at 12928 images, running_loss is 1.6541
# after looking at 19328 images, running_loss is 1.6522
# after looking at 25728 images, running_loss is 1.6621
# after looking at 32128 images, running_loss is 1.6672
# epoch 18 : loss 1.6666
# after looking at 128 images, running_acc is 0.4062
# after looking at 6528 images, running_acc is 0.3419
# after looking at 12928 images, running_acc is 0.4097
# epoch 18 : acc 0.4543
# after looking at 128 images, running_loss is 1.8356
# after looking at 6528 images, running_loss is 1.6502
# after looking at 12928 images, running_loss is 1.6374
# after looking at 19328 images, running_loss is 1.6338
# after looking at 25728 images, running_loss is 1.6442
# after looking at 32128 images, running_loss is 1.6502
# epoch 19 : loss 1.6470
# after looking at 128 images, running_acc is 0.5000
# after looking at 6528 images, running_acc is 0.3438
# after looking at 12928 images, running_acc is 0.4418
# epoch 19 : acc 0.4701
# after looking at 128 images, running_loss is 1.7540
# after looking at 6528 images, running_loss is 1.6171
# after looking at 12928 images, running_loss is 1.6094
# after looking at 19328 images, running_loss is 1.6040
# after looking at 25728 images, running_loss is 1.5869
# after looking at 32128 images, running_loss is 1.5928
# epoch 20 : loss 1.5916
# after looking at 128 images, running_acc is 0.6562
# after looking at 6528 images, running_acc is 0.4228
# after looking at 12928 images, running_acc is 0.4437
# epoch 20 : acc 0.4829
# after looking at 128 images, running_loss is 1.7144
# after looking at 6528 images, running_loss is 1.5903
# after looking at 12928 images, running_loss is 1.5740
# after looking at 19328 images, running_loss is 1.5726
# after looking at 25728 images, running_loss is 1.5597
# after looking at 32128 images, running_loss is 1.5626
# epoch 21 : loss 1.5651
# after looking at 128 images, running_acc is 0.6250
# after looking at 6528 images, running_acc is 0.4547
# after looking at 12928 images, running_acc is 0.5015
# epoch 21 : acc 0.5305
# after looking at 128 images, running_loss is 1.4740
# after looking at 6528 images, running_loss is 1.5236
# after looking at 12928 images, running_loss is 1.5230
# after looking at 19328 images, running_loss is 1.5157
# after looking at 25728 images, running_loss is 1.5121
# after looking at 32128 images, running_loss is 1.5166
# epoch 22 : loss 1.5165
# after looking at 128 images, running_acc is 0.7188
# after looking at 6528 images, running_acc is 0.4841
# after looking at 12928 images, running_acc is 0.4777
# epoch 22 : acc 0.5101
# after looking at 128 images, running_loss is 0.9812
# after looking at 6528 images, running_loss is 1.4997
# after looking at 12928 images, running_loss is 1.4874
# after looking at 19328 images, running_loss is 1.4862
# after looking at 25728 images, running_loss is 1.4814
# after looking at 32128 images, running_loss is 1.4880
# epoch 23 : loss 1.4822
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.5233
# after looking at 12928 images, running_acc is 0.5297
# epoch 23 : acc 0.5436
# after looking at 128 images, running_loss is 1.4120
# after looking at 6528 images, running_loss is 1.4740
# after looking at 12928 images, running_loss is 1.4456
# after looking at 19328 images, running_loss is 1.4387
# after looking at 25728 images, running_loss is 1.4302
# after looking at 32128 images, running_loss is 1.4253
# epoch 24 : loss 1.4243
# after looking at 128 images, running_acc is 0.6875
# after looking at 6528 images, running_acc is 0.5294
# after looking at 12928 images, running_acc is 0.5517
# epoch 24 : acc 0.5594
# after looking at 128 images, running_loss is 1.7038
# after looking at 6528 images, running_loss is 1.3597
# after looking at 12928 images, running_loss is 1.3836
# after looking at 19328 images, running_loss is 1.3936
# after looking at 25728 images, running_loss is 1.3862
# after looking at 32128 images, running_loss is 1.3838
# epoch 25 : loss 1.3864
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.5551
# after looking at 12928 images, running_acc is 0.5523
# epoch 25 : acc 0.5606
# after looking at 128 images, running_loss is 1.7565
# after looking at 6528 images, running_loss is 1.3405
# after looking at 12928 images, running_loss is 1.3513
# after looking at 19328 images, running_loss is 1.3505
# after looking at 25728 images, running_loss is 1.3475
# after looking at 32128 images, running_loss is 1.3455
# epoch 26 : loss 1.3489
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.5895
# after looking at 12928 images, running_acc is 0.5903
# epoch 26 : acc 0.5859
# after looking at 128 images, running_loss is 1.2843
# after looking at 6528 images, running_loss is 1.2962
# after looking at 12928 images, running_loss is 1.3078
# after looking at 19328 images, running_loss is 1.3139
# after looking at 25728 images, running_loss is 1.3145
# after looking at 32128 images, running_loss is 1.3132
# epoch 27 : loss 1.3112
# after looking at 128 images, running_acc is 0.7188
# after looking at 6528 images, running_acc is 0.5827
# after looking at 12928 images, running_acc is 0.5535
# epoch 27 : acc 0.5876
# after looking at 128 images, running_loss is 1.5201
# after looking at 6528 images, running_loss is 1.2520
# after looking at 12928 images, running_loss is 1.2709
# after looking at 19328 images, running_loss is 1.2550
# after looking at 25728 images, running_loss is 1.2393
# after looking at 32128 images, running_loss is 1.2444
# epoch 28 : loss 1.2375
# after looking at 128 images, running_acc is 0.7812
# after looking at 6528 images, running_acc is 0.5631
# after looking at 12928 images, running_acc is 0.6139
# epoch 28 : acc 0.6222
# after looking at 128 images, running_loss is 1.4164
# after looking at 6528 images, running_loss is 1.2017
# after looking at 12928 images, running_loss is 1.1753
# after looking at 19328 images, running_loss is 1.1904
# after looking at 25728 images, running_loss is 1.1895
# after looking at 32128 images, running_loss is 1.1916
# epoch 29 : loss 1.1968
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.6189
# after looking at 12928 images, running_acc is 0.6114
# epoch 29 : acc 0.6163
# after looking at 128 images, running_loss is 1.2181
# after looking at 6528 images, running_loss is 1.1691
# after looking at 12928 images, running_loss is 1.1795
# after looking at 19328 images, running_loss is 1.1573
# after looking at 25728 images, running_loss is 1.1487
# after looking at 32128 images, running_loss is 1.1518
# epoch 30 : loss 1.1424
# after looking at 128 images, running_acc is 0.7812
# after looking at 6528 images, running_acc is 0.5582
# after looking at 12928 images, running_acc is 0.5950
# epoch 30 : acc 0.6032
# after looking at 128 images, running_loss is 1.1397
# after looking at 6528 images, running_loss is 1.1103
# after looking at 12928 images, running_loss is 1.1077
# after looking at 19328 images, running_loss is 1.1123
# after looking at 25728 images, running_loss is 1.0953
# after looking at 32128 images, running_loss is 1.0933
# epoch 31 : loss 1.1004
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.5864
# after looking at 12928 images, running_acc is 0.5928
# epoch 31 : acc 0.6232
# after looking at 128 images, running_loss is 0.9998
# after looking at 6528 images, running_loss is 1.0504
# after looking at 12928 images, running_loss is 1.0740
# after looking at 19328 images, running_loss is 1.0653
# after looking at 25728 images, running_loss is 1.0591
# after looking at 32128 images, running_loss is 1.0499
# epoch 32 : loss 1.0577
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7218
# after looking at 12928 images, running_acc is 0.7058
# epoch 32 : acc 0.6989
# after looking at 128 images, running_loss is 1.3047
# after looking at 6528 images, running_loss is 0.9876
# after looking at 12928 images, running_loss is 1.0002
# after looking at 19328 images, running_loss is 1.0127
# after looking at 25728 images, running_loss is 1.0248
# after looking at 32128 images, running_loss is 1.0310
# epoch 33 : loss 1.0291
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.6991
# after looking at 12928 images, running_acc is 0.6949
# epoch 33 : acc 0.6830
# after looking at 128 images, running_loss is 0.7281
# after looking at 6528 images, running_loss is 1.0040
# after looking at 12928 images, running_loss is 0.9955
# after looking at 19328 images, running_loss is 0.9999
# after looking at 25728 images, running_loss is 1.0126
# after looking at 32128 images, running_loss is 1.0100
# epoch 34 : loss 1.0020
# after looking at 128 images, running_acc is 0.8125
# after looking at 6528 images, running_acc is 0.7224
# after looking at 12928 images, running_acc is 0.7348
# epoch 34 : acc 0.7221
# after looking at 128 images, running_loss is 1.3985
# after looking at 6528 images, running_loss is 0.9563
# after looking at 12928 images, running_loss is 0.9529
# after looking at 19328 images, running_loss is 0.9557
# after looking at 25728 images, running_loss is 0.9497
# after looking at 32128 images, running_loss is 0.9547
# epoch 35 : loss 0.9591
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7488
# after looking at 12928 images, running_acc is 0.7184
# epoch 35 : acc 0.7074
# after looking at 128 images, running_loss is 0.9500
# after looking at 6528 images, running_loss is 0.9345
# after looking at 12928 images, running_loss is 0.9219
# after looking at 19328 images, running_loss is 0.9275
# after looking at 25728 images, running_loss is 0.9229
# after looking at 32128 images, running_loss is 0.9209
# epoch 36 : loss 0.9264
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.7298
# after looking at 12928 images, running_acc is 0.7361
# epoch 36 : acc 0.7196
# after looking at 128 images, running_loss is 0.6355
# after looking at 6528 images, running_loss is 0.9077
# after looking at 12928 images, running_loss is 0.9125
# after looking at 19328 images, running_loss is 0.9236
# after looking at 25728 images, running_loss is 0.9190
# after looking at 32128 images, running_loss is 0.9062
# epoch 37 : loss 0.9012
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7825
# after looking at 12928 images, running_acc is 0.7073
# epoch 37 : acc 0.7034
# after looking at 128 images, running_loss is 1.1422
# after looking at 6528 images, running_loss is 0.8637
# after looking at 12928 images, running_loss is 0.8488
# after looking at 19328 images, running_loss is 0.8463
# after looking at 25728 images, running_loss is 0.8448
# after looking at 32128 images, running_loss is 0.8471
# epoch 38 : loss 0.8514
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7574
# after looking at 12928 images, running_acc is 0.7587
# epoch 38 : acc 0.7564
# after looking at 128 images, running_loss is 0.8819
# after looking at 6528 images, running_loss is 0.8218
# after looking at 12928 images, running_loss is 0.8165
# after looking at 19328 images, running_loss is 0.8510
# after looking at 25728 images, running_loss is 0.8433
# after looking at 32128 images, running_loss is 0.8477
# epoch 39 : loss 0.8432
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.6636
# after looking at 12928 images, running_acc is 0.7178
# epoch 39 : acc 0.7278
# after looking at 128 images, running_loss is 0.4545
# after looking at 6528 images, running_loss is 0.8247
# after looking at 12928 images, running_loss is 0.8271
# after looking at 19328 images, running_loss is 0.8138
# after looking at 25728 images, running_loss is 0.8080
# after looking at 32128 images, running_loss is 0.8153
# epoch 40 : loss 0.8186
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7696
# after looking at 12928 images, running_acc is 0.7426
# epoch 40 : acc 0.7442
# after looking at 128 images, running_loss is 0.8324
# after looking at 6528 images, running_loss is 0.8226
# after looking at 12928 images, running_loss is 0.8294
# after looking at 19328 images, running_loss is 0.8163
# after looking at 25728 images, running_loss is 0.8097
# after looking at 32128 images, running_loss is 0.8161
# epoch 41 : loss 0.8088
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.7788
# after looking at 12928 images, running_acc is 0.7460
# epoch 41 : acc 0.7463
# after looking at 128 images, running_loss is 0.8567
# after looking at 6528 images, running_loss is 0.7890
# after looking at 12928 images, running_loss is 0.8169
# after looking at 19328 images, running_loss is 0.8074
# after looking at 25728 images, running_loss is 0.8073
# after looking at 32128 images, running_loss is 0.7989
# epoch 42 : loss 0.7956
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7696
# after looking at 12928 images, running_acc is 0.7837
# epoch 42 : acc 0.7679
# after looking at 128 images, running_loss is 0.8608
# after looking at 6528 images, running_loss is 0.7625
# after looking at 12928 images, running_loss is 0.7795
# after looking at 19328 images, running_loss is 0.7557
# after looking at 25728 images, running_loss is 0.7676
# after looking at 32128 images, running_loss is 0.7771
# epoch 43 : loss 0.7684
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7635
# after looking at 12928 images, running_acc is 0.7744
# epoch 43 : acc 0.7803
# after looking at 128 images, running_loss is 0.7727
# after looking at 6528 images, running_loss is 0.7845
# after looking at 12928 images, running_loss is 0.7596
# after looking at 19328 images, running_loss is 0.7461
# after looking at 25728 images, running_loss is 0.7538
# after looking at 32128 images, running_loss is 0.7401
# epoch 44 : loss 0.7441
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8131
# after looking at 12928 images, running_acc is 0.7871
# epoch 44 : acc 0.7732
# after looking at 128 images, running_loss is 0.8046
# after looking at 6528 images, running_loss is 0.7101
# after looking at 12928 images, running_loss is 0.7062
# after looking at 19328 images, running_loss is 0.7232
# after looking at 25728 images, running_loss is 0.7227
# after looking at 32128 images, running_loss is 0.7306
# epoch 45 : loss 0.7271
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.7708
# after looking at 12928 images, running_acc is 0.7720
# epoch 45 : acc 0.7642
# after looking at 128 images, running_loss is 0.5536
# after looking at 6528 images, running_loss is 0.7015
# after looking at 12928 images, running_loss is 0.7248
# after looking at 19328 images, running_loss is 0.7048
# after looking at 25728 images, running_loss is 0.7119
# after looking at 32128 images, running_loss is 0.7121
# epoch 46 : loss 0.7128
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7911
# after looking at 12928 images, running_acc is 0.7748
# epoch 46 : acc 0.7826
# after looking at 128 images, running_loss is 0.9997
# after looking at 6528 images, running_loss is 0.6956
# after looking at 12928 images, running_loss is 0.7001
# after looking at 19328 images, running_loss is 0.6915
# after looking at 25728 images, running_loss is 0.7047
# after looking at 32128 images, running_loss is 0.6984
# epoch 47 : loss 0.6987
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8058
# after looking at 12928 images, running_acc is 0.7927
# epoch 47 : acc 0.7872
# after looking at 128 images, running_loss is 0.4965
# after looking at 6528 images, running_loss is 0.6784
# after looking at 12928 images, running_loss is 0.6793
# after looking at 19328 images, running_loss is 0.6658
# after looking at 25728 images, running_loss is 0.6622
# after looking at 32128 images, running_loss is 0.6584
# epoch 48 : loss 0.6667
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.7335
# after looking at 12928 images, running_acc is 0.7222
# epoch 48 : acc 0.7417
# after looking at 128 images, running_loss is 0.7475
# after looking at 6528 images, running_loss is 0.6357
# after looking at 12928 images, running_loss is 0.6708
# after looking at 19328 images, running_loss is 0.6845
# after looking at 25728 images, running_loss is 0.6764
# after looking at 32128 images, running_loss is 0.6609
# epoch 49 : loss 0.6524
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.7770
# after looking at 12928 images, running_acc is 0.7760
# epoch 49 : acc 0.7832
# after looking at 128 images, running_loss is 0.3266
# after looking at 6528 images, running_loss is 0.6101
# after looking at 12928 images, running_loss is 0.6714
# after looking at 19328 images, running_loss is 0.6758
# after looking at 25728 images, running_loss is 0.6534
# after looking at 32128 images, running_loss is 0.6587
# epoch 50 : loss 0.6552
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.7941
# after looking at 12928 images, running_acc is 0.7887
# epoch 50 : acc 0.7808
# after looking at 128 images, running_loss is 0.4004
# after looking at 6528 images, running_loss is 0.6081
# after looking at 12928 images, running_loss is 0.5896
# after looking at 19328 images, running_loss is 0.6027
# after looking at 25728 images, running_loss is 0.6040
# after looking at 32128 images, running_loss is 0.6145
# epoch 51 : loss 0.6183
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8100
# after looking at 12928 images, running_acc is 0.7896
# epoch 51 : acc 0.7892
# after looking at 128 images, running_loss is 0.5315
# after looking at 6528 images, running_loss is 0.6385
# after looking at 12928 images, running_loss is 0.6529
# after looking at 19328 images, running_loss is 0.6370
# after looking at 25728 images, running_loss is 0.6293
# after looking at 32128 images, running_loss is 0.6155
# epoch 52 : loss 0.6120
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.7984
# after looking at 12928 images, running_acc is 0.7995
# epoch 52 : acc 0.8036
# after looking at 128 images, running_loss is 0.6337
# after looking at 6528 images, running_loss is 0.5662
# after looking at 12928 images, running_loss is 0.5961
# after looking at 19328 images, running_loss is 0.5964
# after looking at 25728 images, running_loss is 0.6071
# after looking at 32128 images, running_loss is 0.6095
# epoch 53 : loss 0.6072
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8076
# after looking at 12928 images, running_acc is 0.8119
# epoch 53 : acc 0.8112
# after looking at 128 images, running_loss is 0.6785
# after looking at 6528 images, running_loss is 0.5681
# after looking at 12928 images, running_loss is 0.5851
# after looking at 19328 images, running_loss is 0.5952
# after looking at 25728 images, running_loss is 0.6114
# after looking at 32128 images, running_loss is 0.6079
# epoch 54 : loss 0.6001
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8064
# after looking at 12928 images, running_acc is 0.7884
# epoch 54 : acc 0.7967
# after looking at 128 images, running_loss is 0.6243
# after looking at 6528 images, running_loss is 0.5402
# after looking at 12928 images, running_loss is 0.5449
# after looking at 19328 images, running_loss is 0.5516
# after looking at 25728 images, running_loss is 0.5578
# after looking at 32128 images, running_loss is 0.5618
# epoch 55 : loss 0.5716
# after looking at 128 images, running_acc is 0.8438
# after looking at 6528 images, running_acc is 0.7837
# after looking at 12928 images, running_acc is 0.8007
# epoch 55 : acc 0.7985
# after looking at 128 images, running_loss is 0.3373
# after looking at 6528 images, running_loss is 0.5340
# after looking at 12928 images, running_loss is 0.5483
# after looking at 19328 images, running_loss is 0.5655
# after looking at 25728 images, running_loss is 0.5626
# after looking at 32128 images, running_loss is 0.5607
# epoch 56 : loss 0.5612
# after looking at 128 images, running_acc is 0.7500
# after looking at 6528 images, running_acc is 0.7886
# after looking at 12928 images, running_acc is 0.7686
# epoch 56 : acc 0.7801
# after looking at 128 images, running_loss is 0.9779
# after looking at 6528 images, running_loss is 0.5351
# after looking at 12928 images, running_loss is 0.5270
# after looking at 19328 images, running_loss is 0.5327
# after looking at 25728 images, running_loss is 0.5406
# after looking at 32128 images, running_loss is 0.5444
# epoch 57 : loss 0.5488
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8192
# after looking at 12928 images, running_acc is 0.7976
# epoch 57 : acc 0.7953
# after looking at 128 images, running_loss is 0.3782
# after looking at 6528 images, running_loss is 0.4914
# after looking at 12928 images, running_loss is 0.4977
# after looking at 19328 images, running_loss is 0.5235
# after looking at 25728 images, running_loss is 0.5209
# after looking at 32128 images, running_loss is 0.5324
# epoch 58 : loss 0.5335
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8272
# after looking at 12928 images, running_acc is 0.7958
# epoch 58 : acc 0.8045
# after looking at 128 images, running_loss is 0.2291
# after looking at 6528 images, running_loss is 0.5340
# after looking at 12928 images, running_loss is 0.5281
# after looking at 19328 images, running_loss is 0.5218
# after looking at 25728 images, running_loss is 0.5219
# after looking at 32128 images, running_loss is 0.5226
# epoch 59 : loss 0.5281
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.7665
# after looking at 12928 images, running_acc is 0.7785
# epoch 59 : acc 0.7793
# after looking at 128 images, running_loss is 0.4919
# after looking at 6528 images, running_loss is 0.5032
# after looking at 12928 images, running_loss is 0.4750
# after looking at 19328 images, running_loss is 0.4543
# after looking at 25728 images, running_loss is 0.4479
# after looking at 32128 images, running_loss is 0.4306
# epoch 60 : loss 0.4243
# after looking at 128 images, running_acc is 0.8750
# after looking at 6528 images, running_acc is 0.8634
# after looking at 12928 images, running_acc is 0.8425
# epoch 60 : acc 0.8427
# after looking at 128 images, running_loss is 0.4975
# after looking at 6528 images, running_loss is 0.3942
# after looking at 12928 images, running_loss is 0.3843
# after looking at 19328 images, running_loss is 0.3853
# after looking at 25728 images, running_loss is 0.3907
# after looking at 32128 images, running_loss is 0.3874
# epoch 61 : loss 0.3806
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8597
# after looking at 12928 images, running_acc is 0.8502
# epoch 61 : acc 0.8503
# after looking at 128 images, running_loss is 0.2764
# after looking at 6528 images, running_loss is 0.3506
# after looking at 12928 images, running_loss is 0.3579
# after looking at 19328 images, running_loss is 0.3644
# after looking at 25728 images, running_loss is 0.3593
# after looking at 32128 images, running_loss is 0.3643
# epoch 62 : loss 0.3703
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8781
# after looking at 12928 images, running_acc is 0.8552
# epoch 62 : acc 0.8544
# after looking at 128 images, running_loss is 0.4647
# after looking at 6528 images, running_loss is 0.3684
# after looking at 12928 images, running_loss is 0.3813
# after looking at 19328 images, running_loss is 0.3553
# after looking at 25728 images, running_loss is 0.3570
# after looking at 32128 images, running_loss is 0.3537
# epoch 63 : loss 0.3569
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8689
# after looking at 12928 images, running_acc is 0.8515
# epoch 63 : acc 0.8529
# after looking at 128 images, running_loss is 0.2398
# after looking at 6528 images, running_loss is 0.3089
# after looking at 12928 images, running_loss is 0.3245
# after looking at 19328 images, running_loss is 0.3341
# after looking at 25728 images, running_loss is 0.3361
# after looking at 32128 images, running_loss is 0.3533
# epoch 64 : loss 0.3565
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8670
# after looking at 12928 images, running_acc is 0.8527
# epoch 64 : acc 0.8534
# after looking at 128 images, running_loss is 0.2517
# after looking at 6528 images, running_loss is 0.3493
# after looking at 12928 images, running_loss is 0.3301
# after looking at 19328 images, running_loss is 0.3425
# after looking at 25728 images, running_loss is 0.3510
# after looking at 32128 images, running_loss is 0.3555
# epoch 65 : loss 0.3576
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8750
# after looking at 12928 images, running_acc is 0.8574
# epoch 65 : acc 0.8559
# after looking at 128 images, running_loss is 0.4303
# after looking at 6528 images, running_loss is 0.3322
# after looking at 12928 images, running_loss is 0.3434
# after looking at 19328 images, running_loss is 0.3426
# after looking at 25728 images, running_loss is 0.3403
# after looking at 32128 images, running_loss is 0.3377
# epoch 66 : loss 0.3396
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8634
# after looking at 12928 images, running_acc is 0.8552
# epoch 66 : acc 0.8566
# after looking at 128 images, running_loss is 0.3480
# after looking at 6528 images, running_loss is 0.3615
# after looking at 12928 images, running_loss is 0.3566
# after looking at 19328 images, running_loss is 0.3522
# after looking at 25728 images, running_loss is 0.3536
# after looking at 32128 images, running_loss is 0.3472
# epoch 67 : loss 0.3485
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8750
# after looking at 12928 images, running_acc is 0.8530
# epoch 67 : acc 0.8557
# after looking at 128 images, running_loss is 0.4071
# after looking at 6528 images, running_loss is 0.3236
# after looking at 12928 images, running_loss is 0.3238
# after looking at 19328 images, running_loss is 0.3331
# after looking at 25728 images, running_loss is 0.3365
# after looking at 32128 images, running_loss is 0.3322
# epoch 68 : loss 0.3339
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8732
# after looking at 12928 images, running_acc is 0.8577
# epoch 68 : acc 0.8573
# after looking at 128 images, running_loss is 0.3224
# after looking at 6528 images, running_loss is 0.3504
# after looking at 12928 images, running_loss is 0.3374
# after looking at 19328 images, running_loss is 0.3418
# after looking at 25728 images, running_loss is 0.3285
# after looking at 32128 images, running_loss is 0.3299
# epoch 69 : loss 0.3325
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8701
# after looking at 12928 images, running_acc is 0.8598
# epoch 69 : acc 0.8623
# after looking at 128 images, running_loss is 0.5336
# after looking at 6528 images, running_loss is 0.3103
# after looking at 12928 images, running_loss is 0.2986
# after looking at 19328 images, running_loss is 0.3071
# after looking at 25728 images, running_loss is 0.3227
# after looking at 32128 images, running_loss is 0.3282
# epoch 70 : loss 0.3333
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8738
# after looking at 12928 images, running_acc is 0.8595
# epoch 70 : acc 0.8607
# after looking at 128 images, running_loss is 0.4970
# after looking at 6528 images, running_loss is 0.2987
# after looking at 12928 images, running_loss is 0.2939
# after looking at 19328 images, running_loss is 0.3142
# after looking at 25728 images, running_loss is 0.3172
# after looking at 32128 images, running_loss is 0.3227
# epoch 71 : loss 0.3235
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8725
# after looking at 12928 images, running_acc is 0.8543
# epoch 71 : acc 0.8572
# after looking at 128 images, running_loss is 0.2203
# after looking at 6528 images, running_loss is 0.3111
# after looking at 12928 images, running_loss is 0.2843
# after looking at 19328 images, running_loss is 0.3053
# after looking at 25728 images, running_loss is 0.3044
# after looking at 32128 images, running_loss is 0.3112
# epoch 72 : loss 0.3147
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8719
# after looking at 12928 images, running_acc is 0.8567
# epoch 72 : acc 0.8585
# after looking at 128 images, running_loss is 0.4391
# after looking at 6528 images, running_loss is 0.3256
# after looking at 12928 images, running_loss is 0.3322
# after looking at 19328 images, running_loss is 0.3340
# after looking at 25728 images, running_loss is 0.3311
# after looking at 32128 images, running_loss is 0.3316
# epoch 73 : loss 0.3311
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8689
# after looking at 12928 images, running_acc is 0.8552
# epoch 73 : acc 0.8577
# after looking at 128 images, running_loss is 0.2839
# after looking at 6528 images, running_loss is 0.2797
# after looking at 12928 images, running_loss is 0.2748
# after looking at 19328 images, running_loss is 0.2878
# after looking at 25728 images, running_loss is 0.2956
# after looking at 32128 images, running_loss is 0.2962
# epoch 74 : loss 0.3001
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8713
# after looking at 12928 images, running_acc is 0.8583
# epoch 74 : acc 0.8606
# after looking at 128 images, running_loss is 0.0952
# after looking at 6528 images, running_loss is 0.2757
# after looking at 12928 images, running_loss is 0.2914
# after looking at 19328 images, running_loss is 0.2970
# after looking at 25728 images, running_loss is 0.2949
# after looking at 32128 images, running_loss is 0.3047
# epoch 75 : loss 0.3091
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8824
# after looking at 12928 images, running_acc is 0.8629
# epoch 75 : acc 0.8620
# after looking at 128 images, running_loss is 0.4630
# after looking at 6528 images, running_loss is 0.3059
# after looking at 12928 images, running_loss is 0.3082
# after looking at 19328 images, running_loss is 0.3057
# after looking at 25728 images, running_loss is 0.3110
# after looking at 32128 images, running_loss is 0.3176
# epoch 76 : loss 0.3194
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8860
# after looking at 12928 images, running_acc is 0.8561
# epoch 76 : acc 0.8585
# after looking at 128 images, running_loss is 0.3260
# after looking at 6528 images, running_loss is 0.2874
# after looking at 12928 images, running_loss is 0.3056
# after looking at 19328 images, running_loss is 0.2906
# after looking at 25728 images, running_loss is 0.2943
# after looking at 32128 images, running_loss is 0.2927
# epoch 77 : loss 0.3032
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8744
# after looking at 12928 images, running_acc is 0.8605
# epoch 77 : acc 0.8599
# after looking at 128 images, running_loss is 0.2041
# after looking at 6528 images, running_loss is 0.2789
# after looking at 12928 images, running_loss is 0.2901
# after looking at 19328 images, running_loss is 0.2861
# after looking at 25728 images, running_loss is 0.2911
# after looking at 32128 images, running_loss is 0.2961
# epoch 78 : loss 0.2921
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8719
# after looking at 12928 images, running_acc is 0.8518
# epoch 78 : acc 0.8563
# after looking at 128 images, running_loss is 0.2221
# after looking at 6528 images, running_loss is 0.3055
# after looking at 12928 images, running_loss is 0.3132
# after looking at 19328 images, running_loss is 0.3060
# after looking at 25728 images, running_loss is 0.2995
# after looking at 32128 images, running_loss is 0.2978
# epoch 79 : loss 0.2967
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8842
# after looking at 12928 images, running_acc is 0.8636
# epoch 79 : acc 0.8639
# after looking at 128 images, running_loss is 0.1622
# after looking at 6528 images, running_loss is 0.2713
# after looking at 12928 images, running_loss is 0.2762
# after looking at 19328 images, running_loss is 0.2772
# after looking at 25728 images, running_loss is 0.2776
# after looking at 32128 images, running_loss is 0.2760
# epoch 80 : loss 0.2769
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8817
# after looking at 12928 images, running_acc is 0.8632
# epoch 80 : acc 0.8637
# after looking at 128 images, running_loss is 0.2975
# after looking at 6528 images, running_loss is 0.2724
# after looking at 12928 images, running_loss is 0.2726
# after looking at 19328 images, running_loss is 0.2845
# after looking at 25728 images, running_loss is 0.2750
# after looking at 32128 images, running_loss is 0.2831
# epoch 81 : loss 0.2840
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8781
# after looking at 12928 images, running_acc is 0.8595
# epoch 81 : acc 0.8614
# after looking at 128 images, running_loss is 0.3069
# after looking at 6528 images, running_loss is 0.3032
# after looking at 12928 images, running_loss is 0.2969
# after looking at 19328 images, running_loss is 0.2944
# after looking at 25728 images, running_loss is 0.2855
# after looking at 32128 images, running_loss is 0.2823
# epoch 82 : loss 0.2824
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8824
# after looking at 12928 images, running_acc is 0.8626
# epoch 82 : acc 0.8626
# after looking at 128 images, running_loss is 0.4518
# after looking at 6528 images, running_loss is 0.2802
# after looking at 12928 images, running_loss is 0.2709
# after looking at 19328 images, running_loss is 0.2710
# after looking at 25728 images, running_loss is 0.2744
# after looking at 32128 images, running_loss is 0.2752
# epoch 83 : loss 0.2789
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8768
# after looking at 12928 images, running_acc is 0.8626
# epoch 83 : acc 0.8632
# after looking at 128 images, running_loss is 0.3922
# after looking at 6528 images, running_loss is 0.2748
# after looking at 12928 images, running_loss is 0.2878
# after looking at 19328 images, running_loss is 0.2921
# after looking at 25728 images, running_loss is 0.2903
# after looking at 32128 images, running_loss is 0.2817
# epoch 84 : loss 0.2770
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8799
# after looking at 12928 images, running_acc is 0.8651
# epoch 84 : acc 0.8640
# after looking at 128 images, running_loss is 0.1812
# after looking at 6528 images, running_loss is 0.2991
# after looking at 12928 images, running_loss is 0.2832
# after looking at 19328 images, running_loss is 0.2799
# after looking at 25728 images, running_loss is 0.2826
# after looking at 32128 images, running_loss is 0.2778
# epoch 85 : loss 0.2767
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8830
# after looking at 12928 images, running_acc is 0.8639
# epoch 85 : acc 0.8637
# after looking at 128 images, running_loss is 0.3525
# after looking at 6528 images, running_loss is 0.2941
# after looking at 12928 images, running_loss is 0.2975
# after looking at 19328 images, running_loss is 0.2911
# after looking at 25728 images, running_loss is 0.2839
# after looking at 32128 images, running_loss is 0.2793
# epoch 86 : loss 0.2778
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8805
# after looking at 12928 images, running_acc is 0.8605
# epoch 86 : acc 0.8618
# after looking at 128 images, running_loss is 0.3989
# after looking at 6528 images, running_loss is 0.2396
# after looking at 12928 images, running_loss is 0.2617
# after looking at 19328 images, running_loss is 0.2630
# after looking at 25728 images, running_loss is 0.2645
# after looking at 32128 images, running_loss is 0.2683
# epoch 87 : loss 0.2679
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8750
# after looking at 12928 images, running_acc is 0.8605
# epoch 87 : acc 0.8626
# after looking at 128 images, running_loss is 0.2877
# after looking at 6528 images, running_loss is 0.2882
# after looking at 12928 images, running_loss is 0.2709
# after looking at 19328 images, running_loss is 0.2662
# after looking at 25728 images, running_loss is 0.2717
# after looking at 32128 images, running_loss is 0.2719
# epoch 88 : loss 0.2730
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8775
# after looking at 12928 images, running_acc is 0.8639
# epoch 88 : acc 0.8639
# after looking at 128 images, running_loss is 0.3977
# after looking at 6528 images, running_loss is 0.2606
# after looking at 12928 images, running_loss is 0.2546
# after looking at 19328 images, running_loss is 0.2624
# after looking at 25728 images, running_loss is 0.2698
# after looking at 32128 images, running_loss is 0.2674
# epoch 89 : loss 0.2690
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8707
# after looking at 12928 images, running_acc is 0.8595
# epoch 89 : acc 0.8612
# after looking at 128 images, running_loss is 0.2827
# after looking at 6528 images, running_loss is 0.3153
# after looking at 12928 images, running_loss is 0.2889
# after looking at 19328 images, running_loss is 0.2822
# after looking at 25728 images, running_loss is 0.2738
# after looking at 32128 images, running_loss is 0.2685
# epoch 90 : loss 0.2656
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8756
# after looking at 12928 images, running_acc is 0.8611
# epoch 90 : acc 0.8624
# after looking at 128 images, running_loss is 0.3184
# after looking at 6528 images, running_loss is 0.2788
# after looking at 12928 images, running_loss is 0.2731
# after looking at 19328 images, running_loss is 0.2726
# after looking at 25728 images, running_loss is 0.2689
# after looking at 32128 images, running_loss is 0.2687
# epoch 91 : loss 0.2730
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8744
# after looking at 12928 images, running_acc is 0.8629
# epoch 91 : acc 0.8634
# after looking at 128 images, running_loss is 0.2837
# after looking at 6528 images, running_loss is 0.2743
# after looking at 12928 images, running_loss is 0.2869
# after looking at 19328 images, running_loss is 0.2844
# after looking at 25728 images, running_loss is 0.2722
# after looking at 32128 images, running_loss is 0.2731
# epoch 92 : loss 0.2752
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8781
# after looking at 12928 images, running_acc is 0.8648
# epoch 92 : acc 0.8647
# after looking at 128 images, running_loss is 0.3289
# after looking at 6528 images, running_loss is 0.2141
# after looking at 12928 images, running_loss is 0.2485
# after looking at 19328 images, running_loss is 0.2650
# after looking at 25728 images, running_loss is 0.2691
# after looking at 32128 images, running_loss is 0.2688
# epoch 93 : loss 0.2686
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8781
# after looking at 12928 images, running_acc is 0.8620
# epoch 93 : acc 0.8629
# after looking at 128 images, running_loss is 0.2592
# after looking at 6528 images, running_loss is 0.2555
# after looking at 12928 images, running_loss is 0.2591
# after looking at 19328 images, running_loss is 0.2697
# after looking at 25728 images, running_loss is 0.2696
# after looking at 32128 images, running_loss is 0.2649
# epoch 94 : loss 0.2616
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8756
# after looking at 12928 images, running_acc is 0.8611
# epoch 94 : acc 0.8624
# after looking at 128 images, running_loss is 0.3589
# after looking at 6528 images, running_loss is 0.2379
# after looking at 12928 images, running_loss is 0.2463
# after looking at 19328 images, running_loss is 0.2554
# after looking at 25728 images, running_loss is 0.2519
# after looking at 32128 images, running_loss is 0.2555
# epoch 95 : loss 0.2648
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8787
# after looking at 12928 images, running_acc is 0.8611
# epoch 95 : acc 0.8629
# after looking at 128 images, running_loss is 0.3538
# after looking at 6528 images, running_loss is 0.2651
# after looking at 12928 images, running_loss is 0.2668
# after looking at 19328 images, running_loss is 0.2755
# after looking at 25728 images, running_loss is 0.2760
# after looking at 32128 images, running_loss is 0.2785
# epoch 96 : loss 0.2731
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8805
# after looking at 12928 images, running_acc is 0.8629
# epoch 96 : acc 0.8624
# after looking at 128 images, running_loss is 0.2352
# after looking at 6528 images, running_loss is 0.2399
# after looking at 12928 images, running_loss is 0.2533
# after looking at 19328 images, running_loss is 0.2490
# after looking at 25728 images, running_loss is 0.2594
# after looking at 32128 images, running_loss is 0.2681
# epoch 97 : loss 0.2677
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8756
# after looking at 12928 images, running_acc is 0.8620
# epoch 97 : acc 0.8632
# after looking at 128 images, running_loss is 0.2362
# after looking at 6528 images, running_loss is 0.2858
# after looking at 12928 images, running_loss is 0.2689
# after looking at 19328 images, running_loss is 0.2618
# after looking at 25728 images, running_loss is 0.2637
# after looking at 32128 images, running_loss is 0.2648
# epoch 98 : loss 0.2627
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8781
# after looking at 12928 images, running_acc is 0.8629
# epoch 98 : acc 0.8637
# after looking at 128 images, running_loss is 0.3322
# after looking at 6528 images, running_loss is 0.2739
# after looking at 12928 images, running_loss is 0.2732
# after looking at 19328 images, running_loss is 0.2667
# after looking at 25728 images, running_loss is 0.2694
# after looking at 32128 images, running_loss is 0.2681
# epoch 99 : loss 0.2693
# after looking at 128 images, running_acc is 0.9062
# after looking at 6528 images, running_acc is 0.8787
# after looking at 12928 images, running_acc is 0.8648
# epoch 99 : acc 0.8637

# %%
val_acc_list
# Out:
# [0.11128048780487805,
#  0.17495402632597754,
#  0.18143873403019745,
#  0.2063371080139373,
#  0.23432055749128922,
#  0.2627637437088656,
#  0.27827380952380953,
#  0.2936386953155246,
#  0.3087616144018583,
#  0.3121854432830043,
#  0.35537650019357336,
#  0.34990805265195507,
#  0.38433991482771973,
#  0.4059233449477352,
#  0.4155536198219125,
#  0.42282471931862176,
#  0.43082171893147503,
#  0.4426417924893534,
#  0.45432878435927215,
#  0.47008081687959735,
#  0.48291715060007745,
#  0.5305482965543942,
#  0.510102109949671,
#  0.5436265969802555,
#  0.5593907278358498,
#  0.5606489547038328,
#  0.5859344754161828,
#  0.587604045683314,
#  0.6221568912117693,
#  0.6163012969415408,
#  0.6032108981804104,
#  0.6231731513743709,
#  0.698884533488192,
#  0.6829873209446381,
#  0.7221254355400697,
#  0.7073896631823461,
#  0.7195847851335656,
#  0.7034456058846302,
#  0.7564363143631436,
#  0.7278479481223383,
#  0.744229094076655,
#  0.7462737127371274,
#  0.7678571428571428,
#  0.7803305265195509,
#  0.7731804103755324,
#  0.7641792489353465,
#  0.7825929152148664,
#  0.7871781842818428,
#  0.7417005420054201,
#  0.783246225319396,
#  0.7808386566008517,
#  0.789198606271777,
#  0.8035714285714285,
#  0.8111812814556717,
#  0.7967116724738675,
#  0.7984780294231514,
#  0.7800885598141696,
#  0.7952961672473867,
#  0.8044546070460705,
#  0.7793021680216803,
#  0.8427095431668602,
#  0.8503314943863725,
#  0.8543965350367789,
#  0.8528721447928765,
#  0.8533802748741773,
#  0.8559209252806814,
#  0.8565500387146728,
#  0.855666860240031,
#  0.857312233836624,
#  0.8622725512969416,
#  0.8607481610530391,
#  0.8571912504839334,
#  0.8584615756871854,
#  0.8576993805652342,
#  0.8606150793650793,
#  0.8620184862562912,
#  0.8584615756871854,
#  0.8598528842431281,
#  0.8562959736740224,
#  0.8639179248935346,
#  0.8636638598528842,
#  0.8613772744870306,
#  0.8626475996902826,
#  0.8631557297715834,
#  0.8640389082462253,
#  0.8636638598528842,
#  0.8617523228803716,
#  0.8626475996902826,
#  0.8639179248935346,
#  0.8612441927990708,
#  0.8623935346496322,
#  0.8634097948122338,
#  0.8646801200154859,
#  0.862901664730933,
#  0.8623935346496322,
#  0.862901664730933,
#  0.8623814363143631,
#  0.8631557297715834,
#  0.8636638598528842,
#  0.8636638598528842]

# %%
torch.randn([128, 512, 2, 2])
# Out:
# tensor([[[[-0.3224,  0.6430],
#           [-2.1366, -0.7955]],
#
#          [[ 1.9297,  0.0319],
#           [-0.8145, -0.0638]],
#
#          [[-0.6602, -1.0492],
#           [-0.0070,  0.2472]],
#
#          ...,
#
#          [[ 0.1214, -0.1647],
#           [-0.1816,  1.3264]],
#
#          [[-0.5477, -0.8337],
#           [-0.0438, -0.6752]],
#
#          [[ 1.0233,  0.0337],
#           [ 0.6048, -0.6336]]],
#
#
#         [[[-0.1632,  0.0448],
#           [ 1.1389, -0.7049]],
#
#          [[-0.9089,  0.3058],
#           [ 0.6314, -0.4440]],
#
#          [[-0.0420, -0.2608],
#           [-2.4411,  0.9408]],
#
#          ...,
#
#          [[-0.8883, -1.6769],
#           [ 0.3247, -0.2730]],
#
#          [[-1.1972, -0.1980],
#           [-0.6327,  0.5523]],
#
#          [[-0.3727, -0.7699],
#           [ 0.2339,  0.2613]]],
#
#
#         [[[ 0.8213, -0.1002],
#           [-0.3785,  0.0206]],
#
#          [[ 0.5312, -1.1690],
#           [ 0.9211, -0.4588]],
#
#          [[-0.6275, -0.4326],
#           [ 0.4619, -0.4406]],
#
#          ...,
#
#          [[-1.0534, -0.8235],
#           [-0.4830, -0.5612]],
#
#          [[ 1.1650, -0.5173],
#           [-0.4580,  0.9482]],
#
#          [[ 0.8473,  0.2763],
#           [ 1.1253, -0.5122]]],
#
#
#         ...,
#
#
#         [[[-1.1377,  1.2120],
#           [-0.3167, -0.1726]],
#
#          [[ 0.0425, -0.1990],
#           [-0.1019, -1.1769]],
#
#          [[-0.3781, -3.3722],
#           [-0.1976, -0.5540]],
#
#          ...,
#
#          [[-1.3382,  0.2191],
#           [ 0.1499,  1.0544]],
#
#          [[ 0.0311,  0.3018],
#           [ 0.7474,  0.9730]],
#
#          [[ 0.1725, -0.3210],
#           [ 0.0816,  1.0190]]],
#
#
#         [[[ 1.5119,  0.1110],
#           [ 1.5913, -0.4125]],
#
#          [[ 1.6268,  0.4650],
#           [-0.4008, -0.2547]],
#
#          [[-1.5135, -0.8488],
#           [ 0.6612,  0.4883]],
#
#          ...,
#
#          [[-0.2647, -1.8118],
#           [-0.3228,  0.1763]],
#
#          [[ 1.0803, -0.1211],
#           [ 0.4473,  0.2035]],
#
#          [[ 0.9399, -0.3193],
#           [-1.3896, -1.8142]]],
#
#
#         [[[-0.0978, -0.4597],
#           [ 0.2275, -0.1628]],
#
#          [[-0.3103, -0.0226],
#           [ 1.0683, -0.5936]],
#
#          [[-0.4030,  1.6632],
#           [ 1.1033, -0.1230]],
#
#          ...,
#
#          [[ 0.6912,  0.3246],
#           [ 1.5102,  0.0271]],
#
#          [[-0.4113,  0.6684],
#           [-1.6351, -0.4456]],
#
#          [[-2.8530, -0.4624],
#           [-1.7163,  1.8250]]]])

# %%
torch.cat(cat, dim=0).shape

# %%
torch.cat((t4d, t4d), dim=0)

# %%
F.pad(t4d, (1,1,1,1,4,4))

# %%
F.avg_pool2d(torch.randn([128, 512, 2, 2]), 2)

# %%
6
