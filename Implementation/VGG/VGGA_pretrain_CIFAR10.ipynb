# %%
from google.colab import drive
drive.mount('/content/gdrive')

MODELPATH = '/content/gdrive/My Drive/Colab Notebooks/yai7_CV1/modelsave/'
# Out:
# Mounted at /content/gdrive

# %%
# going to use imagewoof dataset for training VGG net D 16

# brief note on VGG 16 architecture :

# seems like there is no batch normalisation
# all hidden layers "equipped" with ReLU
# dropout on first two layers of fully connected layers (p=0.5)
# L2 regularizer
# mini-batch gradient descent with momentum (batchsize=256) (based on LeNet)
# initial learning rate 10^-2
# learning rate decreased fater of 10 when val acc stop improving (ReduceLRonPlateau?)
# 370K iterations = 74 epochs
# augmentations : randomcrop, horizontalflip, randomrgbcolorshift
# shallow train net A first and then do transfer learning?
# random initialization with zero mean 10-^2 variance

##################################
# net A arch:   ## net D arch:   #
#               ##               #
# input 224x224 ## input 224x224 #
#               ##               #
# conv3-64      ## conv3-64      #
#               ## conv3-64      #
# maxpool       ## maxpool       #
#               ##               #
# conv3-128     ## conv3-128     #
#               ## conv3-128     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-256     ## conv3-256     #
# conv3-256     ## conv3-256     #
#               ## conv3-256     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-512     ## conv3-512     #
# conv3-512     ## conv3-512     #
#               ## conv3-512     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-512     ## conv3-512     #
# conv3-512     ## conv3-512     #
#               ## conv3-512     #
# maxpool       ## maxpool       #
#               ##               #
# dropout       ## dropout       #
# fc-4096       ## fc-4096       #
# dropout       ## dropout       #
# fc-4096       ## fc-4096       #
# fc-1000       ## fc-1000       #
# softmax       ## softmax       #
##################################

# %%
import torch

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

# %%
torch.__version__
# Out:
# '1.7.0+cu101'

# %%
import torchvision
import torchvision.transforms as transforms

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("check device:", torch.cuda.get_device_name())
print("how many?:", torch.cuda.device_count())
print("so can i use it?", torch.cuda.is_available())
# Out:
# check device: Tesla P4
# how many?: 1
# so can i use it? True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# before loading data,
# need to determine transformation (augmentation)

# %%
# no augmentation yet

"""train_transform = A.Compose([
                             ToTensor()
])

test_transform = A.Compose([
                            ToTensor()
])"""
# Out:
# 'train_transform = A.Compose([\n                             ToTensor()\n])\n\ntest_transform = A.Compose([\n                            ToTensor()\n])'

# %%
train_transform = transforms.Compose([
                             transforms.ToTensor()
])
train_set = torchvision.datasets.CIFAR10(root='/data', train=True, download=True, 
                                         transform=train_transform)
# Out:
# Files already downloaded and verified

# %%
# page 2
# "The only preprocessing we do is subtracting the mean RGB value, 
# computed on the training set, from each pixel."

mean = 0.0
for image, _ in train_set:
    mean += image.mean([1,2])

mean = mean/len(train_set)
print(mean)

del train_set, train_transform
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %%
# using torchvision transformation
# augmentations : randomcrop, horizontalflip, randomrgbcolorshift
# image for CIFAR10 is too small for randomcrop... so add padding
# googled std :P

train_transform = transforms.Compose([
                             transforms.RandomCrop(32, padding=4),
                             transforms.RandomHorizontalFlip(p=0.5),
                             transforms.ToTensor(),
                             transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))
])

test_transform = transforms.Compose([
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))
])

# %%
train_set = torchvision.datasets.CIFAR10(root='/data', train=True, download=True, 
                                         transform=train_transform)

test_set = torchvision.datasets.CIFAR10(root='/data', train=False, download=True, 
                                         transform=test_transform)

# how to retrieve image without using DataLoader?
# just by indexing is good enough
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# checking on the loaded data :0
train_set
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
test_set
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: /data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# from dataset to loader

train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False, num_workers=4)

# seems like num_workers works best when...
# num_workers = num GPU * 4

# %%
# check on the images

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# used for checking if image came out with batchsize=1

"""for image, label in train_loader:
    print(image)
    print(image.dtype)
    print(label)
    print(label.dtype)
    print(image.squeeze_().shape)
    imshow(image)
    break"""
# Out:
# 'for image, label in train_loader:\n    print(image)\n    print(image.dtype)\n    print(label)\n    print(label.dtype)\n    print(image.squeeze_().shape)\n    imshow(image)\n    break'

# %%
# construct architecture for VGG-D
# but will use this for VGG-A :)

class VGGa(nn.Module):
    def __init__(self):
        super(VGGa, self).__init__()

        self.conv1a = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv1d = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2a = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2d = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv3a = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU())
        
        self.conv3d = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        self.conv4a = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
            )
        self.conv4d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv5a = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv5d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        # 32 --> 16 --> 8 --> 4 --> 2 --> 1
        # 512 * 1 * 1 = 512
        self.fcd = nn.Linear(512, 10)

        self.fca = nn.Linear(512, 10)

        self.dropout = nn.Dropout(p=0.5)

        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.softmax = nn.Softmax(dim=0)

    def forward(self, x):
        x = self.conv1a(x)
        x = self.maxpool(x)
        x = self.conv2a(x)
        x = self.maxpool(x)
        x = self.conv3a(x)
        x = self.maxpool(x)
        x = self.conv4a(x)
        x = self.maxpool(x)
        x= self.conv5a(x)
        x = self.maxpool(x)
        #print('before view', x.shape)

        # 224 --> 112 --> 56 --> 28 --> 14 --> 7 
        # 512 * 7 * 7 = 25088
        x = x.view(-1, 512)
        #print('after view', x.shape)
        x = self.dropout(x)
        x = self.fca(x) 
        #x = self.softmax(x)
        return x

# %%
vgga = VGGa()
vgga.to(device)
# Out:
# VGGa(
#   (conv1a): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv1d): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2a): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2d): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv3a): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv3d): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv4a): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv4d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5a): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv5d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (fcd): Linear(in_features=512, out_features=10, bias=True)
#   (fca): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (softmax): Softmax(dim=0)
# )

# %%
# as in the paper,
# init weights with normal distribution
# init biases with zeros

# init all weights and biases

# next time try making this inside the module

def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.normal_(child.weight, mean=0.0, std=0.01)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.normal_(grandchild.weight, mean=0.0, std=0.01)
                    torch.nn.init.zeros_(grandchild.bias)

# %%
# try xavier just for fun~
"""
def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.xavier_normal_(child.weight)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.xavier_normal_(grandchild.weight)
                    torch.nn.init.zeros_(grandchild.bias)"""
# Out:
# '\ndef init_weights(m):\n\n    for i, child in enumerate(m.children()):\n        if type(child) is (nn.Linear or nn.Conv2d):\n            torch.nn.init.xavier_normal_(child.weight)\n            torch.nn.init.zeros_(child.bias)\n        elif type(child) == nn.Sequential:\n            for j, grandchild in enumerate(child.children()):\n                #print(j, grandchild)\n                if type(child) is (nn.Linear or nn.Conv2d):\n                    torch.nn.init.xavier_normal_(grandchild.weight)\n                    torch.nn.init.zeros_(grandchild.bias)'

# %%
init_weights(vgga)

# %%
# just for checking if initialized correctly

"""for i, child in enumerate(vgga.children()):
    if type(child) == nn.Sequential:
        for j, grandchild in enumerate(child.children()):
            if type(child) is (nn.Linear or nn.Conv2d):
                print(i, j, grandchild)
                print(grandchild.weight)
                print(grandchild.bias)

    else:
        if type(child) is (nn.Linear or nn.Conv2d):
            print(i, child)
            print(child.weight)
            print(child.bias)"""

# seems to work :)
# Out:
# 'for i, child in enumerate(vgga.children()):\n    if type(child) == nn.Sequential:\n        for j, grandchild in enumerate(child.children()):\n            if type(child) is (nn.Linear or nn.Conv2d):\n                print(i, j, grandchild)\n                print(grandchild.weight)\n                print(grandchild.bias)\n\n    else:\n        if type(child) is (nn.Linear or nn.Conv2d):\n            print(i, child)\n            print(child.weight)\n            print(child.bias)'

# %%
def train_one_epoch(model, train_loader, loss_function, optimizer, epoch):
    #model.train()
    length = len(train_loader)
    #pbar = tqdm(enumerate(train_loader), total=length)
    running_loss = 0.0

    for i, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        pred = model(image)
        #print('pred')
        #print(pred.shape)
        #print('label')
        #print(label.shape)
        loss = loss_function(pred, label)
        #print(loss)
        #print(loss.item())
    
        loss.backward()
        
        optimizer.step()

        running_loss += loss.item()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_loss is {running_loss/(i+1):.4f}')
        #pbar.set_description(f'running_loss {running_loss/(i+1):.4f}')

    print(f'epoch {epoch} : loss {running_loss/length:.4f}')


def eval_one_epoch(model, test_loader, scheduler, epoch, best_val_acc):
    #model.eval()
    length = len(test_loader)
    #pbar = tqdm(enumerate(test_loader), total=length)
    running_acc = 0.0

    for i, (image, label) in enumerate(test_loader):
        image, label = image.to(device), label.numpy()

        pred = model(image)
        pred_label = pred.argmax(axis=1).detach().cpu().numpy()
        running_acc += (pred_label==label).mean()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_acc is {running_acc/(i+1):.4f}')
        #pbar.set_description(f'running_acc {running_acc/(i+1):.4f}')

    val_acc = running_acc/length
    scheduler.step(val_acc)

    print(f'epoch {epoch} : acc {val_acc:.4f}')
    
    if val_acc > best_val_acc:
        print("### saving current model...### \n")
        torch.save(model.state_dict(), MODELPATH+f'pretrained_{epoch}_epochs')
        best_val_acc = val_acc

    return best_val_acc

# %%
# hyperparameters from paper
# assuming same for pretraining

learning_rate = 0.01
momentum = 0.9
weight_decay = 5e-4
epochs = 20

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(vgga.parameters(), lr=learning_rate, 
                            momentum=momentum, weight_decay=weight_decay)

# patience=5 chosen arbitrarily
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.1, patience=5, verbose=True
    )

# %%
best_val_acc = 0.0

for epoch in range(epochs):
    vgga.train()
    train_one_epoch(vgga, train_loader, loss_function, optimizer, epoch)
    vgga.eval()
    best_val_acc = eval_one_epoch(vgga, test_loader, scheduler, epoch, best_val_acc)
# Out:
# after looking at 32 images, running_loss is 2.3022
# after looking at 1632 images, running_loss is 2.3033
# after looking at 3232 images, running_loss is 2.3028
# after looking at 4832 images, running_loss is 2.3033
# after looking at 6432 images, running_loss is 2.3033
# after looking at 8032 images, running_loss is 2.3033
# after looking at 9632 images, running_loss is 2.3032
# after looking at 11232 images, running_loss is 2.3030
# after looking at 12832 images, running_loss is 2.3031
# after looking at 14432 images, running_loss is 2.3032
# after looking at 16032 images, running_loss is 2.3032
# after looking at 17632 images, running_loss is 2.3031
# after looking at 19232 images, running_loss is 2.3032
# after looking at 20832 images, running_loss is 2.3031
# after looking at 22432 images, running_loss is 2.3030
# after looking at 24032 images, running_loss is 2.3030
# after looking at 25632 images, running_loss is 2.3028
# after looking at 27232 images, running_loss is 2.3014
# after looking at 28832 images, running_loss is 2.2980
# after looking at 30432 images, running_loss is 2.2924
# after looking at 32032 images, running_loss is 2.2858
# after looking at 33632 images, running_loss is 2.2774
# after looking at 35232 images, running_loss is 2.2701
# after looking at 36832 images, running_loss is 2.2621
# after looking at 38432 images, running_loss is 2.2542
# after looking at 40032 images, running_loss is 2.2453
# after looking at 41632 images, running_loss is 2.2354
# after looking at 43232 images, running_loss is 2.2272
# after looking at 44832 images, running_loss is 2.2185
# after looking at 46432 images, running_loss is 2.2112
# after looking at 48032 images, running_loss is 2.2036
# after looking at 49632 images, running_loss is 2.1941
# epoch 0 : loss 2.1921
# after looking at 32 images, running_acc is 0.3438
# after looking at 1632 images, running_acc is 0.2610
# after looking at 3232 images, running_acc is 0.2645
# after looking at 4832 images, running_acc is 0.2577
# after looking at 6432 images, running_acc is 0.2562
# after looking at 8032 images, running_acc is 0.2546
# after looking at 9632 images, running_acc is 0.2579
# epoch 0 : acc 0.2569
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.9800
# after looking at 1632 images, running_loss is 1.9325
# after looking at 3232 images, running_loss is 1.9302
# after looking at 4832 images, running_loss is 1.9208
# after looking at 6432 images, running_loss is 1.9186
# after looking at 8032 images, running_loss is 1.9089
# after looking at 9632 images, running_loss is 1.8932
# after looking at 11232 images, running_loss is 1.8804
# after looking at 12832 images, running_loss is 1.8811
# after looking at 14432 images, running_loss is 1.8718
# after looking at 16032 images, running_loss is 1.8592
# after looking at 17632 images, running_loss is 1.8463
# after looking at 19232 images, running_loss is 1.8416
# after looking at 20832 images, running_loss is 1.8343
# after looking at 22432 images, running_loss is 1.8258
# after looking at 24032 images, running_loss is 1.8167
# after looking at 25632 images, running_loss is 1.8114
# after looking at 27232 images, running_loss is 1.8033
# after looking at 28832 images, running_loss is 1.7987
# after looking at 30432 images, running_loss is 1.7934
# after looking at 32032 images, running_loss is 1.7851
# after looking at 33632 images, running_loss is 1.7796
# after looking at 35232 images, running_loss is 1.7736
# after looking at 36832 images, running_loss is 1.7680
# after looking at 38432 images, running_loss is 1.7592
# after looking at 40032 images, running_loss is 1.7548
# after looking at 41632 images, running_loss is 1.7492
# after looking at 43232 images, running_loss is 1.7432
# after looking at 44832 images, running_loss is 1.7371
# after looking at 46432 images, running_loss is 1.7324
# after looking at 48032 images, running_loss is 1.7270
# after looking at 49632 images, running_loss is 1.7215
# epoch 1 : loss 1.7201
# after looking at 32 images, running_acc is 0.3750
# after looking at 1632 images, running_acc is 0.4412
# after looking at 3232 images, running_acc is 0.4347
# after looking at 4832 images, running_acc is 0.4329
# after looking at 6432 images, running_acc is 0.4303
# after looking at 8032 images, running_acc is 0.4270
# after looking at 9632 images, running_acc is 0.4283
# epoch 1 : acc 0.4271
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.7986
# after looking at 1632 images, running_loss is 1.5371
# after looking at 3232 images, running_loss is 1.4875
# after looking at 4832 images, running_loss is 1.4796
# after looking at 6432 images, running_loss is 1.4760
# after looking at 8032 images, running_loss is 1.4796
# after looking at 9632 images, running_loss is 1.4893
# after looking at 11232 images, running_loss is 1.4821
# after looking at 12832 images, running_loss is 1.4765
# after looking at 14432 images, running_loss is 1.4680
# after looking at 16032 images, running_loss is 1.4681
# after looking at 17632 images, running_loss is 1.4651
# after looking at 19232 images, running_loss is 1.4591
# after looking at 20832 images, running_loss is 1.4543
# after looking at 22432 images, running_loss is 1.4505
# after looking at 24032 images, running_loss is 1.4418
# after looking at 25632 images, running_loss is 1.4364
# after looking at 27232 images, running_loss is 1.4314
# after looking at 28832 images, running_loss is 1.4239
# after looking at 30432 images, running_loss is 1.4191
# after looking at 32032 images, running_loss is 1.4152
# after looking at 33632 images, running_loss is 1.4109
# after looking at 35232 images, running_loss is 1.4062
# after looking at 36832 images, running_loss is 1.4008
# after looking at 38432 images, running_loss is 1.3954
# after looking at 40032 images, running_loss is 1.3907
# after looking at 41632 images, running_loss is 1.3852
# after looking at 43232 images, running_loss is 1.3802
# after looking at 44832 images, running_loss is 1.3733
# after looking at 46432 images, running_loss is 1.3713
# after looking at 48032 images, running_loss is 1.3675
# after looking at 49632 images, running_loss is 1.3627
# epoch 2 : loss 1.3615
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.5944
# after looking at 3232 images, running_acc is 0.6046
# after looking at 4832 images, running_acc is 0.6037
# after looking at 6432 images, running_acc is 0.5973
# after looking at 8032 images, running_acc is 0.5949
# after looking at 9632 images, running_acc is 0.5958
# epoch 2 : acc 0.5937
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.0166
# after looking at 1632 images, running_loss is 1.1345
# after looking at 3232 images, running_loss is 1.1717
# after looking at 4832 images, running_loss is 1.1812
# after looking at 6432 images, running_loss is 1.1766
# after looking at 8032 images, running_loss is 1.1702
# after looking at 9632 images, running_loss is 1.1632
# after looking at 11232 images, running_loss is 1.1672
# after looking at 12832 images, running_loss is 1.1664
# after looking at 14432 images, running_loss is 1.1687
# after looking at 16032 images, running_loss is 1.1704
# after looking at 17632 images, running_loss is 1.1652
# after looking at 19232 images, running_loss is 1.1590
# after looking at 20832 images, running_loss is 1.1553
# after looking at 22432 images, running_loss is 1.1483
# after looking at 24032 images, running_loss is 1.1435
# after looking at 25632 images, running_loss is 1.1418
# after looking at 27232 images, running_loss is 1.1401
# after looking at 28832 images, running_loss is 1.1392
# after looking at 30432 images, running_loss is 1.1337
# after looking at 32032 images, running_loss is 1.1318
# after looking at 33632 images, running_loss is 1.1300
# after looking at 35232 images, running_loss is 1.1269
# after looking at 36832 images, running_loss is 1.1246
# after looking at 38432 images, running_loss is 1.1211
# after looking at 40032 images, running_loss is 1.1184
# after looking at 41632 images, running_loss is 1.1169
# after looking at 43232 images, running_loss is 1.1140
# after looking at 44832 images, running_loss is 1.1109
# after looking at 46432 images, running_loss is 1.1065
# after looking at 48032 images, running_loss is 1.1046
# after looking at 49632 images, running_loss is 1.1025
# epoch 3 : loss 1.1013
# after looking at 32 images, running_acc is 0.7812
# after looking at 1632 images, running_acc is 0.6685
# after looking at 3232 images, running_acc is 0.6621
# after looking at 4832 images, running_acc is 0.6654
# after looking at 6432 images, running_acc is 0.6614
# after looking at 8032 images, running_acc is 0.6640
# after looking at 9632 images, running_acc is 0.6640
# epoch 3 : acc 0.6633
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.8219
# after looking at 1632 images, running_loss is 0.9501
# after looking at 3232 images, running_loss is 0.9691
# after looking at 4832 images, running_loss is 0.9667
# after looking at 6432 images, running_loss is 0.9668
# after looking at 8032 images, running_loss is 0.9718
# after looking at 9632 images, running_loss is 0.9688
# after looking at 11232 images, running_loss is 0.9740
# after looking at 12832 images, running_loss is 0.9634
# after looking at 14432 images, running_loss is 0.9617
# after looking at 16032 images, running_loss is 0.9640
# after looking at 17632 images, running_loss is 0.9664
# after looking at 19232 images, running_loss is 0.9632
# after looking at 20832 images, running_loss is 0.9626
# after looking at 22432 images, running_loss is 0.9589
# after looking at 24032 images, running_loss is 0.9577
# after looking at 25632 images, running_loss is 0.9530
# after looking at 27232 images, running_loss is 0.9484
# after looking at 28832 images, running_loss is 0.9469
# after looking at 30432 images, running_loss is 0.9445
# after looking at 32032 images, running_loss is 0.9442
# after looking at 33632 images, running_loss is 0.9437
# after looking at 35232 images, running_loss is 0.9437
# after looking at 36832 images, running_loss is 0.9427
# after looking at 38432 images, running_loss is 0.9412
# after looking at 40032 images, running_loss is 0.9408
# after looking at 41632 images, running_loss is 0.9387
# after looking at 43232 images, running_loss is 0.9387
# after looking at 44832 images, running_loss is 0.9380
# after looking at 46432 images, running_loss is 0.9369
# after looking at 48032 images, running_loss is 0.9352
# after looking at 49632 images, running_loss is 0.9329
# epoch 4 : loss 0.9324
# after looking at 32 images, running_acc is 0.8125
# after looking at 1632 images, running_acc is 0.7243
# after looking at 3232 images, running_acc is 0.7188
# after looking at 4832 images, running_acc is 0.7227
# after looking at 6432 images, running_acc is 0.7209
# after looking at 8032 images, running_acc is 0.7217
# after looking at 9632 images, running_acc is 0.7209
# epoch 4 : acc 0.7194
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.9089
# after looking at 1632 images, running_loss is 0.8781
# after looking at 3232 images, running_loss is 0.8572
# after looking at 4832 images, running_loss is 0.8621
# after looking at 6432 images, running_loss is 0.8529
# after looking at 8032 images, running_loss is 0.8580
# after looking at 9632 images, running_loss is 0.8530
# after looking at 11232 images, running_loss is 0.8453
# after looking at 12832 images, running_loss is 0.8461
# after looking at 14432 images, running_loss is 0.8414
# after looking at 16032 images, running_loss is 0.8435
# after looking at 17632 images, running_loss is 0.8472
# after looking at 19232 images, running_loss is 0.8501
# after looking at 20832 images, running_loss is 0.8500
# after looking at 22432 images, running_loss is 0.8453
# after looking at 24032 images, running_loss is 0.8415
# after looking at 25632 images, running_loss is 0.8415
# after looking at 27232 images, running_loss is 0.8426
# after looking at 28832 images, running_loss is 0.8398
# after looking at 30432 images, running_loss is 0.8398
# after looking at 32032 images, running_loss is 0.8373
# after looking at 33632 images, running_loss is 0.8360
# after looking at 35232 images, running_loss is 0.8338
# after looking at 36832 images, running_loss is 0.8339
# after looking at 38432 images, running_loss is 0.8328
# after looking at 40032 images, running_loss is 0.8314
# after looking at 41632 images, running_loss is 0.8302
# after looking at 43232 images, running_loss is 0.8284
# after looking at 44832 images, running_loss is 0.8283
# after looking at 46432 images, running_loss is 0.8271
# after looking at 48032 images, running_loss is 0.8294
# after looking at 49632 images, running_loss is 0.8270
# epoch 5 : loss 0.8266
# after looking at 32 images, running_acc is 0.8125
# after looking at 1632 images, running_acc is 0.7549
# after looking at 3232 images, running_acc is 0.7444
# after looking at 4832 images, running_acc is 0.7508
# after looking at 6432 images, running_acc is 0.7537
# after looking at 8032 images, running_acc is 0.7571
# after looking at 9632 images, running_acc is 0.7548
# epoch 5 : acc 0.7535
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.3772
# after looking at 1632 images, running_loss is 0.7222
# after looking at 3232 images, running_loss is 0.7448
# after looking at 4832 images, running_loss is 0.7534
# after looking at 6432 images, running_loss is 0.7464
# after looking at 8032 images, running_loss is 0.7488
# after looking at 9632 images, running_loss is 0.7439
# after looking at 11232 images, running_loss is 0.7445
# after looking at 12832 images, running_loss is 0.7488
# after looking at 14432 images, running_loss is 0.7502
# after looking at 16032 images, running_loss is 0.7490
# after looking at 17632 images, running_loss is 0.7487
# after looking at 19232 images, running_loss is 0.7506
# after looking at 20832 images, running_loss is 0.7489
# after looking at 22432 images, running_loss is 0.7513
# after looking at 24032 images, running_loss is 0.7544
# after looking at 25632 images, running_loss is 0.7546
# after looking at 27232 images, running_loss is 0.7507
# after looking at 28832 images, running_loss is 0.7486
# after looking at 30432 images, running_loss is 0.7492
# after looking at 32032 images, running_loss is 0.7482
# after looking at 33632 images, running_loss is 0.7450
# after looking at 35232 images, running_loss is 0.7430
# after looking at 36832 images, running_loss is 0.7417
# after looking at 38432 images, running_loss is 0.7391
# after looking at 40032 images, running_loss is 0.7379
# after looking at 41632 images, running_loss is 0.7372
# after looking at 43232 images, running_loss is 0.7375
# after looking at 44832 images, running_loss is 0.7410
# after looking at 46432 images, running_loss is 0.7405
# after looking at 48032 images, running_loss is 0.7397
# after looking at 49632 images, running_loss is 0.7383
# epoch 6 : loss 0.7380
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.7684
# after looking at 3232 images, running_acc is 0.7723
# after looking at 4832 images, running_acc is 0.7750
# after looking at 6432 images, running_acc is 0.7719
# after looking at 8032 images, running_acc is 0.7729
# after looking at 9632 images, running_acc is 0.7737
# epoch 6 : acc 0.7732
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.6587
# after looking at 1632 images, running_loss is 0.6819
# after looking at 3232 images, running_loss is 0.6855
# after looking at 4832 images, running_loss is 0.6887
# after looking at 6432 images, running_loss is 0.6857
# after looking at 8032 images, running_loss is 0.6927
# after looking at 9632 images, running_loss is 0.6952
# after looking at 11232 images, running_loss is 0.6911
# after looking at 12832 images, running_loss is 0.6944
# after looking at 14432 images, running_loss is 0.6927
# after looking at 16032 images, running_loss is 0.6957
# after looking at 17632 images, running_loss is 0.6934
# after looking at 19232 images, running_loss is 0.6931
# after looking at 20832 images, running_loss is 0.6936
# after looking at 22432 images, running_loss is 0.6903
# after looking at 24032 images, running_loss is 0.6910
# after looking at 25632 images, running_loss is 0.6860
# after looking at 27232 images, running_loss is 0.6847
# after looking at 28832 images, running_loss is 0.6848
# after looking at 30432 images, running_loss is 0.6847
# after looking at 32032 images, running_loss is 0.6857
# after looking at 33632 images, running_loss is 0.6855
# after looking at 35232 images, running_loss is 0.6847
# after looking at 36832 images, running_loss is 0.6815
# after looking at 38432 images, running_loss is 0.6798
# after looking at 40032 images, running_loss is 0.6789
# after looking at 41632 images, running_loss is 0.6803
# after looking at 43232 images, running_loss is 0.6802
# after looking at 44832 images, running_loss is 0.6808
# after looking at 46432 images, running_loss is 0.6797
# after looking at 48032 images, running_loss is 0.6790
# after looking at 49632 images, running_loss is 0.6796
# epoch 7 : loss 0.6796
# after looking at 32 images, running_acc is 0.7812
# after looking at 1632 images, running_acc is 0.7574
# after looking at 3232 images, running_acc is 0.7534
# after looking at 4832 images, running_acc is 0.7575
# after looking at 6432 images, running_acc is 0.7558
# after looking at 8032 images, running_acc is 0.7577
# after looking at 9632 images, running_acc is 0.7610
# epoch 7 : acc 0.7609
# after looking at 32 images, running_loss is 1.0504
# after looking at 1632 images, running_loss is 0.6264
# after looking at 3232 images, running_loss is 0.6364
# after looking at 4832 images, running_loss is 0.6306
# after looking at 6432 images, running_loss is 0.6361
# after looking at 8032 images, running_loss is 0.6316
# after looking at 9632 images, running_loss is 0.6304
# after looking at 11232 images, running_loss is 0.6324
# after looking at 12832 images, running_loss is 0.6270
# after looking at 14432 images, running_loss is 0.6269
# after looking at 16032 images, running_loss is 0.6327
# after looking at 17632 images, running_loss is 0.6349
# after looking at 19232 images, running_loss is 0.6372
# after looking at 20832 images, running_loss is 0.6386
# after looking at 22432 images, running_loss is 0.6388
# after looking at 24032 images, running_loss is 0.6366
# after looking at 25632 images, running_loss is 0.6354
# after looking at 27232 images, running_loss is 0.6329
# after looking at 28832 images, running_loss is 0.6316
# after looking at 30432 images, running_loss is 0.6305
# after looking at 32032 images, running_loss is 0.6310
# after looking at 33632 images, running_loss is 0.6298
# after looking at 35232 images, running_loss is 0.6297
# after looking at 36832 images, running_loss is 0.6305
# after looking at 38432 images, running_loss is 0.6295
# after looking at 40032 images, running_loss is 0.6292
# after looking at 41632 images, running_loss is 0.6301
# after looking at 43232 images, running_loss is 0.6304
# after looking at 44832 images, running_loss is 0.6304
# after looking at 46432 images, running_loss is 0.6296
# after looking at 48032 images, running_loss is 0.6298
# after looking at 49632 images, running_loss is 0.6302
# epoch 8 : loss 0.6298
# after looking at 32 images, running_acc is 0.8125
# after looking at 1632 images, running_acc is 0.7757
# after looking at 3232 images, running_acc is 0.7738
# after looking at 4832 images, running_acc is 0.7779
# after looking at 6432 images, running_acc is 0.7763
# after looking at 8032 images, running_acc is 0.7763
# after looking at 9632 images, running_acc is 0.7776
# epoch 8 : acc 0.7767
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.8248
# after looking at 1632 images, running_loss is 0.5871
# after looking at 3232 images, running_loss is 0.5980
# after looking at 4832 images, running_loss is 0.5844
# after looking at 6432 images, running_loss is 0.5766
# after looking at 8032 images, running_loss is 0.5799
# after looking at 9632 images, running_loss is 0.5790
# after looking at 11232 images, running_loss is 0.5817
# after looking at 12832 images, running_loss is 0.5845
# after looking at 14432 images, running_loss is 0.5778
# after looking at 16032 images, running_loss is 0.5785
# after looking at 17632 images, running_loss is 0.5805
# after looking at 19232 images, running_loss is 0.5852
# after looking at 20832 images, running_loss is 0.5867
# after looking at 22432 images, running_loss is 0.5881
# after looking at 24032 images, running_loss is 0.5866
# after looking at 25632 images, running_loss is 0.5873
# after looking at 27232 images, running_loss is 0.5871
# after looking at 28832 images, running_loss is 0.5882
# after looking at 30432 images, running_loss is 0.5912
# after looking at 32032 images, running_loss is 0.5940
# after looking at 33632 images, running_loss is 0.5922
# after looking at 35232 images, running_loss is 0.5915
# after looking at 36832 images, running_loss is 0.5905
# after looking at 38432 images, running_loss is 0.5923
# after looking at 40032 images, running_loss is 0.5930
# after looking at 41632 images, running_loss is 0.5938
# after looking at 43232 images, running_loss is 0.5924
# after looking at 44832 images, running_loss is 0.5919
# after looking at 46432 images, running_loss is 0.5932
# after looking at 48032 images, running_loss is 0.5930
# after looking at 49632 images, running_loss is 0.5920
# epoch 9 : loss 0.5923
# after looking at 32 images, running_acc is 0.8438
# after looking at 1632 images, running_acc is 0.8058
# after looking at 3232 images, running_acc is 0.8045
# after looking at 4832 images, running_acc is 0.8106
# after looking at 6432 images, running_acc is 0.8080
# after looking at 8032 images, running_acc is 0.8069
# after looking at 9632 images, running_acc is 0.8091
# epoch 9 : acc 0.8087
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5820
# after looking at 1632 images, running_loss is 0.5333
# after looking at 3232 images, running_loss is 0.5620
# after looking at 4832 images, running_loss is 0.5529
# after looking at 6432 images, running_loss is 0.5568
# after looking at 8032 images, running_loss is 0.5585
# after looking at 9632 images, running_loss is 0.5553
# after looking at 11232 images, running_loss is 0.5557
# after looking at 12832 images, running_loss is 0.5527
# after looking at 14432 images, running_loss is 0.5560
# after looking at 16032 images, running_loss is 0.5639
# after looking at 17632 images, running_loss is 0.5606
# after looking at 19232 images, running_loss is 0.5578
# after looking at 20832 images, running_loss is 0.5568
# after looking at 22432 images, running_loss is 0.5582
# after looking at 24032 images, running_loss is 0.5553
# after looking at 25632 images, running_loss is 0.5536
# after looking at 27232 images, running_loss is 0.5530
# after looking at 28832 images, running_loss is 0.5505
# after looking at 30432 images, running_loss is 0.5492
# after looking at 32032 images, running_loss is 0.5507
# after looking at 33632 images, running_loss is 0.5504
# after looking at 35232 images, running_loss is 0.5510
# after looking at 36832 images, running_loss is 0.5517
# after looking at 38432 images, running_loss is 0.5546
# after looking at 40032 images, running_loss is 0.5543
# after looking at 41632 images, running_loss is 0.5548
# after looking at 43232 images, running_loss is 0.5549
# after looking at 44832 images, running_loss is 0.5545
# after looking at 46432 images, running_loss is 0.5554
# after looking at 48032 images, running_loss is 0.5569
# after looking at 49632 images, running_loss is 0.5578
# epoch 10 : loss 0.5577
# after looking at 32 images, running_acc is 0.9062
# after looking at 1632 images, running_acc is 0.8113
# after looking at 3232 images, running_acc is 0.8094
# after looking at 4832 images, running_acc is 0.8129
# after looking at 6432 images, running_acc is 0.8127
# after looking at 8032 images, running_acc is 0.8108
# after looking at 9632 images, running_acc is 0.8113
# epoch 10 : acc 0.8101
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.2879
# after looking at 1632 images, running_loss is 0.4988
# after looking at 3232 images, running_loss is 0.4915
# after looking at 4832 images, running_loss is 0.4860
# after looking at 6432 images, running_loss is 0.5023
# after looking at 8032 images, running_loss is 0.5101
# after looking at 9632 images, running_loss is 0.5126
# after looking at 11232 images, running_loss is 0.5177
# after looking at 12832 images, running_loss is 0.5144
# after looking at 14432 images, running_loss is 0.5137
# after looking at 16032 images, running_loss is 0.5159
# after looking at 17632 images, running_loss is 0.5210
# after looking at 19232 images, running_loss is 0.5243
# after looking at 20832 images, running_loss is 0.5225
# after looking at 22432 images, running_loss is 0.5215
# after looking at 24032 images, running_loss is 0.5203
# after looking at 25632 images, running_loss is 0.5233
# after looking at 27232 images, running_loss is 0.5261
# after looking at 28832 images, running_loss is 0.5262
# after looking at 30432 images, running_loss is 0.5247
# after looking at 32032 images, running_loss is 0.5254
# after looking at 33632 images, running_loss is 0.5253
# after looking at 35232 images, running_loss is 0.5270
# after looking at 36832 images, running_loss is 0.5277
# after looking at 38432 images, running_loss is 0.5259
# after looking at 40032 images, running_loss is 0.5273
# after looking at 41632 images, running_loss is 0.5268
# after looking at 43232 images, running_loss is 0.5261
# after looking at 44832 images, running_loss is 0.5258
# after looking at 46432 images, running_loss is 0.5254
# after looking at 48032 images, running_loss is 0.5257
# after looking at 49632 images, running_loss is 0.5264
# epoch 11 : loss 0.5271
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8235
# after looking at 3232 images, running_acc is 0.8171
# after looking at 4832 images, running_acc is 0.8173
# after looking at 6432 images, running_acc is 0.8181
# after looking at 8032 images, running_acc is 0.8177
# after looking at 9632 images, running_acc is 0.8199
# epoch 11 : acc 0.8201
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.4185
# after looking at 1632 images, running_loss is 0.4823
# after looking at 3232 images, running_loss is 0.5017
# after looking at 4832 images, running_loss is 0.4867
# after looking at 6432 images, running_loss is 0.4901
# after looking at 8032 images, running_loss is 0.4947
# after looking at 9632 images, running_loss is 0.4919
# after looking at 11232 images, running_loss is 0.4955
# after looking at 12832 images, running_loss is 0.4926
# after looking at 14432 images, running_loss is 0.4938
# after looking at 16032 images, running_loss is 0.4920
# after looking at 17632 images, running_loss is 0.4954
# after looking at 19232 images, running_loss is 0.4950
# after looking at 20832 images, running_loss is 0.4988
# after looking at 22432 images, running_loss is 0.4987
# after looking at 24032 images, running_loss is 0.5028
# after looking at 25632 images, running_loss is 0.5040
# after looking at 27232 images, running_loss is 0.5071
# after looking at 28832 images, running_loss is 0.5061
# after looking at 30432 images, running_loss is 0.5075
# after looking at 32032 images, running_loss is 0.5080
# after looking at 33632 images, running_loss is 0.5068
# after looking at 35232 images, running_loss is 0.5081
# after looking at 36832 images, running_loss is 0.5072
# after looking at 38432 images, running_loss is 0.5061
# after looking at 40032 images, running_loss is 0.5050
# after looking at 41632 images, running_loss is 0.5050
# after looking at 43232 images, running_loss is 0.5037
# after looking at 44832 images, running_loss is 0.5050
# after looking at 46432 images, running_loss is 0.5041
# after looking at 48032 images, running_loss is 0.5046
# after looking at 49632 images, running_loss is 0.5042
# epoch 12 : loss 0.5038
# after looking at 32 images, running_acc is 0.8438
# after looking at 1632 images, running_acc is 0.8223
# after looking at 3232 images, running_acc is 0.8190
# after looking at 4832 images, running_acc is 0.8222
# after looking at 6432 images, running_acc is 0.8221
# after looking at 8032 images, running_acc is 0.8252
# after looking at 9632 images, running_acc is 0.8264
# epoch 12 : acc 0.8265
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.3375
# after looking at 1632 images, running_loss is 0.4787
# after looking at 3232 images, running_loss is 0.4866
# after looking at 4832 images, running_loss is 0.4808
# after looking at 6432 images, running_loss is 0.4750
# after looking at 8032 images, running_loss is 0.4821
# after looking at 9632 images, running_loss is 0.4883
# after looking at 11232 images, running_loss is 0.4888
# after looking at 12832 images, running_loss is 0.4868
# after looking at 14432 images, running_loss is 0.4880
# after looking at 16032 images, running_loss is 0.4895
# after looking at 17632 images, running_loss is 0.4866
# after looking at 19232 images, running_loss is 0.4840
# after looking at 20832 images, running_loss is 0.4869
# after looking at 22432 images, running_loss is 0.4886
# after looking at 24032 images, running_loss is 0.4854
# after looking at 25632 images, running_loss is 0.4870
# after looking at 27232 images, running_loss is 0.4878
# after looking at 28832 images, running_loss is 0.4885
# after looking at 30432 images, running_loss is 0.4883
# after looking at 32032 images, running_loss is 0.4879
# after looking at 33632 images, running_loss is 0.4881
# after looking at 35232 images, running_loss is 0.4882
# after looking at 36832 images, running_loss is 0.4881
# after looking at 38432 images, running_loss is 0.4879
# after looking at 40032 images, running_loss is 0.4878
# after looking at 41632 images, running_loss is 0.4855
# after looking at 43232 images, running_loss is 0.4851
# after looking at 44832 images, running_loss is 0.4860
# after looking at 46432 images, running_loss is 0.4852
# after looking at 48032 images, running_loss is 0.4860
# after looking at 49632 images, running_loss is 0.4868
# epoch 13 : loss 0.4866
# after looking at 32 images, running_acc is 0.9375
# after looking at 1632 images, running_acc is 0.8162
# after looking at 3232 images, running_acc is 0.8110
# after looking at 4832 images, running_acc is 0.8144
# after looking at 6432 images, running_acc is 0.8147
# after looking at 8032 images, running_acc is 0.8155
# after looking at 9632 images, running_acc is 0.8163
# epoch 13 : acc 0.8160
# after looking at 32 images, running_loss is 0.4868
# after looking at 1632 images, running_loss is 0.4601
# after looking at 3232 images, running_loss is 0.4620
# after looking at 4832 images, running_loss is 0.4686
# after looking at 6432 images, running_loss is 0.4655
# after looking at 8032 images, running_loss is 0.4717
# after looking at 9632 images, running_loss is 0.4687
# after looking at 11232 images, running_loss is 0.4653
# after looking at 12832 images, running_loss is 0.4703
# after looking at 14432 images, running_loss is 0.4672
# after looking at 16032 images, running_loss is 0.4705
# after looking at 17632 images, running_loss is 0.4688
# after looking at 19232 images, running_loss is 0.4670
# after looking at 20832 images, running_loss is 0.4654
# after looking at 22432 images, running_loss is 0.4642
# after looking at 24032 images, running_loss is 0.4626
# after looking at 25632 images, running_loss is 0.4642
# after looking at 27232 images, running_loss is 0.4644
# after looking at 28832 images, running_loss is 0.4684
# after looking at 30432 images, running_loss is 0.4674
# after looking at 32032 images, running_loss is 0.4678
# after looking at 33632 images, running_loss is 0.4678
# after looking at 35232 images, running_loss is 0.4689
# after looking at 36832 images, running_loss is 0.4705
# after looking at 38432 images, running_loss is 0.4724
# after looking at 40032 images, running_loss is 0.4710
# after looking at 41632 images, running_loss is 0.4718
# after looking at 43232 images, running_loss is 0.4728
# after looking at 44832 images, running_loss is 0.4699
# after looking at 46432 images, running_loss is 0.4710
# after looking at 48032 images, running_loss is 0.4703
# after looking at 49632 images, running_loss is 0.4701
# epoch 14 : loss 0.4704
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8168
# after looking at 3232 images, running_acc is 0.8175
# after looking at 4832 images, running_acc is 0.8197
# after looking at 6432 images, running_acc is 0.8189
# after looking at 8032 images, running_acc is 0.8172
# after looking at 9632 images, running_acc is 0.8189
# epoch 14 : acc 0.8189
# after looking at 32 images, running_loss is 0.3631
# after looking at 1632 images, running_loss is 0.4366
# after looking at 3232 images, running_loss is 0.4227
# after looking at 4832 images, running_loss is 0.4318
# after looking at 6432 images, running_loss is 0.4286
# after looking at 8032 images, running_loss is 0.4227
# after looking at 9632 images, running_loss is 0.4293
# after looking at 11232 images, running_loss is 0.4316
# after looking at 12832 images, running_loss is 0.4273
# after looking at 14432 images, running_loss is 0.4290
# after looking at 16032 images, running_loss is 0.4279
# after looking at 17632 images, running_loss is 0.4305
# after looking at 19232 images, running_loss is 0.4298
# after looking at 20832 images, running_loss is 0.4269
# after looking at 22432 images, running_loss is 0.4244
# after looking at 24032 images, running_loss is 0.4293
# after looking at 25632 images, running_loss is 0.4293
# after looking at 27232 images, running_loss is 0.4294
# after looking at 28832 images, running_loss is 0.4291
# after looking at 30432 images, running_loss is 0.4339
# after looking at 32032 images, running_loss is 0.4357
# after looking at 33632 images, running_loss is 0.4374
# after looking at 35232 images, running_loss is 0.4382
# after looking at 36832 images, running_loss is 0.4414
# after looking at 38432 images, running_loss is 0.4439
# after looking at 40032 images, running_loss is 0.4455
# after looking at 41632 images, running_loss is 0.4483
# after looking at 43232 images, running_loss is 0.4498
# after looking at 44832 images, running_loss is 0.4487
# after looking at 46432 images, running_loss is 0.4487
# after looking at 48032 images, running_loss is 0.4497
# after looking at 49632 images, running_loss is 0.4481
# epoch 15 : loss 0.4477
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8327
# after looking at 3232 images, running_acc is 0.8326
# after looking at 4832 images, running_acc is 0.8351
# after looking at 6432 images, running_acc is 0.8319
# after looking at 8032 images, running_acc is 0.8318
# after looking at 9632 images, running_acc is 0.8338
# epoch 15 : acc 0.8322
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5455
# after looking at 1632 images, running_loss is 0.4820
# after looking at 3232 images, running_loss is 0.4639
# after looking at 4832 images, running_loss is 0.4376
# after looking at 6432 images, running_loss is 0.4337
# after looking at 8032 images, running_loss is 0.4296
# after looking at 9632 images, running_loss is 0.4276
# after looking at 11232 images, running_loss is 0.4246
# after looking at 12832 images, running_loss is 0.4249
# after looking at 14432 images, running_loss is 0.4234
# after looking at 16032 images, running_loss is 0.4216
# after looking at 17632 images, running_loss is 0.4240
# after looking at 19232 images, running_loss is 0.4227
# after looking at 20832 images, running_loss is 0.4255
# after looking at 22432 images, running_loss is 0.4278
# after looking at 24032 images, running_loss is 0.4275
# after looking at 25632 images, running_loss is 0.4273
# after looking at 27232 images, running_loss is 0.4280
# after looking at 28832 images, running_loss is 0.4278
# after looking at 30432 images, running_loss is 0.4276
# after looking at 32032 images, running_loss is 0.4285
# after looking at 33632 images, running_loss is 0.4285
# after looking at 35232 images, running_loss is 0.4289
# after looking at 36832 images, running_loss is 0.4307
# after looking at 38432 images, running_loss is 0.4319
# after looking at 40032 images, running_loss is 0.4319
# after looking at 41632 images, running_loss is 0.4324
# after looking at 43232 images, running_loss is 0.4324
# after looking at 44832 images, running_loss is 0.4326
# after looking at 46432 images, running_loss is 0.4339
# after looking at 48032 images, running_loss is 0.4348
# after looking at 49632 images, running_loss is 0.4341
# epoch 16 : loss 0.4356
# after looking at 32 images, running_acc is 0.7500
# after looking at 1632 images, running_acc is 0.8309
# after looking at 3232 images, running_acc is 0.8246
# after looking at 4832 images, running_acc is 0.8288
# after looking at 6432 images, running_acc is 0.8245
# after looking at 8032 images, running_acc is 0.8264
# after looking at 9632 images, running_acc is 0.8290
# epoch 16 : acc 0.8287
# after looking at 32 images, running_loss is 0.7091
# after looking at 1632 images, running_loss is 0.4133
# after looking at 3232 images, running_loss is 0.4345
# after looking at 4832 images, running_loss is 0.4074
# after looking at 6432 images, running_loss is 0.4064
# after looking at 8032 images, running_loss is 0.4081
# after looking at 9632 images, running_loss is 0.4122
# after looking at 11232 images, running_loss is 0.4099
# after looking at 12832 images, running_loss is 0.4102
# after looking at 14432 images, running_loss is 0.4115
# after looking at 16032 images, running_loss is 0.4111
# after looking at 17632 images, running_loss is 0.4138
# after looking at 19232 images, running_loss is 0.4113
# after looking at 20832 images, running_loss is 0.4128
# after looking at 22432 images, running_loss is 0.4169
# after looking at 24032 images, running_loss is 0.4175
# after looking at 25632 images, running_loss is 0.4176
# after looking at 27232 images, running_loss is 0.4174
# after looking at 28832 images, running_loss is 0.4200
# after looking at 30432 images, running_loss is 0.4189
# after looking at 32032 images, running_loss is 0.4185
# after looking at 33632 images, running_loss is 0.4179
# after looking at 35232 images, running_loss is 0.4169
# after looking at 36832 images, running_loss is 0.4173
# after looking at 38432 images, running_loss is 0.4166
# after looking at 40032 images, running_loss is 0.4185
# after looking at 41632 images, running_loss is 0.4197
# after looking at 43232 images, running_loss is 0.4205
# after looking at 44832 images, running_loss is 0.4207
# after looking at 46432 images, running_loss is 0.4198
# after looking at 48032 images, running_loss is 0.4201
# after looking at 49632 images, running_loss is 0.4223
# epoch 17 : loss 0.4225
# after looking at 32 images, running_acc is 0.9062
# after looking at 1632 images, running_acc is 0.8290
# after looking at 3232 images, running_acc is 0.8308
# after looking at 4832 images, running_acc is 0.8305
# after looking at 6432 images, running_acc is 0.8291
# after looking at 8032 images, running_acc is 0.8264
# after looking at 9632 images, running_acc is 0.8264
# epoch 17 : acc 0.8265
# after looking at 32 images, running_loss is 0.6298
# after looking at 1632 images, running_loss is 0.3734
# after looking at 3232 images, running_loss is 0.3681
# after looking at 4832 images, running_loss is 0.3790
# after looking at 6432 images, running_loss is 0.3785
# after looking at 8032 images, running_loss is 0.3929
# after looking at 9632 images, running_loss is 0.4011
# after looking at 11232 images, running_loss is 0.4039
# after looking at 12832 images, running_loss is 0.4022
# after looking at 14432 images, running_loss is 0.4037
# after looking at 16032 images, running_loss is 0.4028
# after looking at 17632 images, running_loss is 0.4010
# after looking at 19232 images, running_loss is 0.3997
# after looking at 20832 images, running_loss is 0.3989
# after looking at 22432 images, running_loss is 0.3996
# after looking at 24032 images, running_loss is 0.4040
# after looking at 25632 images, running_loss is 0.4027
# after looking at 27232 images, running_loss is 0.4026
# after looking at 28832 images, running_loss is 0.4041
# after looking at 30432 images, running_loss is 0.4053
# after looking at 32032 images, running_loss is 0.4047
# after looking at 33632 images, running_loss is 0.4057
# after looking at 35232 images, running_loss is 0.4061
# after looking at 36832 images, running_loss is 0.4060
# after looking at 38432 images, running_loss is 0.4054
# after looking at 40032 images, running_loss is 0.4066
# after looking at 41632 images, running_loss is 0.4072
# after looking at 43232 images, running_loss is 0.4065
# after looking at 44832 images, running_loss is 0.4064
# after looking at 46432 images, running_loss is 0.4066
# after looking at 48032 images, running_loss is 0.4076
# after looking at 49632 images, running_loss is 0.4070
# epoch 18 : loss 0.4068
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8395
# after looking at 3232 images, running_acc is 0.8410
# after looking at 4832 images, running_acc is 0.8429
# after looking at 6432 images, running_acc is 0.8427
# after looking at 8032 images, running_acc is 0.8414
# after looking at 9632 images, running_acc is 0.8417
# epoch 18 : acc 0.8411
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.6809
# after looking at 1632 images, running_loss is 0.3929
# after looking at 3232 images, running_loss is 0.3907
# after looking at 4832 images, running_loss is 0.3824
# after looking at 6432 images, running_loss is 0.3776
# after looking at 8032 images, running_loss is 0.3763
# after looking at 9632 images, running_loss is 0.3887
# after looking at 11232 images, running_loss is 0.3931
# after looking at 12832 images, running_loss is 0.3933
# after looking at 14432 images, running_loss is 0.3968
# after looking at 16032 images, running_loss is 0.3940
# after looking at 17632 images, running_loss is 0.3910
# after looking at 19232 images, running_loss is 0.3938
# after looking at 20832 images, running_loss is 0.3937
# after looking at 22432 images, running_loss is 0.3968
# after looking at 24032 images, running_loss is 0.3969
# after looking at 25632 images, running_loss is 0.3967
# after looking at 27232 images, running_loss is 0.3988
# after looking at 28832 images, running_loss is 0.3975
# after looking at 30432 images, running_loss is 0.3985
# after looking at 32032 images, running_loss is 0.3985
# after looking at 33632 images, running_loss is 0.3984
# after looking at 35232 images, running_loss is 0.3989
# after looking at 36832 images, running_loss is 0.4017
# after looking at 38432 images, running_loss is 0.4007
# after looking at 40032 images, running_loss is 0.4015
# after looking at 41632 images, running_loss is 0.4015
# after looking at 43232 images, running_loss is 0.4027
# after looking at 44832 images, running_loss is 0.4028
# after looking at 46432 images, running_loss is 0.4028
# after looking at 48032 images, running_loss is 0.4034
# after looking at 49632 images, running_loss is 0.4030
# epoch 19 : loss 0.4032
# after looking at 32 images, running_acc is 0.9062
# after looking at 1632 images, running_acc is 0.8536
# after looking at 3232 images, running_acc is 0.8493
# after looking at 4832 images, running_acc is 0.8506
# after looking at 6432 images, running_acc is 0.8484
# after looking at 8032 images, running_acc is 0.8461
# after looking at 9632 images, running_acc is 0.8478
# epoch 19 : acc 0.8477
# ### saving current model...###

# %%
vgga.conv1a[0].weight
# Out:
# Parameter containing:
# tensor([[[[-0.2921, -0.3159, -0.1400],
#           [-0.3848, -0.1721,  0.1862],
#           [ 0.1684,  0.4809,  0.5738]],
#
#          [[ 0.2174,  0.0913, -0.0117],
#           [-0.1756, -0.1870, -0.0773],
#           [-0.0321,  0.0455,  0.0592]],
#
#          [[ 0.4902,  0.2905,  0.0942],
#           [ 0.0962, -0.1479, -0.1659],
#           [-0.1122, -0.2057, -0.3572]]],
#
#
#         [[[-0.0175, -0.0723,  0.0780],
#           [-0.0982, -0.0335,  0.0246],
#           [-0.0404,  0.0237,  0.0100]],
#
#          [[-0.1500, -0.1248,  0.0137],
#           [-0.2211, -0.0520,  0.0216],
#           [ 0.0672,  0.0828,  0.0170]],
#
#          [[-0.1423, -0.0995,  0.0776],
#           [-0.0419,  0.1408,  0.1638],
#           [ 0.2724,  0.2639,  0.1659]]],
#
#
#         [[[-0.0161,  0.4498, -0.2505],
#           [ 0.4555, -0.7634, -0.0139],
#           [-0.2441, -0.0829,  0.6397]],
#
#          [[ 0.1326,  0.4843, -0.3416],
#           [ 0.5029, -0.8290, -0.1472],
#           [-0.3118, -0.1980,  0.6230]],
#
#          [[ 0.0419,  0.5696, -0.2723],
#           [ 0.5120, -0.6432, -0.1375],
#           [-0.1890, -0.1276,  0.3664]]],
#
#
#         ...,
#
#
#         [[[-0.2086, -0.2969, -0.1304],
#           [ 0.1900,  0.2272,  0.1518],
#           [ 0.0174, -0.1124, -0.0018]],
#
#          [[-0.1798, -0.3383, -0.1053],
#           [ 0.2343,  0.3060,  0.3029],
#           [ 0.0897, -0.0434, -0.0167]],
#
#          [[-0.2537, -0.3763, -0.1571],
#           [ 0.2345,  0.3181,  0.3159],
#           [-0.0027, -0.0501, -0.0564]]],
#
#
#         [[[ 0.1524,  0.1979,  0.1641],
#           [ 0.2050,  0.1669,  0.1547],
#           [ 0.0864,  0.0608, -0.0722]],
#
#          [[-0.0326, -0.0388, -0.0495],
#           [ 0.0176,  0.0361, -0.0748],
#           [-0.0289, -0.0531, -0.1197]],
#
#          [[ 0.0618,  0.0584,  0.0021],
#           [ 0.0705,  0.1335, -0.0332],
#           [ 0.1154,  0.0516, -0.0326]]],
#
#
#         [[[ 0.0677,  0.1556,  0.0780],
#           [ 0.1385,  0.2737,  0.2581],
#           [ 0.0432,  0.2228,  0.1453]],
#
#          [[-0.2040, -0.2878, -0.2512],
#           [-0.3023, -0.4228, -0.3673],
#           [-0.1584, -0.3280, -0.2392]],
#
#          [[ 0.1623,  0.1455,  0.1804],
#           [ 0.1925,  0.1349,  0.1176],
#           [ 0.1456,  0.1284,  0.1498]]]], device='cuda:0', requires_grad=True)
