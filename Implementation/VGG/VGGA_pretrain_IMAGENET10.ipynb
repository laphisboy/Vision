# %%
from google.colab import drive
drive.mount('/content/gdrive')

MODELPATH = '/content/gdrive/My Drive/Colab Notebooks/yai7_CV1/modelsave/'

IMAGEWOOFPATH = '/content/gdrive/My Drive/Colab Notebooks/data/imagewoof2'

labels = dict(
  n02093754='Australian terrier', 
  n02089973='Border terrier', 
  n02099601='Samoyed',
  n02087394='Beagle', 
  n02105641='Shih-Tzu', 
  n02096294='English foxhound', 
  n02088364='Rhodesian ridgeback', 
  n02115641='Dingo', 
  n02111889='Golden retriever', 
  n02086240='Old English sheepdog'
)
# Out:
# Mounted at /content/gdrive

# %%
# going to use imagewoof dataset for training VGG net D 16

# brief note on VGG 16 architecture :

# seems like there is no batch normalisation
# all hidden layers "equipped" with ReLU
# dropout on first two layers of fully connected layers (p=0.5)
# L2 regularizer
# mini-batch gradient descent with momentum (batchsize=256) (based on LeNet)
# initial learning rate 10^-2
# learning rate decreased fater of 10 when val acc stop improving (ReduceLRonPlateau?)
# 370K iterations = 74 epochs
# augmentations : randomcrop, horizontalflip, randomrgbcolorshift
# shallow train net A first and then do transfer learning?
# random initialization with zero mean 10-^2 variance

##################################
# net A arch:   ## net D arch:   #
#               ##               #
# input 224x224 ## input 224x224 #
#               ##               #
# conv3-64      ## conv3-64      #
#               ## conv3-64      #
# maxpool       ## maxpool       #
#               ##               #
# conv3-128     ## conv3-128     #
#               ## conv3-128     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-256     ## conv3-256     #
# conv3-256     ## conv3-256     #
#               ## conv3-256     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-512     ## conv3-512     #
# conv3-512     ## conv3-512     #
#               ## conv3-512     #
# maxpool       ## maxpool       #
#               ##               #
# conv3-512     ## conv3-512     #
# conv3-512     ## conv3-512     #
#               ## conv3-512     #
# maxpool       ## maxpool       #
#               ##               #
# dropout       ## dropout       #
# fc-4096       ## fc-4096       #
# dropout       ## dropout       #
# fc-4096       ## fc-4096       #
# fc-1000       ## fc-1000       #
# softmax       ## softmax       #
##################################

# %%
import torch

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

# %%
torch.__version__
# Out:
# '1.7.0+cu101'

# %%
import torchvision
import torchvision.transforms as transforms

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("check device:", torch.cuda.get_device_name())
print("how many?:", torch.cuda.device_count())
print("so can i use it?", torch.cuda.is_available())
# Out:
# check device: Tesla T4
# how many?: 1
# so can i use it? True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# before loading data,
# need to determine transformation (augmentation)

# %%
# no augmentation yet

"""train_transform = A.Compose([
                             ToTensor()
])

test_transform = A.Compose([
                            ToTensor()
])"""
# Out:
# 'train_transform = A.Compose([\n                             ToTensor()\n])\n\ntest_transform = A.Compose([\n                            ToTensor()\n])'

# %%
"""train_transform = transforms.Compose([
                             transforms.Resize(224),
                             transforms.CenterCrop(224),
                             transforms.ToTensor()
])

train_set = torchvision.datasets.ImageFolder(root=IMAGEWOOFPATH+'/train', transform=train_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=False, num_workers=4)"""
# Out:
# "train_transform = transforms.Compose([\n                             transforms.Resize(224),\n                             transforms.CenterCrop(224),\n                             transforms.ToTensor()\n])\n\ntrain_set = torchvision.datasets.ImageFolder(root=IMAGEWOOFPATH+'/train', transform=train_transform)\n\ntrain_loader = DataLoader(train_set, batch_size=32, shuffle=False, num_workers=4)"

# %%
"""# page 2
# "The only preprocessing we do is subtracting the mean RGB value, 
# computed on the training set, from each pixel."

mean = 0.
std = 0.
nb_samples = 0.

for data, _ in train_loader:
    batch_samples = data.size(0)
    data = data.view(batch_samples, data.size(1), -1)
    mean += data.mean(2).sum(0)
    std += data.std(2).sum(0)
    nb_samples += batch_samples

mean /= nb_samples
std /= nb_samples

print(f'mean = {mean}')
print(f'std = {std}')
"""
#del train_set, train_transform, train_loader
# Out:
# '# page 2\n# "The only preprocessing we do is subtracting the mean RGB value, \n# computed on the training set, from each pixel."\n\nmean = 0.\nstd = 0.\nnb_samples = 0.\n\nfor data, _ in train_loader:\n    batch_samples = data.size(0)\n    data = data.view(batch_samples, data.size(1), -1)\n    mean += data.mean(2).sum(0)\n    std += data.std(2).sum(0)\n    nb_samples += batch_samples\n\nmean /= nb_samples\nstd /= nb_samples\n\nprint(f\'mean = {mean}\')\nprint(f\'std = {std}\')\n'

# %%
# using torchvision transformation
# augmentations : randomcrop, horizontalflip, randomrgbcolorshift
# image for CIFAR10 is too small for randomcrop... so add padding
# paper doesn't say anything about normalization ... so not doing it :P

train_transform = transforms.Compose([
                             transforms.Resize(224),
                             transforms.CenterCrop(224),
                             transforms.RandomHorizontalFlip(p=0.5),
                             transforms.ToTensor(),
                             transforms.Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
])

test_transform = transforms.Compose([
                            transforms.Resize(224),
                            transforms.CenterCrop(224),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
])

# %%
train_set = torchvision.datasets.ImageFolder(root=IMAGEWOOFPATH+'/train', transform=train_transform)

test_set = torchvision.datasets.ImageFolder(root=IMAGEWOOFPATH+'/val', transform=test_transform)

# how to retrieve image without using DataLoader?
# just by indexing is good enough

# %%
# checking on the loaded data :0
train_set
# Out:
# Dataset ImageFolder
#     Number of datapoints: 9025
#     Root location: /content/gdrive/My Drive/Colab Notebooks/data/imagewoof2/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(224, 224))
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
#            )

# %%
test_set
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3929
#     Root location: /content/gdrive/My Drive/Colab Notebooks/data/imagewoof2/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=224, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=(0.4963, 0.4612, 0.3981), std=(0.2224, 0.2163, 0.2181))
#            )

# %%
labels = dict(
  n02093754='Australian terrier', 
  n02089973='Border terrier', 
  n02099601='Samoyed', 
  n02087394='Beagle', 
  n02105641='Shih-Tzu', 
  n02096294='English foxhound', 
  n02088364='Rhodesian ridgeback', 
  n02115641='Dingo', 
  n02111889='Golden retriever', 
  n02086240='Old English sheepdog'
)

classes = ('Australian terrier', 'Border terrier', 'Samoyed', 'Beagle', 
           'Shih-Tzu', 'English foxhound', 'Rhodesian ridgeback', 
           'Dingo', 'Golden retriever', 'Old English sheepdog')

# %%
# from dataset to loader

train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False, num_workers=4)

# seems like num_workers works best when...
# num_workers = num GPU * 4

# %%
# check on the images

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# used for checking if image came out with batchsize=1

"""for image, label in train_loader:
    print(image)
    print(image.dtype)
    print(label)
    print(label.dtype)
    print(image.squeeze_().shape)
    imshow(image)
    break"""
# Out:
# 'for image, label in train_loader:\n    print(image)\n    print(image.dtype)\n    print(label)\n    print(label.dtype)\n    print(image.squeeze_().shape)\n    imshow(image)\n    break'

# %%
# construct architecture for VGG-D
# but will use this for VGG-A :)

class VGGa(nn.Module):
    def __init__(self):
        super(VGGa, self).__init__()

        self.conv1a = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv1d = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2a = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2d = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv3a = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=0),
            nn.ReLU())
        
        self.conv3d = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        self.conv4a = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=0),
            nn.ReLU()
            )
        self.conv4d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv5a = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=0),
            nn.ReLU()
        )
        self.conv5d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        # 224 --> 112 --> 56 54 52 --> 26 24 22--> 11 9 7 --> 3
        # 512 * 3 * 3 = 4608
        self.fcd = nn.Linear(4608, 10)


        self.fca = nn.Linear(4608, 10)

        self.dropout = nn.Dropout(p=0.5)

        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.softmax = nn.Softmax(dim=0)


    def forward(self, x):
        x = self.conv1a(x)
        x = self.maxpool(x)
        x = self.conv2a(x)
        x = self.maxpool(x)
        x = self.conv3a(x)
        x = self.maxpool(x)
        x = self.conv4a(x)
        x = self.maxpool(x)
        x= self.conv5a(x)
        x = self.maxpool(x)
        #print('before view', x.shape)

        # 224 --> 112 --> 56 54 52 --> 26 24 22--> 11 9 7 --> 3
        # 512 * 3 * 3 = 4608
        x = x.view(-1, 4608)
        #print('after view', x.shape)
        x = self.dropout(x)
        x = self.fca(x)
        #x = self.softmax(x)
        return x

# %%
vgga = VGGa()
vgga.to(device)
# Out:
# VGGa(
#   (conv1a): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv1d): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2a): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2d): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv3a): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#   )
#   (conv3d): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv4a): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#   )
#   (conv4d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5a): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#   )
#   (conv5d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (fcd): Linear(in_features=4608, out_features=10, bias=True)
#   (fca): Linear(in_features=4608, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (softmax): Softmax(dim=0)
# )

# %%
# as in the paper,
# init weights with normal distribution
# init biases with zeros

# init all weights and biases

# next time try making this inside the module

def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.normal_(child.weight, mean=0.0, std=0.01)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.normal_(grandchild.weight, mean=0.0, std=0.01)
                    torch.nn.init.zeros_(grandchild.bias)

# %%
# try xavier just for fun~
"""
def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.xavier_normal_(child.weight)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.xavier_normal_(grandchild.weight)
                    torch.nn.init.zeros_(grandchild.bias)"""
# Out:
# '\ndef init_weights(m):\n\n    for i, child in enumerate(m.children()):\n        if type(child) is (nn.Linear or nn.Conv2d):\n            torch.nn.init.xavier_normal_(child.weight)\n            torch.nn.init.zeros_(child.bias)\n        elif type(child) == nn.Sequential:\n            for j, grandchild in enumerate(child.children()):\n                #print(j, grandchild)\n                if type(child) is (nn.Linear or nn.Conv2d):\n                    torch.nn.init.xavier_normal_(grandchild.weight)\n                    torch.nn.init.zeros_(grandchild.bias)'

# %%
init_weights(vgga)

# %%
# just for checking if initialized correctly

"""for i, child in enumerate(vgga.children()):
    if type(child) == nn.Sequential:
        for j, grandchild in enumerate(child.children()):
            if type(child) is (nn.Linear or nn.Conv2d):
                print(i, j, grandchild)
                print(grandchild.weight)
                print(grandchild.bias)

    else:
        if type(child) is (nn.Linear or nn.Conv2d):
            print(i, child)
            print(child.weight)
            print(child.bias)"""

# seems to work :)
# Out:
# 'for i, child in enumerate(vgga.children()):\n    if type(child) == nn.Sequential:\n        for j, grandchild in enumerate(child.children()):\n            if type(child) is (nn.Linear or nn.Conv2d):\n                print(i, j, grandchild)\n                print(grandchild.weight)\n                print(grandchild.bias)\n\n    else:\n        if type(child) is (nn.Linear or nn.Conv2d):\n            print(i, child)\n            print(child.weight)\n            print(child.bias)'

# %%
def train_one_epoch(model, train_loader, loss_function, optimizer, epoch):
    #model.train()
    length = len(train_loader)
    #pbar = tqdm(enumerate(train_loader), total=length)
    running_loss = 0.0

    for i, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        pred = model(image)
        #print('pred')
        #print(pred.shape)
        #print('label')
        #print(label.shape)
        loss = loss_function(pred, label)
        #print(loss)
        #print(loss.item())
    
        loss.backward()
        
        optimizer.step()

        running_loss += loss.item()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_loss is {running_loss/(i+1):.4f}')
        #pbar.set_description(f'running_loss {running_loss/(i+1):.4f}')

    print(f'epoch {epoch} : loss {running_loss/length:.4f}')


def eval_one_epoch(model, test_loader, scheduler, epoch, best_val_acc):
    #model.eval()
    length = len(test_loader)
    #pbar = tqdm(enumerate(test_loader), total=length)
    running_acc = 0.0

    for i, (image, label) in enumerate(test_loader):
        image, label = image.to(device), label.numpy()

        pred = model(image)
        pred_label = pred.argmax(axis=1).detach().cpu().numpy()
        running_acc += (pred_label==label).mean()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_acc is {running_acc/(i+1):.4f}')
        #pbar.set_description(f'running_acc {running_acc/(i+1):.4f}')

    val_acc = running_acc/length
    scheduler.step(val_acc)

    print(f'epoch {epoch} : acc {val_acc:.4f}')
    
    if val_acc > best_val_acc:
        print("### saving current model...### \n")
        torch.save(model.state_dict(), MODELPATH+f'woof_pretrained_{epoch}_epochs')
        best_val_acc = val_acc

    return best_val_acc

# %%
# hyperparameters from paper
# assuming same for pretraining

learning_rate = 0.01
momentum = 0.9
weight_decay = 5e-4
epochs = 74

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(vgga.parameters(), lr=learning_rate, 
                            momentum=momentum, weight_decay=weight_decay)

# patience=5 chosen arbitrarily
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.1, patience=10, verbose=True
    )

# %%
best_val_acc = 0.0

for epoch in range(epochs):
    vgga.train()
    train_one_epoch(vgga, train_loader, loss_function, optimizer, epoch)
    vgga.eval()
    best_val_acc = eval_one_epoch(vgga, test_loader, scheduler, epoch, best_val_acc)
# Out:
# after looking at 32 images, running_loss is 2.3027
# after looking at 1632 images, running_loss is 2.3024
# after looking at 3232 images, running_loss is 2.3003
# after looking at 4832 images, running_loss is 2.2986
# after looking at 6432 images, running_loss is 2.2988
# after looking at 8032 images, running_loss is 2.2932
# epoch 0 : loss 2.2829
# after looking at 32 images, running_acc is 0.0000
# after looking at 1632 images, running_acc is 0.2629
# after looking at 3232 images, running_acc is 0.1553
# epoch 0 : acc 0.1456
# ### saving current model...###
#
# after looking at 32 images, running_loss is 2.1149
# after looking at 1632 images, running_loss is 2.2726
# after looking at 3232 images, running_loss is 2.2190
# after looking at 4832 images, running_loss is 2.1801
# after looking at 6432 images, running_loss is 2.1585
# after looking at 8032 images, running_loss is 2.1482
# epoch 1 : loss 2.1425
# after looking at 32 images, running_acc is 0.3125
# after looking at 1632 images, running_acc is 0.1740
# after looking at 3232 images, running_acc is 0.1643
# epoch 1 : acc 0.1957
# ### saving current model...###
#
# after looking at 32 images, running_loss is 2.1017
# after looking at 1632 images, running_loss is 2.1120
# after looking at 3232 images, running_loss is 2.0947
# after looking at 4832 images, running_loss is 2.0868
# after looking at 6432 images, running_loss is 2.0804
# after looking at 8032 images, running_loss is 2.0785
# epoch 2 : loss 2.0732
# after looking at 32 images, running_acc is 0.2500
# after looking at 1632 images, running_acc is 0.1985
# after looking at 3232 images, running_acc is 0.2101
# epoch 2 : acc 0.2319
# ### saving current model...###
#
# after looking at 32 images, running_loss is 2.2046
# after looking at 1632 images, running_loss is 2.0599
# after looking at 3232 images, running_loss is 2.0650
# after looking at 4832 images, running_loss is 2.0416
# after looking at 6432 images, running_loss is 2.0340
# after looking at 8032 images, running_loss is 2.0305
# epoch 3 : loss 2.0255
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.2678
# after looking at 3232 images, running_acc is 0.2129
# epoch 3 : acc 0.2435
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.7762
# after looking at 1632 images, running_loss is 2.0116
# after looking at 3232 images, running_loss is 1.9808
# after looking at 4832 images, running_loss is 1.9731
# after looking at 6432 images, running_loss is 1.9700
# after looking at 8032 images, running_loss is 1.9715
# epoch 4 : loss 1.9684
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.3309
# after looking at 3232 images, running_acc is 0.2587
# epoch 4 : acc 0.2816
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.7944
# after looking at 1632 images, running_loss is 1.9126
# after looking at 3232 images, running_loss is 1.9275
# after looking at 4832 images, running_loss is 1.9403
# after looking at 6432 images, running_loss is 1.9480
# after looking at 8032 images, running_loss is 1.9485
# epoch 5 : loss 1.9495
# after looking at 32 images, running_acc is 0.5312
# after looking at 1632 images, running_acc is 0.3866
# after looking at 3232 images, running_acc is 0.2460
# epoch 5 : acc 0.2741
# after looking at 32 images, running_loss is 1.9454
# after looking at 1632 images, running_loss is 1.9272
# after looking at 3232 images, running_loss is 1.9065
# after looking at 4832 images, running_loss is 1.8825
# after looking at 6432 images, running_loss is 1.8760
# after looking at 8032 images, running_loss is 1.8799
# epoch 6 : loss 1.8829
# after looking at 32 images, running_acc is 0.3125
# after looking at 1632 images, running_acc is 0.3156
# after looking at 3232 images, running_acc is 0.2420
# epoch 6 : acc 0.2623
# after looking at 32 images, running_loss is 1.8929
# after looking at 1632 images, running_loss is 1.9001
# after looking at 3232 images, running_loss is 1.8806
# after looking at 4832 images, running_loss is 1.8609
# after looking at 6432 images, running_loss is 1.8458
# after looking at 8032 images, running_loss is 1.8557
# epoch 7 : loss 1.8579
# after looking at 32 images, running_acc is 0.7188
# after looking at 1632 images, running_acc is 0.2047
# after looking at 3232 images, running_acc is 0.1501
# epoch 7 : acc 0.1825
# after looking at 32 images, running_loss is 2.4185
# after looking at 1632 images, running_loss is 2.3142
# after looking at 3232 images, running_loss is 2.3057
# after looking at 4832 images, running_loss is 2.2986
# after looking at 6432 images, running_loss is 2.2914
# after looking at 8032 images, running_loss is 2.2818
# epoch 8 : loss 2.2735
# after looking at 32 images, running_acc is 0.0000
# after looking at 1632 images, running_acc is 0.2218
# after looking at 3232 images, running_acc is 0.1429
# epoch 8 : acc 0.1511
# after looking at 32 images, running_loss is 2.3502
# after looking at 1632 images, running_loss is 2.1717
# after looking at 3232 images, running_loss is 2.1527
# after looking at 4832 images, running_loss is 2.1226
# after looking at 6432 images, running_loss is 2.0797
# after looking at 8032 images, running_loss is 2.0582
# epoch 9 : loss 2.0451
# after looking at 32 images, running_acc is 0.5625
# after looking at 1632 images, running_acc is 0.3309
# after looking at 3232 images, running_acc is 0.2386
# epoch 9 : acc 0.2600
# after looking at 32 images, running_loss is 1.8648
# after looking at 1632 images, running_loss is 1.9141
# after looking at 3232 images, running_loss is 1.9110
# after looking at 4832 images, running_loss is 1.8985
# after looking at 6432 images, running_loss is 1.8825
# after looking at 8032 images, running_loss is 1.8794
# epoch 10 : loss 1.8738
# after looking at 32 images, running_acc is 0.5000
# after looking at 1632 images, running_acc is 0.2537
# after looking at 3232 images, running_acc is 0.2324
# epoch 10 : acc 0.2160
# after looking at 32 images, running_loss is 2.0383
# after looking at 1632 images, running_loss is 2.0240
# after looking at 3232 images, running_loss is 1.9647
# after looking at 4832 images, running_loss is 1.9273
# after looking at 6432 images, running_loss is 1.8968
# after looking at 8032 images, running_loss is 1.8760
# epoch 11 : loss 1.8617
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.4210
# after looking at 3232 images, running_acc is 0.3150
# epoch 11 : acc 0.3439
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.8463
# after looking at 1632 images, running_loss is 1.8084
# after looking at 3232 images, running_loss is 1.7960
# after looking at 4832 images, running_loss is 1.7794
# after looking at 6432 images, running_loss is 1.7678
# after looking at 8032 images, running_loss is 1.7656
# epoch 12 : loss 1.7622
# after looking at 32 images, running_acc is 0.2812
# after looking at 1632 images, running_acc is 0.2911
# after looking at 3232 images, running_acc is 0.2645
# epoch 12 : acc 0.3084
# after looking at 32 images, running_loss is 1.5940
# after looking at 1632 images, running_loss is 1.7265
# after looking at 3232 images, running_loss is 1.7255
# after looking at 4832 images, running_loss is 1.7166
# after looking at 6432 images, running_loss is 1.7038
# after looking at 8032 images, running_loss is 1.7018
# epoch 13 : loss 1.7074
# after looking at 32 images, running_acc is 0.0625
# after looking at 1632 images, running_acc is 0.2310
# after looking at 3232 images, running_acc is 0.2803
# epoch 13 : acc 0.3217
# after looking at 32 images, running_loss is 1.6187
# after looking at 1632 images, running_loss is 1.6654
# after looking at 3232 images, running_loss is 1.6712
# after looking at 4832 images, running_loss is 1.6562
# after looking at 6432 images, running_loss is 1.6636
# after looking at 8032 images, running_loss is 1.6607
# epoch 14 : loss 1.6561
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.3487
# after looking at 3232 images, running_acc is 0.3199
# epoch 14 : acc 0.3708
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.7020
# after looking at 1632 images, running_loss is 1.6334
# after looking at 3232 images, running_loss is 1.6195
# after looking at 4832 images, running_loss is 1.5992
# after looking at 6432 images, running_loss is 1.6024
# after looking at 8032 images, running_loss is 1.6025
# epoch 15 : loss 1.5905
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.4350
# after looking at 3232 images, running_acc is 0.3716
# epoch 15 : acc 0.3872
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.4563
# after looking at 1632 images, running_loss is 1.5607
# after looking at 3232 images, running_loss is 1.5413
# after looking at 4832 images, running_loss is 1.5423
# after looking at 6432 images, running_loss is 1.5566
# after looking at 8032 images, running_loss is 1.5668
# epoch 16 : loss 1.5551
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.4265
# after looking at 3232 images, running_acc is 0.3419
# epoch 16 : acc 0.3702
# after looking at 32 images, running_loss is 1.6620
# after looking at 1632 images, running_loss is 1.4518
# after looking at 3232 images, running_loss is 1.4666
# after looking at 4832 images, running_loss is 1.4563
# after looking at 6432 images, running_loss is 1.4663
# after looking at 8032 images, running_loss is 1.4744
# epoch 17 : loss 1.4714
# after looking at 32 images, running_acc is 0.5000
# after looking at 1632 images, running_acc is 0.3401
# after looking at 3232 images, running_acc is 0.3301
# epoch 17 : acc 0.3264
# after looking at 32 images, running_loss is 1.4250
# after looking at 1632 images, running_loss is 1.4329
# after looking at 3232 images, running_loss is 1.4491
# after looking at 4832 images, running_loss is 1.4351
# after looking at 6432 images, running_loss is 1.4210
# after looking at 8032 images, running_loss is 1.4177
# epoch 18 : loss 1.4315
# after looking at 32 images, running_acc is 0.4062
# after looking at 1632 images, running_acc is 0.3572
# after looking at 3232 images, running_acc is 0.3295
# epoch 18 : acc 0.3543
# after looking at 32 images, running_loss is 1.3509
# after looking at 1632 images, running_loss is 1.4270
# after looking at 3232 images, running_loss is 1.3821
# after looking at 4832 images, running_loss is 1.3875
# after looking at 6432 images, running_loss is 1.3829
# after looking at 8032 images, running_loss is 1.3735
# epoch 19 : loss 1.3677
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.4099
# after looking at 3232 images, running_acc is 0.3722
# epoch 19 : acc 0.4095
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.4291
# after looking at 1632 images, running_loss is 1.4126
# after looking at 3232 images, running_loss is 1.3659
# after looking at 4832 images, running_loss is 1.3519
# after looking at 6432 images, running_loss is 1.3524
# after looking at 8032 images, running_loss is 1.3436
# epoch 20 : loss 1.3464
# after looking at 32 images, running_acc is 0.4062
# after looking at 1632 images, running_acc is 0.3143
# after looking at 3232 images, running_acc is 0.2763
# epoch 20 : acc 0.3528
# after looking at 32 images, running_loss is 1.7817
# after looking at 1632 images, running_loss is 1.5921
# after looking at 3232 images, running_loss is 1.4873
# after looking at 4832 images, running_loss is 1.4294
# after looking at 6432 images, running_loss is 1.3975
# after looking at 8032 images, running_loss is 1.3703
# epoch 21 : loss 1.3569
# after looking at 32 images, running_acc is 0.4375
# after looking at 1632 images, running_acc is 0.3873
# after looking at 3232 images, running_acc is 0.3666
# epoch 21 : acc 0.4058
# after looking at 32 images, running_loss is 0.9853
# after looking at 1632 images, running_loss is 1.1876
# after looking at 3232 images, running_loss is 1.2265
# after looking at 4832 images, running_loss is 1.2104
# after looking at 6432 images, running_loss is 1.2226
# after looking at 8032 images, running_loss is 1.2178
# epoch 22 : loss 1.2115
# after looking at 32 images, running_acc is 0.7188
# after looking at 1632 images, running_acc is 0.4871
# after looking at 3232 images, running_acc is 0.3889
# epoch 22 : acc 0.4350
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.0322
# after looking at 1632 images, running_loss is 1.1270
# after looking at 3232 images, running_loss is 1.1528
# after looking at 4832 images, running_loss is 1.1508
# after looking at 6432 images, running_loss is 1.1550
# after looking at 8032 images, running_loss is 1.1491
# epoch 23 : loss 1.1567
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5380
# after looking at 3232 images, running_acc is 0.4196
# epoch 23 : acc 0.4431
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.2355
# after looking at 1632 images, running_loss is 1.2085
# after looking at 3232 images, running_loss is 1.1528
# after looking at 4832 images, running_loss is 1.1285
# after looking at 6432 images, running_loss is 1.1266
# after looking at 8032 images, running_loss is 1.1270
# epoch 24 : loss 1.1167
# after looking at 32 images, running_acc is 0.4062
# after looking at 1632 images, running_acc is 0.4246
# after looking at 3232 images, running_acc is 0.4121
# epoch 24 : acc 0.4472
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.1342
# after looking at 1632 images, running_loss is 1.0060
# after looking at 3232 images, running_loss is 0.9913
# after looking at 4832 images, running_loss is 1.0028
# after looking at 6432 images, running_loss is 1.0052
# after looking at 8032 images, running_loss is 1.0171
# epoch 25 : loss 1.0258
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.4963
# after looking at 3232 images, running_acc is 0.4273
# epoch 25 : acc 0.4735
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.8227
# after looking at 1632 images, running_loss is 0.9431
# after looking at 3232 images, running_loss is 0.9322
# after looking at 4832 images, running_loss is 0.9380
# after looking at 6432 images, running_loss is 0.9518
# after looking at 8032 images, running_loss is 0.9524
# epoch 26 : loss 0.9634
# after looking at 32 images, running_acc is 0.3125
# after looking at 1632 images, running_acc is 0.3321
# after looking at 3232 images, running_acc is 0.2584
# epoch 26 : acc 0.3384
# after looking at 32 images, running_loss is 1.6670
# after looking at 1632 images, running_loss is 1.5305
# after looking at 3232 images, running_loss is 1.3669
# after looking at 4832 images, running_loss is 1.2819
# after looking at 6432 images, running_loss is 1.2193
# after looking at 8032 images, running_loss is 1.1844
# epoch 27 : loss 1.1733
# after looking at 32 images, running_acc is 0.3438
# after looking at 1632 images, running_acc is 0.4228
# after looking at 3232 images, running_acc is 0.3852
# epoch 27 : acc 0.4014
# after looking at 32 images, running_loss is 1.0127
# after looking at 1632 images, running_loss is 1.3780
# after looking at 3232 images, running_loss is 1.2165
# after looking at 4832 images, running_loss is 1.1494
# after looking at 6432 images, running_loss is 1.1067
# after looking at 8032 images, running_loss is 1.0999
# epoch 28 : loss 1.0894
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.5319
# after looking at 3232 images, running_acc is 0.4131
# epoch 28 : acc 0.4372
# after looking at 32 images, running_loss is 0.7660
# after looking at 1632 images, running_loss is 0.9999
# after looking at 3232 images, running_loss is 0.9648
# after looking at 4832 images, running_loss is 0.9497
# after looking at 6432 images, running_loss is 0.9331
# after looking at 8032 images, running_loss is 0.9231
# epoch 29 : loss 0.9209
# after looking at 32 images, running_acc is 0.5625
# after looking at 1632 images, running_acc is 0.4265
# after looking at 3232 images, running_acc is 0.4032
# epoch 29 : acc 0.4419
# after looking at 32 images, running_loss is 1.2751
# after looking at 1632 images, running_loss is 0.8709
# after looking at 3232 images, running_loss is 0.8825
# after looking at 4832 images, running_loss is 0.8709
# after looking at 6432 images, running_loss is 0.8608
# after looking at 8032 images, running_loss is 0.8659
# epoch 30 : loss 0.8570
# after looking at 32 images, running_acc is 0.4062
# after looking at 1632 images, running_acc is 0.5012
# after looking at 3232 images, running_acc is 0.3963
# epoch 30 : acc 0.4385
# after looking at 32 images, running_loss is 0.6245
# after looking at 1632 images, running_loss is 0.8782
# after looking at 3232 images, running_loss is 0.8315
# after looking at 4832 images, running_loss is 0.8167
# after looking at 6432 images, running_loss is 0.8108
# after looking at 8032 images, running_loss is 0.8302
# epoch 31 : loss 0.8340
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.4320
# after looking at 3232 images, running_acc is 0.4174
# epoch 31 : acc 0.4524
# after looking at 32 images, running_loss is 1.0936
# after looking at 1632 images, running_loss is 0.8275
# after looking at 3232 images, running_loss is 0.8090
# after looking at 4832 images, running_loss is 0.7981
# after looking at 6432 images, running_loss is 0.8055
# after looking at 8032 images, running_loss is 0.7848
# epoch 32 : loss 0.7826
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5270
# after looking at 3232 images, running_acc is 0.4242
# epoch 32 : acc 0.4737
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5474
# after looking at 1632 images, running_loss is 0.7404
# after looking at 3232 images, running_loss is 0.7066
# after looking at 4832 images, running_loss is 0.7046
# after looking at 6432 images, running_loss is 0.7219
# after looking at 8032 images, running_loss is 0.7378
# epoch 33 : loss 0.7418
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5012
# after looking at 3232 images, running_acc is 0.4084
# epoch 33 : acc 0.4106
# after looking at 32 images, running_loss is 1.3961
# after looking at 1632 images, running_loss is 0.8507
# after looking at 3232 images, running_loss is 0.7924
# after looking at 4832 images, running_loss is 0.7423
# after looking at 6432 images, running_loss is 0.7323
# after looking at 8032 images, running_loss is 0.7292
# epoch 34 : loss 0.7228
# after looking at 32 images, running_acc is 0.5625
# after looking at 1632 images, running_acc is 0.4663
# after looking at 3232 images, running_acc is 0.4325
# epoch 34 : acc 0.4840
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.8894
# after looking at 1632 images, running_loss is 0.6776
# after looking at 3232 images, running_loss is 0.6578
# after looking at 4832 images, running_loss is 0.6656
# after looking at 6432 images, running_loss is 0.6652
# after looking at 8032 images, running_loss is 0.6626
# epoch 35 : loss 0.6543
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.4951
# after looking at 3232 images, running_acc is 0.4459
# epoch 35 : acc 0.4724
# after looking at 32 images, running_loss is 0.7331
# after looking at 1632 images, running_loss is 0.5492
# after looking at 3232 images, running_loss is 0.5540
# after looking at 4832 images, running_loss is 0.5821
# after looking at 6432 images, running_loss is 0.5776
# after looking at 8032 images, running_loss is 0.5777
# epoch 36 : loss 0.5845
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.5159
# after looking at 3232 images, running_acc is 0.4499
# epoch 36 : acc 0.4887
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.6903
# after looking at 1632 images, running_loss is 0.5460
# after looking at 3232 images, running_loss is 0.5786
# after looking at 4832 images, running_loss is 0.5845
# after looking at 6432 images, running_loss is 0.5762
# after looking at 8032 images, running_loss is 0.5836
# epoch 37 : loss 0.5806
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.4994
# after looking at 3232 images, running_acc is 0.4307
# epoch 37 : acc 0.4774
# after looking at 32 images, running_loss is 0.5793
# after looking at 1632 images, running_loss is 0.4395
# after looking at 3232 images, running_loss is 0.4692
# after looking at 4832 images, running_loss is 0.4958
# after looking at 6432 images, running_loss is 0.4947
# after looking at 8032 images, running_loss is 0.5084
# epoch 38 : loss 0.5211
# after looking at 32 images, running_acc is 0.5312
# after looking at 1632 images, running_acc is 0.5159
# after looking at 3232 images, running_acc is 0.4669
# epoch 38 : acc 0.5000
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.6116
# after looking at 1632 images, running_loss is 0.5272
# after looking at 3232 images, running_loss is 0.5095
# after looking at 4832 images, running_loss is 0.4950
# after looking at 6432 images, running_loss is 0.4885
# after looking at 8032 images, running_loss is 0.5033
# epoch 39 : loss 0.5103
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.5686
# after looking at 3232 images, running_acc is 0.4415
# epoch 39 : acc 0.4938
# after looking at 32 images, running_loss is 0.5594
# after looking at 1632 images, running_loss is 0.4021
# after looking at 3232 images, running_loss is 0.4502
# after looking at 4832 images, running_loss is 0.4578
# after looking at 6432 images, running_loss is 0.4833
# after looking at 8032 images, running_loss is 0.4902
# epoch 40 : loss 0.4906
# after looking at 32 images, running_acc is 0.7500
# after looking at 1632 images, running_acc is 0.5833
# after looking at 3232 images, running_acc is 0.4623
# epoch 40 : acc 0.5062
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.2300
# after looking at 1632 images, running_loss is 0.4079
# after looking at 3232 images, running_loss is 0.4195
# after looking at 4832 images, running_loss is 0.4233
# after looking at 6432 images, running_loss is 0.4338
# after looking at 8032 images, running_loss is 0.4518
# epoch 41 : loss 0.4543
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5355
# after looking at 3232 images, running_acc is 0.4480
# epoch 41 : acc 0.4970
# after looking at 32 images, running_loss is 0.3609
# after looking at 1632 images, running_loss is 0.4069
# after looking at 3232 images, running_loss is 0.4028
# after looking at 4832 images, running_loss is 0.4248
# after looking at 6432 images, running_loss is 0.4424
# after looking at 8032 images, running_loss is 0.4507
# epoch 42 : loss 0.4500
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.4945
# after looking at 3232 images, running_acc is 0.4530
# epoch 42 : acc 0.5020
# after looking at 32 images, running_loss is 0.2346
# after looking at 1632 images, running_loss is 0.3620
# after looking at 3232 images, running_loss is 0.3798
# after looking at 4832 images, running_loss is 0.4129
# after looking at 6432 images, running_loss is 0.4075
# after looking at 8032 images, running_loss is 0.4091
# epoch 43 : loss 0.4106
# after looking at 32 images, running_acc is 0.7188
# after looking at 1632 images, running_acc is 0.5343
# after looking at 3232 images, running_acc is 0.4511
# epoch 43 : acc 0.4914
# after looking at 32 images, running_loss is 0.4617
# after looking at 1632 images, running_loss is 0.3455
# after looking at 3232 images, running_loss is 0.4099
# after looking at 4832 images, running_loss is 0.4078
# after looking at 6432 images, running_loss is 0.4190
# after looking at 8032 images, running_loss is 0.4241
# epoch 44 : loss 0.4186
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5355
# after looking at 3232 images, running_acc is 0.4406
# epoch 44 : acc 0.4953
# after looking at 32 images, running_loss is 0.5645
# after looking at 1632 images, running_loss is 0.3523
# after looking at 3232 images, running_loss is 0.3717
# after looking at 4832 images, running_loss is 0.3940
# after looking at 6432 images, running_loss is 0.3839
# after looking at 8032 images, running_loss is 0.3897
# epoch 45 : loss 0.3995
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5453
# after looking at 3232 images, running_acc is 0.4824
# epoch 45 : acc 0.5058
# after looking at 32 images, running_loss is 0.4421
# after looking at 1632 images, running_loss is 0.3438
# after looking at 3232 images, running_loss is 0.3346
# after looking at 4832 images, running_loss is 0.3227
# after looking at 6432 images, running_loss is 0.3459
# after looking at 8032 images, running_loss is 0.3531
# epoch 46 : loss 0.3541
# after looking at 32 images, running_acc is 0.5938
# after looking at 1632 images, running_acc is 0.5460
# after looking at 3232 images, running_acc is 0.4796
# epoch 46 : acc 0.5219
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.2288
# after looking at 1632 images, running_loss is 0.2563
# after looking at 3232 images, running_loss is 0.3370
# after looking at 4832 images, running_loss is 0.3414
# after looking at 6432 images, running_loss is 0.3484
# after looking at 8032 images, running_loss is 0.3477
# epoch 47 : loss 0.3579
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5135
# after looking at 3232 images, running_acc is 0.4360
# epoch 47 : acc 0.4692
# after looking at 32 images, running_loss is 0.4550
# after looking at 1632 images, running_loss is 0.6953
# after looking at 3232 images, running_loss is 0.5651
# after looking at 4832 images, running_loss is 0.5212
# after looking at 6432 images, running_loss is 0.4893
# after looking at 8032 images, running_loss is 0.4768
# epoch 48 : loss 0.4687
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5080
# after looking at 3232 images, running_acc is 0.4601
# epoch 48 : acc 0.5026
# after looking at 32 images, running_loss is 0.2687
# after looking at 1632 images, running_loss is 0.3209
# after looking at 3232 images, running_loss is 0.3254
# after looking at 4832 images, running_loss is 0.3270
# after looking at 6432 images, running_loss is 0.3216
# after looking at 8032 images, running_loss is 0.3352
# epoch 49 : loss 0.3376
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5833
# after looking at 3232 images, running_acc is 0.4867
# epoch 49 : acc 0.5103
# after looking at 32 images, running_loss is 0.2843
# after looking at 1632 images, running_loss is 0.2939
# after looking at 3232 images, running_loss is 0.3217
# after looking at 4832 images, running_loss is 0.3170
# after looking at 6432 images, running_loss is 0.3186
# after looking at 8032 images, running_loss is 0.3265
# epoch 50 : loss 0.3302
# after looking at 32 images, running_acc is 0.3750
# after looking at 1632 images, running_acc is 0.5037
# after looking at 3232 images, running_acc is 0.4335
# epoch 50 : acc 0.4826
# after looking at 32 images, running_loss is 0.2401
# after looking at 1632 images, running_loss is 0.2908
# after looking at 3232 images, running_loss is 0.3068
# after looking at 4832 images, running_loss is 0.3013
# after looking at 6432 images, running_loss is 0.2912
# after looking at 8032 images, running_loss is 0.2916
# epoch 51 : loss 0.3116
# after looking at 32 images, running_acc is 0.5625
# after looking at 1632 images, running_acc is 0.4228
# after looking at 3232 images, running_acc is 0.4069
# epoch 51 : acc 0.4509
# after looking at 32 images, running_loss is 0.4486
# after looking at 1632 images, running_loss is 1.4430
# after looking at 3232 images, running_loss is 1.1741
# after looking at 4832 images, running_loss is 1.0114
# after looking at 6432 images, running_loss is 0.9369
# after looking at 8032 images, running_loss is 0.8679
# epoch 52 : loss 0.8352
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5319
# after looking at 3232 images, running_acc is 0.4372
# epoch 52 : acc 0.4801
# after looking at 32 images, running_loss is 0.4202
# after looking at 1632 images, running_loss is 0.4271
# after looking at 3232 images, running_loss is 0.4125
# after looking at 4832 images, running_loss is 0.4183
# after looking at 6432 images, running_loss is 0.4260
# after looking at 8032 images, running_loss is 0.4226
# epoch 53 : loss 0.4215
# after looking at 32 images, running_acc is 0.5312
# after looking at 1632 images, running_acc is 0.5257
# after looking at 3232 images, running_acc is 0.4520
# epoch 53 : acc 0.5005
# after looking at 32 images, running_loss is 0.2834
# after looking at 1632 images, running_loss is 0.2874
# after looking at 3232 images, running_loss is 0.3253
# after looking at 4832 images, running_loss is 0.3384
# after looking at 6432 images, running_loss is 0.3497
# after looking at 8032 images, running_loss is 0.3496
# epoch 54 : loss 0.3611
# after looking at 32 images, running_acc is 0.3125
# after looking at 1632 images, running_acc is 0.4491
# after looking at 3232 images, running_acc is 0.4471
# epoch 54 : acc 0.4853
# after looking at 32 images, running_loss is 0.3296
# after looking at 1632 images, running_loss is 0.4307
# after looking at 3232 images, running_loss is 0.4123
# after looking at 4832 images, running_loss is 0.3956
# after looking at 6432 images, running_loss is 0.3814
# after looking at 8032 images, running_loss is 0.3749
# epoch 55 : loss 0.3713
# after looking at 32 images, running_acc is 0.5312
# after looking at 1632 images, running_acc is 0.5674
# after looking at 3232 images, running_acc is 0.4712
# epoch 55 : acc 0.5087
# after looking at 32 images, running_loss is 0.1600
# after looking at 1632 images, running_loss is 0.4936
# after looking at 3232 images, running_loss is 0.4383
# after looking at 4832 images, running_loss is 0.4032
# after looking at 6432 images, running_loss is 0.3787
# after looking at 8032 images, running_loss is 0.3764
# epoch 56 : loss 0.3661
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5362
# after looking at 3232 images, running_acc is 0.4641
# epoch 56 : acc 0.5064
# after looking at 32 images, running_loss is 0.0914
# after looking at 1632 images, running_loss is 0.2620
# after looking at 3232 images, running_loss is 0.2658
# after looking at 4832 images, running_loss is 0.2811
# after looking at 6432 images, running_loss is 0.3035
# after looking at 8032 images, running_loss is 0.3167
# epoch 57 : loss 0.3177
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5656
# after looking at 3232 images, running_acc is 0.4805
# Epoch    58: reducing learning rate of group 0 to 1.0000e-03.
# epoch 57 : acc 0.5153
# after looking at 32 images, running_loss is 0.3170
# after looking at 1632 images, running_loss is 0.2048
# after looking at 3232 images, running_loss is 0.1793
# after looking at 4832 images, running_loss is 0.1662
# after looking at 6432 images, running_loss is 0.1614
# after looking at 8032 images, running_loss is 0.1524
# epoch 58 : loss 0.1475
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5723
# after looking at 3232 images, running_acc is 0.4916
# epoch 58 : acc 0.5374
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.0722
# after looking at 1632 images, running_loss is 0.0989
# after looking at 3232 images, running_loss is 0.0940
# after looking at 4832 images, running_loss is 0.0944
# after looking at 6432 images, running_loss is 0.0911
# after looking at 8032 images, running_loss is 0.0888
# epoch 59 : loss 0.0871
# after looking at 32 images, running_acc is 0.7188
# after looking at 1632 images, running_acc is 0.5754
# after looking at 3232 images, running_acc is 0.4889
# epoch 59 : acc 0.5354
# after looking at 32 images, running_loss is 0.0095
# after looking at 1632 images, running_loss is 0.0564
# after looking at 3232 images, running_loss is 0.0659
# after looking at 4832 images, running_loss is 0.0619
# after looking at 6432 images, running_loss is 0.0618
# after looking at 8032 images, running_loss is 0.0618
# epoch 60 : loss 0.0616
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.5723
# after looking at 3232 images, running_acc is 0.4938
# epoch 60 : acc 0.5410
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.0369
# after looking at 1632 images, running_loss is 0.0595
# after looking at 3232 images, running_loss is 0.0603
# after looking at 4832 images, running_loss is 0.0589
# after looking at 6432 images, running_loss is 0.0568
# after looking at 8032 images, running_loss is 0.0569
# epoch 61 : loss 0.0560
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5760
# after looking at 3232 images, running_acc is 0.4898
# epoch 61 : acc 0.5357
# after looking at 32 images, running_loss is 0.0115
# after looking at 1632 images, running_loss is 0.0598
# after looking at 3232 images, running_loss is 0.0533
# after looking at 4832 images, running_loss is 0.0511
# after looking at 6432 images, running_loss is 0.0480
# after looking at 8032 images, running_loss is 0.0463
# epoch 62 : loss 0.0468
# after looking at 32 images, running_acc is 0.6250
# after looking at 1632 images, running_acc is 0.5760
# after looking at 3232 images, running_acc is 0.4926
# epoch 62 : acc 0.5387
# after looking at 32 images, running_loss is 0.0235
# after looking at 1632 images, running_loss is 0.0416
# after looking at 3232 images, running_loss is 0.0437
# after looking at 4832 images, running_loss is 0.0384
# after looking at 6432 images, running_loss is 0.0401
# after looking at 8032 images, running_loss is 0.0408
# epoch 63 : loss 0.0408
# after looking at 32 images, running_acc is 0.7500
# after looking at 1632 images, running_acc is 0.5925
# after looking at 3232 images, running_acc is 0.4938
# epoch 63 : acc 0.5400
# after looking at 32 images, running_loss is 0.0871
# after looking at 1632 images, running_loss is 0.0353
# after looking at 3232 images, running_loss is 0.0339
# after looking at 4832 images, running_loss is 0.0406
# after looking at 6432 images, running_loss is 0.0411
# after looking at 8032 images, running_loss is 0.0402
# epoch 64 : loss 0.0376
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5821
# after looking at 3232 images, running_acc is 0.4960
# epoch 64 : acc 0.5420
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.0022
# after looking at 1632 images, running_loss is 0.0291
# after looking at 3232 images, running_loss is 0.0268
# after looking at 4832 images, running_loss is 0.0262
# after looking at 6432 images, running_loss is 0.0267
# after looking at 8032 images, running_loss is 0.0267
# epoch 65 : loss 0.0263
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.5797
# after looking at 3232 images, running_acc is 0.4935
# epoch 65 : acc 0.5407
# after looking at 32 images, running_loss is 0.0068
# after looking at 1632 images, running_loss is 0.0352
# after looking at 3232 images, running_loss is 0.0300
# after looking at 4832 images, running_loss is 0.0272
# after looking at 6432 images, running_loss is 0.0299
# after looking at 8032 images, running_loss is 0.0289
# epoch 66 : loss 0.0277
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5784
# after looking at 3232 images, running_acc is 0.4935
# epoch 66 : acc 0.5402
# after looking at 32 images, running_loss is 0.0088
# after looking at 1632 images, running_loss is 0.0265
# after looking at 3232 images, running_loss is 0.0301
# after looking at 4832 images, running_loss is 0.0314
# after looking at 6432 images, running_loss is 0.0296
# after looking at 8032 images, running_loss is 0.0287
# epoch 67 : loss 0.0293
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5754
# after looking at 3232 images, running_acc is 0.4950
# epoch 67 : acc 0.5407
# after looking at 32 images, running_loss is 0.0072
# after looking at 1632 images, running_loss is 0.0209
# after looking at 3232 images, running_loss is 0.0221
# after looking at 4832 images, running_loss is 0.0219
# after looking at 6432 images, running_loss is 0.0232
# after looking at 8032 images, running_loss is 0.0231
# epoch 68 : loss 0.0223
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5778
# after looking at 3232 images, running_acc is 0.4950
# epoch 68 : acc 0.5412
# after looking at 32 images, running_loss is 0.0024
# after looking at 1632 images, running_loss is 0.0180
# after looking at 3232 images, running_loss is 0.0197
# after looking at 4832 images, running_loss is 0.0192
# after looking at 6432 images, running_loss is 0.0199
# after looking at 8032 images, running_loss is 0.0215
# epoch 69 : loss 0.0224
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5821
# after looking at 3232 images, running_acc is 0.4960
# epoch 69 : acc 0.5453
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.0043
# after looking at 1632 images, running_loss is 0.0169
# after looking at 3232 images, running_loss is 0.0173
# after looking at 4832 images, running_loss is 0.0187
# after looking at 6432 images, running_loss is 0.0190
# after looking at 8032 images, running_loss is 0.0193
# epoch 70 : loss 0.0188
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.5839
# after looking at 3232 images, running_acc is 0.4932
# epoch 70 : acc 0.5415
# after looking at 32 images, running_loss is 0.0018
# after looking at 1632 images, running_loss is 0.0117
# after looking at 3232 images, running_loss is 0.0162
# after looking at 4832 images, running_loss is 0.0148
# after looking at 6432 images, running_loss is 0.0158
# after looking at 8032 images, running_loss is 0.0164
# epoch 71 : loss 0.0161
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5846
# after looking at 3232 images, running_acc is 0.4957
# epoch 71 : acc 0.5438
# after looking at 32 images, running_loss is 0.0007
# after looking at 1632 images, running_loss is 0.0133
# after looking at 3232 images, running_loss is 0.0216
# after looking at 4832 images, running_loss is 0.0195
# after looking at 6432 images, running_loss is 0.0208
# after looking at 8032 images, running_loss is 0.0203
# epoch 72 : loss 0.0205
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5833
# after looking at 3232 images, running_acc is 0.4991
# epoch 72 : acc 0.5433
# after looking at 32 images, running_loss is 0.0039
# after looking at 1632 images, running_loss is 0.0146
# after looking at 3232 images, running_loss is 0.0121
# after looking at 4832 images, running_loss is 0.0152
# after looking at 6432 images, running_loss is 0.0157
# after looking at 8032 images, running_loss is 0.0163
# epoch 73 : loss 0.0174
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.5772
# after looking at 3232 images, running_acc is 0.4916
# epoch 73 : acc 0.5382

# %%
vgga.conv1a[0].weight
# Out:
# Parameter containing:
# tensor([[[[ 0.2983, -0.1228, -0.0315],
#           [-0.2209, -0.0483,  0.0830],
#           [-0.2935,  0.1417, -0.0425]],
#
#          [[ 0.3703, -0.2143, -0.0730],
#           [-0.1584,  0.0187,  0.1212],
#           [-0.1912,  0.2364,  0.1296]],
#
#          [[ 0.3377, -0.2077,  0.0006],
#           [-0.0964, -0.0875, -0.0648],
#           [-0.0981,  0.1257, -0.0235]]],
#
#
#         [[[-0.0649, -0.2438, -0.1118],
#           [-0.3136, -0.4512, -0.1921],
#           [ 0.0057, -0.1783, -0.1115]],
#
#          [[ 0.3910,  0.3132,  0.2674],
#           [ 0.1644,  0.0979,  0.3389],
#           [ 0.4417,  0.3436,  0.3452]],
#
#          [[-0.0428, -0.1545, -0.0734],
#           [-0.2878, -0.3495, -0.1060],
#           [ 0.0076, -0.1959, -0.1518]]],
#
#
#         [[[ 0.1482, -0.1335,  0.1074],
#           [ 0.2180, -0.2594,  0.1798],
#           [ 0.0822, -0.0970, -0.1130]],
#
#          [[ 0.1133, -0.2634, -0.0017],
#           [ 0.1205, -0.3038,  0.1298],
#           [-0.0171, -0.1376,  0.0080]],
#
#          [[ 0.0463, -0.2432,  0.1830],
#           [ 0.1074, -0.2358,  0.2084],
#           [ 0.0889, -0.0246,  0.0038]]],
#
#
#         ...,
#
#
#         [[[-0.0529,  0.0188,  0.0957],
#           [ 0.0481, -0.0180,  0.1675],
#           [ 0.0522, -0.2243, -0.0293]],
#
#          [[-0.0830, -0.2838, -0.1778],
#           [ 0.0564, -0.1573, -0.0512],
#           [-0.1048, -0.4174, -0.3518]],
#
#          [[ 0.2737,  0.0329,  0.0438],
#           [ 0.2844,  0.1814,  0.1761],
#           [ 0.2346, -0.1171,  0.0762]]],
#
#
#         [[[-0.4859, -0.5641,  0.1036],
#           [ 0.0177,  0.2770,  0.1914],
#           [ 0.0416,  0.2612, -0.2665]],
#
#          [[-0.2537, -0.2840,  0.3006],
#           [ 0.3066,  0.5262,  0.3115],
#           [ 0.1520,  0.3618, -0.3479]],
#
#          [[-0.1521, -0.2660,  0.0945],
#           [ 0.0494,  0.2505, -0.0482],
#           [-0.1685, -0.0214, -0.5767]]],
#
#
#         [[[ 0.2959, -0.1377, -0.0045],
#           [ 0.1830, -0.2151,  0.0081],
#           [-0.1288, -0.0404,  0.2869]],
#
#          [[ 0.2954, -0.1828, -0.0592],
#           [ 0.0865, -0.2431, -0.1351],
#           [-0.3033, -0.2549,  0.1664]],
#
#          [[ 0.3549,  0.0121,  0.0423],
#           [ 0.2089, -0.1557, -0.0958],
#           [-0.2062, -0.1539,  0.2594]]]], device='cuda:0', requires_grad=True)
