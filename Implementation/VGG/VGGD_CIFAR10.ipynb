# %%
from google.colab import drive
drive.mount('/content/gdrive')

MODELPATH = '/content/gdrive/My Drive/Colab Notebooks/yai7_CV1/week2_resnet/modelsave/'
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

# torch.__version__
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
print("torch version:", torch.__version__())
print("check device:", torch.cuda.get_device_name())
print("how many?:", torch.cuda.device_count())
print("so can i use it?", torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-76ec713da3b0> in <module>()
#      10 import matplotlib.pyplot as plt
#      11 get_ipython().magic('matplotlib inline')
# ---> 12 print("torch version:", torch.__version__())
#      13 print("check device:", torch.cuda.get_device_name())
#      14 print("how many?:", torch.cuda.device_count())
#
# TypeError: 'str' object is not callable

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# before loading data,
# need to determine transformation (augmentation)

# %%
# no augmentation yet

"""train_transform = A.Compose([
                             ToTensor()
])

test_transform = A.Compose([
                            ToTensor()
])"""
# Out:
# 'train_transform = A.Compose([\n                             ToTensor()\n])\n\ntest_transform = A.Compose([\n                            ToTensor()\n])'

# %%
train_transform = transforms.Compose([
                             transforms.ToTensor()
])
train_set = torchvision.datasets.CIFAR10(root='/data', train=True, download=True, 
                                         transform=train_transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /data/cifar-10-python.tar.gz to /data

# %%
# page 2
# "The only preprocessing we do is subtracting the mean RGB value, 
# computed on the training set, from each pixel."

mean = 0.0
for image, _ in train_set:
    mean += image.mean([1,2])

mean = mean/len(train_set)
print(mean)

del train_set, train_transform
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %%
# using torchvision transformation
# augmentations : randomcrop, horizontalflip, randomrgbcolorshift
# image for CIFAR10 is too small for randomcrop... so add padding
# paper doesn't say anything about normalization ... so not doing it :P

train_transform = transforms.Compose([
                             transforms.RandomCrop(32, padding=4),
                             transforms.RandomHorizontalFlip(p=0.5),
                             transforms.ToTensor(),
                             transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))
])

test_transform = transforms.Compose([
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))
])

# %%
train_set = torchvision.datasets.CIFAR10(root='/data', train=True, download=True, 
                                         transform=train_transform)

test_set = torchvision.datasets.CIFAR10(root='/data', train=False, download=True, 
                                         transform=test_transform)

# how to retrieve image without using DataLoader?
# just by indexing is good enough
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# checking on the loaded data :0
train_set
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
test_set
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: /data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# from dataset to loader

train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False, num_workers=4)

# seems like num_workers works best when...
# num_workers = num GPU * 4

# %%
# check on the images

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# used for checking if image came out with batchsize=1

"""for image, label in train_loader:
    print(image)
    print(image.dtype)
    print(label)
    print(label.dtype)
    print(image.squeeze_().shape)
    imshow(image)
    break"""
# Out:
# 'for image, label in train_loader:\n    print(image)\n    print(image.dtype)\n    print(label)\n    print(label.dtype)\n    print(image.squeeze_().shape)\n    imshow(image)\n    break'

# %%
# construct architecture for VGG-D
# but will use this for VGG-A :)

class VGGa(nn.Module):
    def __init__(self):
        super(VGGa, self).__init__()

        self.conv1a = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv1d = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2a = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv2d = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv3a = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU())
        
        self.conv3d = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        self.conv4a = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
            )
        self.conv4d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv5a = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        self.conv5d = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )

        # 32 --> 16 --> 8 --> 4 --> 2 --> 1
        # 512 * 1 * 1 = 512
        self.fcd = nn.Linear(512, 10)

        self.fca = nn.Linear(512, 10)

        self.dropout = nn.Dropout(p=0.5)

        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.softmax = nn.Softmax(dim=0)

    def forward(self, x):
        x = self.conv1a(x)
        x = self.maxpool(x)
        x = self.conv2a(x)
        x = self.maxpool(x)
        x = self.conv3a(x)
        x = self.maxpool(x)
        x = self.conv4a(x)
        x = self.maxpool(x)
        x= self.conv5a(x)
        x = self.maxpool(x)
        #print('before view', x.shape)

        # 224 --> 112 --> 56 --> 28 --> 14 --> 7 
        # 512 * 7 * 7 = 25088
        x = x.view(-1, 512)
        #print('after view', x.shape)
        #x = self.dropout(x)
        x = self.fca(x) 
        #x = self.softmax(x)
        return x

# %%
vgga = VGGa()
vgga.to(device)
# Out:
# VGGa(
#   (conv1a): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv1d): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2a): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2d): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv3a): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv3d): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv4a): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv4d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5a): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (conv5d): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (fcd): Linear(in_features=512, out_features=10, bias=True)
#   (fca): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (softmax): Softmax(dim=0)
# )

# %%
# as in the paper,
# init weights with normal distribution
# init biases with zeros

# init all weights and biases

# next time try making this inside the module

def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.normal_(child.weight, mean=0.0, std=0.01)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.normal_(grandchild.weight, mean=0.0, std=0.01)
                    torch.nn.init.zeros_(grandchild.bias)

# %%
"""# try xavier just for fun~

def init_weights(m):

    for i, child in enumerate(m.children()):
        if type(child) is (nn.Linear or nn.Conv2d):
            torch.nn.init.xavier_normal_(child.weight)
            torch.nn.init.zeros_(child.bias)
        elif type(child) == nn.Sequential:
            for j, grandchild in enumerate(child.children()):
                #print(j, grandchild)
                if type(child) is (nn.Linear or nn.Conv2d):
                    torch.nn.init.xavier_normal_(grandchild.weight)
                    torch.nn.init.zeros_(grandchild.bias)"""

# %%
init_weights(vgga)

# %%
# just for checking if initialized correctly

"""for i, child in enumerate(vgga.children()):
    if type(child) == nn.Sequential:
        for j, grandchild in enumerate(child.children()):
            if type(child) is (nn.Linear or nn.Conv2d):
                print(i, j, grandchild)
                print(grandchild.weight)
                print(grandchild.bias)

    else:
        if type(child) is (nn.Linear or nn.Conv2d):
            print(i, child)
            print(child.weight)
            print(child.bias)"""

# seems to work :)
# Out:
# 'for i, child in enumerate(vgga.children()):\n    if type(child) == nn.Sequential:\n        for j, grandchild in enumerate(child.children()):\n            if type(child) is (nn.Linear or nn.Conv2d):\n                print(i, j, grandchild)\n                print(grandchild.weight)\n                print(grandchild.bias)\n\n    else:\n        if type(child) is (nn.Linear or nn.Conv2d):\n            print(i, child)\n            print(child.weight)\n            print(child.bias)'

# %%
# load pretrained model

epoch = 19

vgga.load_state_dict(torch.load(MODELPATH+f'pretrained_{epoch}_epochs', map_location=torch.device(device)))
# Out:
# <All keys matched successfully>

# %%
# create vgg-d from VGGA() :)

vggd = nn.Sequential(
    vgga.conv1a,
    vgga.conv1d,
    vgga.maxpool,
    vgga.conv2a,
    vgga.conv2d,
    vgga.maxpool,
    vgga.conv3a,
    vgga.conv3d,
    vgga.maxpool,
    vgga.conv4a,
    vgga.conv4d,
    vgga.maxpool,
    vgga.conv5a,
    vgga.conv5d,
    vgga.maxpool,
    nn.Flatten(),
    vgga.dropout,
    vgga.fcd
)

vggd.to(device)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (1): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (7): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (9): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (10): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (12): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (13): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (15): Flatten(start_dim=1, end_dim=-1)
#   (16): Dropout(p=0.5, inplace=False)
#   (17): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
def train_one_epoch(model, train_loader, loss_function, optimizer, epoch):
    #model.train()
    length = len(train_loader)
    #pbar = tqdm(enumerate(train_loader), total=length)
    running_loss = 0.0

    for i, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        pred = model(image)
        #print('pred')
        #print(pred.shape)
        #print('label')
        #print(label.shape)
        loss = loss_function(pred, label)
        #print(loss)
        #print(loss.item())
    
        loss.backward()
        
        optimizer.step()

        running_loss += loss.item()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_loss is {running_loss/(i+1):.4f}')
        #pbar.set_description(f'running_loss {running_loss/(i+1):.4f}')

    print(f'epoch {epoch} : loss {running_loss/length:.4f}')


def eval_one_epoch(model, test_loader, scheduler, epoch, best_val_acc):
    #model.eval()
    length = len(test_loader)
    #pbar = tqdm(enumerate(test_loader), total=length)
    running_acc = 0.0

    for i, (image, label) in enumerate(test_loader):
        image, label = image.to(device), label.numpy()

        pred = model(image)
        pred_label = pred.argmax(axis=1).detach().cpu().numpy()
        running_acc += (pred_label==label).mean()

        if i % 50 == 0:
            print(f'after looking at {(i+1)*32} images, running_acc is {running_acc/(i+1):.4f}')
        #pbar.set_description(f'running_acc {running_acc/(i+1):.4f}')

    val_acc = running_acc/length
    scheduler.step(val_acc)

    print(f'epoch {epoch} : acc {val_acc:.4f}')
    
    if val_acc > best_val_acc:
        print("### saving current model...### \n")
        torch.save(model.state_dict(), MODELPATH+f'aftertrain_{epoch}_epochs')
        best_val_acc = val_acc

    return best_val_acc

# %%
# hyperparameters from paper
# assuming same for pretraining

learning_rate = 0.01
momentum = 0.9
weight_decay = 5e-4
epochs = 74

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(vggd.parameters(), lr=learning_rate, 
                            momentum=momentum, weight_decay=weight_decay)

# patience=5 chosen arbitrarily
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.1, patience=5, verbose=True
    )

# %%
best_val_acc = 0.0

for epoch in range(epochs):
    vggd.train()
    train_one_epoch(vggd, train_loader, loss_function, optimizer, epoch)
    vggd.eval()
    best_val_acc = eval_one_epoch(vggd, test_loader, scheduler, epoch, best_val_acc)
# Out:
# after looking at 32 images, running_loss is 2.3032
# after looking at 1632 images, running_loss is 2.3043
# after looking at 3232 images, running_loss is 2.3030
# after looking at 4832 images, running_loss is 2.3035
# after looking at 6432 images, running_loss is 2.3036
# after looking at 8032 images, running_loss is 2.3036
# after looking at 9632 images, running_loss is 2.3037
# after looking at 11232 images, running_loss is 2.3037
# after looking at 12832 images, running_loss is 2.3037
# after looking at 14432 images, running_loss is 2.3036
# after looking at 16032 images, running_loss is 2.3036
# after looking at 17632 images, running_loss is 2.3036
# after looking at 19232 images, running_loss is 2.3036
# after looking at 20832 images, running_loss is 2.3037
# after looking at 22432 images, running_loss is 2.3036
# after looking at 24032 images, running_loss is 2.3037
# after looking at 25632 images, running_loss is 2.3037
# after looking at 27232 images, running_loss is 2.3036
# after looking at 28832 images, running_loss is 2.3035
# after looking at 30432 images, running_loss is 2.3036
# after looking at 32032 images, running_loss is 2.3036
# after looking at 33632 images, running_loss is 2.3036
# after looking at 35232 images, running_loss is 2.3035
# after looking at 36832 images, running_loss is 2.3035
# after looking at 38432 images, running_loss is 2.3035
# after looking at 40032 images, running_loss is 2.3036
# after looking at 41632 images, running_loss is 2.3036
# after looking at 43232 images, running_loss is 2.3036
# after looking at 44832 images, running_loss is 2.3035
# after looking at 46432 images, running_loss is 2.3035
# after looking at 48032 images, running_loss is 2.3035
# after looking at 49632 images, running_loss is 2.3035
# epoch 0 : loss 2.3035
# after looking at 32 images, running_acc is 0.1250
# after looking at 1632 images, running_acc is 0.0962
# after looking at 3232 images, running_acc is 0.0996
# after looking at 4832 images, running_acc is 0.0983
# after looking at 6432 images, running_acc is 0.0993
# after looking at 8032 images, running_acc is 0.1011
# after looking at 9632 images, running_acc is 0.0991
# epoch 0 : acc 0.1000
# ### saving current model...###
#
# after looking at 32 images, running_loss is 2.3066
# after looking at 1632 images, running_loss is 2.3018
# after looking at 3232 images, running_loss is 2.3027
# after looking at 4832 images, running_loss is 2.3030
# after looking at 6432 images, running_loss is 2.3030
# after looking at 8032 images, running_loss is 2.3032
# after looking at 9632 images, running_loss is 2.3034
# after looking at 11232 images, running_loss is 2.3035
# after looking at 12832 images, running_loss is 2.3034
# after looking at 14432 images, running_loss is 2.3034
# after looking at 16032 images, running_loss is 2.3035
# after looking at 17632 images, running_loss is 2.3035
# after looking at 19232 images, running_loss is 2.3034
# after looking at 20832 images, running_loss is 2.3034
# after looking at 22432 images, running_loss is 2.3034
# after looking at 24032 images, running_loss is 2.3035
# after looking at 25632 images, running_loss is 2.3035
# after looking at 27232 images, running_loss is 2.3034
# after looking at 28832 images, running_loss is 2.3035
# after looking at 30432 images, running_loss is 2.3034
# after looking at 32032 images, running_loss is 2.3033
# after looking at 33632 images, running_loss is 2.3034
# after looking at 35232 images, running_loss is 2.3035
# after looking at 36832 images, running_loss is 2.3034
# after looking at 38432 images, running_loss is 2.3034
# after looking at 40032 images, running_loss is 2.3034
# after looking at 41632 images, running_loss is 2.3034
# after looking at 43232 images, running_loss is 2.3033
# after looking at 44832 images, running_loss is 2.3032
# after looking at 46432 images, running_loss is 2.3030
# after looking at 48032 images, running_loss is 2.3020
# after looking at 49632 images, running_loss is 2.2980
# epoch 1 : loss 2.2966
# after looking at 32 images, running_acc is 0.2500
# after looking at 1632 images, running_acc is 0.1740
# after looking at 3232 images, running_acc is 0.1702
# after looking at 4832 images, running_acc is 0.1685
# after looking at 6432 images, running_acc is 0.1709
# after looking at 8032 images, running_acc is 0.1714
# after looking at 9632 images, running_acc is 0.1730
# epoch 1 : acc 0.1730
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.9872
# after looking at 1632 images, running_loss is 2.1307
# after looking at 3232 images, running_loss is 2.0720
# after looking at 4832 images, running_loss is 2.0528
# after looking at 6432 images, running_loss is 2.0304
# after looking at 8032 images, running_loss is 2.0147
# after looking at 9632 images, running_loss is 2.0025
# after looking at 11232 images, running_loss is 1.9916
# after looking at 12832 images, running_loss is 1.9837
# after looking at 14432 images, running_loss is 1.9763
# after looking at 16032 images, running_loss is 1.9667
# after looking at 17632 images, running_loss is 1.9632
# after looking at 19232 images, running_loss is 1.9570
# after looking at 20832 images, running_loss is 1.9537
# after looking at 22432 images, running_loss is 1.9489
# after looking at 24032 images, running_loss is 1.9436
# after looking at 25632 images, running_loss is 1.9406
# after looking at 27232 images, running_loss is 1.9363
# after looking at 28832 images, running_loss is 1.9321
# after looking at 30432 images, running_loss is 1.9283
# after looking at 32032 images, running_loss is 1.9242
# after looking at 33632 images, running_loss is 1.9230
# after looking at 35232 images, running_loss is 1.9191
# after looking at 36832 images, running_loss is 1.9156
# after looking at 38432 images, running_loss is 1.9124
# after looking at 40032 images, running_loss is 1.9081
# after looking at 41632 images, running_loss is 1.9055
# after looking at 43232 images, running_loss is 1.9014
# after looking at 44832 images, running_loss is 1.9001
# after looking at 46432 images, running_loss is 1.8972
# after looking at 48032 images, running_loss is 1.8929
# after looking at 49632 images, running_loss is 1.8899
# epoch 2 : loss 1.8898
# after looking at 32 images, running_acc is 0.3750
# after looking at 1632 images, running_acc is 0.3076
# after looking at 3232 images, running_acc is 0.3140
# after looking at 4832 images, running_acc is 0.3069
# after looking at 6432 images, running_acc is 0.3080
# after looking at 8032 images, running_acc is 0.3044
# after looking at 9632 images, running_acc is 0.3041
# epoch 2 : acc 0.3029
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.9246
# after looking at 1632 images, running_loss is 1.7790
# after looking at 3232 images, running_loss is 1.7822
# after looking at 4832 images, running_loss is 1.7669
# after looking at 6432 images, running_loss is 1.7567
# after looking at 8032 images, running_loss is 1.7443
# after looking at 9632 images, running_loss is 1.7267
# after looking at 11232 images, running_loss is 1.7274
# after looking at 12832 images, running_loss is 1.7254
# after looking at 14432 images, running_loss is 1.7192
# after looking at 16032 images, running_loss is 1.7098
# after looking at 17632 images, running_loss is 1.7088
# after looking at 19232 images, running_loss is 1.7019
# after looking at 20832 images, running_loss is 1.6983
# after looking at 22432 images, running_loss is 1.6890
# after looking at 24032 images, running_loss is 1.6810
# after looking at 25632 images, running_loss is 1.6733
# after looking at 27232 images, running_loss is 1.6693
# after looking at 28832 images, running_loss is 1.6616
# after looking at 30432 images, running_loss is 1.6582
# after looking at 32032 images, running_loss is 1.6497
# after looking at 33632 images, running_loss is 1.6453
# after looking at 35232 images, running_loss is 1.6376
# after looking at 36832 images, running_loss is 1.6305
# after looking at 38432 images, running_loss is 1.6260
# after looking at 40032 images, running_loss is 1.6214
# after looking at 41632 images, running_loss is 1.6188
# after looking at 43232 images, running_loss is 1.6133
# after looking at 44832 images, running_loss is 1.6079
# after looking at 46432 images, running_loss is 1.6035
# after looking at 48032 images, running_loss is 1.5991
# after looking at 49632 images, running_loss is 1.5935
# epoch 3 : loss 1.5919
# after looking at 32 images, running_acc is 0.4688
# after looking at 1632 images, running_acc is 0.4926
# after looking at 3232 images, running_acc is 0.4926
# after looking at 4832 images, running_acc is 0.4954
# after looking at 6432 images, running_acc is 0.4963
# after looking at 8032 images, running_acc is 0.4934
# after looking at 9632 images, running_acc is 0.4956
# epoch 3 : acc 0.4946
# ### saving current model...###
#
# after looking at 32 images, running_loss is 1.1725
# after looking at 1632 images, running_loss is 1.5217
# after looking at 3232 images, running_loss is 1.4843
# after looking at 4832 images, running_loss is 1.4571
# after looking at 6432 images, running_loss is 1.4478
# after looking at 8032 images, running_loss is 1.4289
# after looking at 9632 images, running_loss is 1.4161
# after looking at 11232 images, running_loss is 1.4121
# after looking at 12832 images, running_loss is 1.4103
# after looking at 14432 images, running_loss is 1.4130
# after looking at 16032 images, running_loss is 1.4137
# after looking at 17632 images, running_loss is 1.4026
# after looking at 19232 images, running_loss is 1.3981
# after looking at 20832 images, running_loss is 1.3974
# after looking at 22432 images, running_loss is 1.3892
# after looking at 24032 images, running_loss is 1.3824
# after looking at 25632 images, running_loss is 1.3756
# after looking at 27232 images, running_loss is 1.3679
# after looking at 28832 images, running_loss is 1.3667
# after looking at 30432 images, running_loss is 1.3613
# after looking at 32032 images, running_loss is 1.3533
# after looking at 33632 images, running_loss is 1.3473
# after looking at 35232 images, running_loss is 1.3425
# after looking at 36832 images, running_loss is 1.3370
# after looking at 38432 images, running_loss is 1.3304
# after looking at 40032 images, running_loss is 1.3265
# after looking at 41632 images, running_loss is 1.3207
# after looking at 43232 images, running_loss is 1.3182
# after looking at 44832 images, running_loss is 1.3137
# after looking at 46432 images, running_loss is 1.3090
# after looking at 48032 images, running_loss is 1.3065
# after looking at 49632 images, running_loss is 1.3025
# epoch 4 : loss 1.3008
# after looking at 32 images, running_acc is 0.5000
# after looking at 1632 images, running_acc is 0.5882
# after looking at 3232 images, running_acc is 0.5863
# after looking at 4832 images, running_acc is 0.5840
# after looking at 6432 images, running_acc is 0.5866
# after looking at 8032 images, running_acc is 0.5839
# after looking at 9632 images, running_acc is 0.5850
# epoch 4 : acc 0.5840
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.8317
# after looking at 1632 images, running_loss is 1.1771
# after looking at 3232 images, running_loss is 1.1486
# after looking at 4832 images, running_loss is 1.1405
# after looking at 6432 images, running_loss is 1.1336
# after looking at 8032 images, running_loss is 1.1318
# after looking at 9632 images, running_loss is 1.1288
# after looking at 11232 images, running_loss is 1.1356
# after looking at 12832 images, running_loss is 1.1269
# after looking at 14432 images, running_loss is 1.1375
# after looking at 16032 images, running_loss is 1.1285
# after looking at 17632 images, running_loss is 1.1247
# after looking at 19232 images, running_loss is 1.1235
# after looking at 20832 images, running_loss is 1.1208
# after looking at 22432 images, running_loss is 1.1185
# after looking at 24032 images, running_loss is 1.1251
# after looking at 25632 images, running_loss is 1.1188
# after looking at 27232 images, running_loss is 1.1141
# after looking at 28832 images, running_loss is 1.1135
# after looking at 30432 images, running_loss is 1.1131
# after looking at 32032 images, running_loss is 1.1109
# after looking at 33632 images, running_loss is 1.1092
# after looking at 35232 images, running_loss is 1.1075
# after looking at 36832 images, running_loss is 1.1037
# after looking at 38432 images, running_loss is 1.1025
# after looking at 40032 images, running_loss is 1.0988
# after looking at 41632 images, running_loss is 1.0969
# after looking at 43232 images, running_loss is 1.0963
# after looking at 44832 images, running_loss is 1.0937
# after looking at 46432 images, running_loss is 1.0940
# after looking at 48032 images, running_loss is 1.0931
# after looking at 49632 images, running_loss is 1.0924
# epoch 5 : loss 1.0927
# after looking at 32 images, running_acc is 0.6562
# after looking at 1632 images, running_acc is 0.6440
# after looking at 3232 images, running_acc is 0.6324
# after looking at 4832 images, running_acc is 0.6310
# after looking at 6432 images, running_acc is 0.6211
# after looking at 8032 images, running_acc is 0.6175
# after looking at 9632 images, running_acc is 0.6186
# epoch 5 : acc 0.6172
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.9335
# after looking at 1632 images, running_loss is 0.9946
# after looking at 3232 images, running_loss is 0.9680
# after looking at 4832 images, running_loss is 0.9660
# after looking at 6432 images, running_loss is 0.9639
# after looking at 8032 images, running_loss is 0.9651
# after looking at 9632 images, running_loss is 0.9700
# after looking at 11232 images, running_loss is 0.9706
# after looking at 12832 images, running_loss is 0.9702
# after looking at 14432 images, running_loss is 0.9693
# after looking at 16032 images, running_loss is 0.9715
# after looking at 17632 images, running_loss is 0.9762
# after looking at 19232 images, running_loss is 0.9757
# after looking at 20832 images, running_loss is 0.9711
# after looking at 22432 images, running_loss is 0.9689
# after looking at 24032 images, running_loss is 0.9679
# after looking at 25632 images, running_loss is 0.9705
# after looking at 27232 images, running_loss is 0.9703
# after looking at 28832 images, running_loss is 0.9673
# after looking at 30432 images, running_loss is 0.9649
# after looking at 32032 images, running_loss is 0.9639
# after looking at 33632 images, running_loss is 0.9630
# after looking at 35232 images, running_loss is 0.9653
# after looking at 36832 images, running_loss is 0.9651
# after looking at 38432 images, running_loss is 0.9603
# after looking at 40032 images, running_loss is 0.9578
# after looking at 41632 images, running_loss is 0.9562
# after looking at 43232 images, running_loss is 0.9563
# after looking at 44832 images, running_loss is 0.9561
# after looking at 46432 images, running_loss is 0.9555
# after looking at 48032 images, running_loss is 0.9528
# after looking at 49632 images, running_loss is 0.9528
# epoch 6 : loss 0.9527
# after looking at 32 images, running_acc is 0.6875
# after looking at 1632 images, running_acc is 0.6808
# after looking at 3232 images, running_acc is 0.6866
# after looking at 4832 images, running_acc is 0.6871
# after looking at 6432 images, running_acc is 0.6883
# after looking at 8032 images, running_acc is 0.6870
# after looking at 9632 images, running_acc is 0.6854
# epoch 6 : acc 0.6845
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.9537
# after looking at 1632 images, running_loss is 0.9268
# after looking at 3232 images, running_loss is 0.8881
# after looking at 4832 images, running_loss is 0.8783
# after looking at 6432 images, running_loss is 0.8898
# after looking at 8032 images, running_loss is 0.9078
# after looking at 9632 images, running_loss is 0.8956
# after looking at 11232 images, running_loss is 0.8906
# after looking at 12832 images, running_loss is 0.8817
# after looking at 14432 images, running_loss is 0.8764
# after looking at 16032 images, running_loss is 0.8759
# after looking at 17632 images, running_loss is 0.8859
# after looking at 19232 images, running_loss is 0.8776
# after looking at 20832 images, running_loss is 0.8774
# after looking at 22432 images, running_loss is 0.8747
# after looking at 24032 images, running_loss is 0.8788
# after looking at 25632 images, running_loss is 0.8759
# after looking at 27232 images, running_loss is 0.8756
# after looking at 28832 images, running_loss is 0.8758
# after looking at 30432 images, running_loss is 0.8736
# after looking at 32032 images, running_loss is 0.8733
# after looking at 33632 images, running_loss is 0.8706
# after looking at 35232 images, running_loss is 0.8661
# after looking at 36832 images, running_loss is 0.8688
# after looking at 38432 images, running_loss is 0.8678
# after looking at 40032 images, running_loss is 0.8651
# after looking at 41632 images, running_loss is 0.8646
# after looking at 43232 images, running_loss is 0.8629
# after looking at 44832 images, running_loss is 0.8625
# after looking at 46432 images, running_loss is 0.8607
# after looking at 48032 images, running_loss is 0.8616
# after looking at 49632 images, running_loss is 0.8612
# epoch 7 : loss 0.8598
# after looking at 32 images, running_acc is 0.8125
# after looking at 1632 images, running_acc is 0.7377
# after looking at 3232 images, running_acc is 0.7308
# after looking at 4832 images, running_acc is 0.7332
# after looking at 6432 images, running_acc is 0.7327
# after looking at 8032 images, running_acc is 0.7333
# after looking at 9632 images, running_acc is 0.7354
# epoch 7 : acc 0.7342
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.7706
# after looking at 1632 images, running_loss is 0.7946
# after looking at 3232 images, running_loss is 0.7959
# after looking at 4832 images, running_loss is 0.8083
# after looking at 6432 images, running_loss is 0.8097
# after looking at 8032 images, running_loss is 0.8061
# after looking at 9632 images, running_loss is 0.7997
# after looking at 11232 images, running_loss is 0.8028
# after looking at 12832 images, running_loss is 0.7948
# after looking at 14432 images, running_loss is 0.7980
# after looking at 16032 images, running_loss is 0.7954
# after looking at 17632 images, running_loss is 0.7929
# after looking at 19232 images, running_loss is 0.7984
# after looking at 20832 images, running_loss is 0.8014
# after looking at 22432 images, running_loss is 0.8002
# after looking at 24032 images, running_loss is 0.7998
# after looking at 25632 images, running_loss is 0.7959
# after looking at 27232 images, running_loss is 0.8002
# after looking at 28832 images, running_loss is 0.8012
# after looking at 30432 images, running_loss is 0.7988
# after looking at 32032 images, running_loss is 0.7971
# after looking at 33632 images, running_loss is 0.7958
# after looking at 35232 images, running_loss is 0.7942
# after looking at 36832 images, running_loss is 0.7935
# after looking at 38432 images, running_loss is 0.7938
# after looking at 40032 images, running_loss is 0.7930
# after looking at 41632 images, running_loss is 0.7893
# after looking at 43232 images, running_loss is 0.7890
# after looking at 44832 images, running_loss is 0.7871
# after looking at 46432 images, running_loss is 0.7845
# after looking at 48032 images, running_loss is 0.7843
# after looking at 49632 images, running_loss is 0.7817
# epoch 8 : loss 0.7824
# after looking at 32 images, running_acc is 0.8438
# after looking at 1632 images, running_acc is 0.7518
# after looking at 3232 images, running_acc is 0.7481
# after looking at 4832 images, running_acc is 0.7481
# after looking at 6432 images, running_acc is 0.7435
# after looking at 8032 images, running_acc is 0.7413
# after looking at 9632 images, running_acc is 0.7400
# epoch 8 : acc 0.7395
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.9877
# after looking at 1632 images, running_loss is 0.7169
# after looking at 3232 images, running_loss is 0.7198
# after looking at 4832 images, running_loss is 0.7356
# after looking at 6432 images, running_loss is 0.7299
# after looking at 8032 images, running_loss is 0.7194
# after looking at 9632 images, running_loss is 0.7233
# after looking at 11232 images, running_loss is 0.7245
# after looking at 12832 images, running_loss is 0.7258
# after looking at 14432 images, running_loss is 0.7249
# after looking at 16032 images, running_loss is 0.7259
# after looking at 17632 images, running_loss is 0.7274
# after looking at 19232 images, running_loss is 0.7326
# after looking at 20832 images, running_loss is 0.7267
# after looking at 22432 images, running_loss is 0.7237
# after looking at 24032 images, running_loss is 0.7227
# after looking at 25632 images, running_loss is 0.7247
# after looking at 27232 images, running_loss is 0.7226
# after looking at 28832 images, running_loss is 0.7211
# after looking at 30432 images, running_loss is 0.7220
# after looking at 32032 images, running_loss is 0.7215
# after looking at 33632 images, running_loss is 0.7225
# after looking at 35232 images, running_loss is 0.7207
# after looking at 36832 images, running_loss is 0.7241
# after looking at 38432 images, running_loss is 0.7216
# after looking at 40032 images, running_loss is 0.7211
# after looking at 41632 images, running_loss is 0.7189
# after looking at 43232 images, running_loss is 0.7179
# after looking at 44832 images, running_loss is 0.7159
# after looking at 46432 images, running_loss is 0.7147
# after looking at 48032 images, running_loss is 0.7119
# after looking at 49632 images, running_loss is 0.7087
# epoch 9 : loss 0.7082
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.7843
# after looking at 3232 images, running_acc is 0.7751
# after looking at 4832 images, running_acc is 0.7771
# after looking at 6432 images, running_acc is 0.7732
# after looking at 8032 images, running_acc is 0.7758
# after looking at 9632 images, running_acc is 0.7772
# epoch 9 : acc 0.7754
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.7561
# after looking at 1632 images, running_loss is 0.6404
# after looking at 3232 images, running_loss is 0.6461
# after looking at 4832 images, running_loss is 0.6714
# after looking at 6432 images, running_loss is 0.6675
# after looking at 8032 images, running_loss is 0.6696
# after looking at 9632 images, running_loss is 0.6655
# after looking at 11232 images, running_loss is 0.6687
# after looking at 12832 images, running_loss is 0.6659
# after looking at 14432 images, running_loss is 0.6630
# after looking at 16032 images, running_loss is 0.6633
# after looking at 17632 images, running_loss is 0.6613
# after looking at 19232 images, running_loss is 0.6571
# after looking at 20832 images, running_loss is 0.6575
# after looking at 22432 images, running_loss is 0.6574
# after looking at 24032 images, running_loss is 0.6613
# after looking at 25632 images, running_loss is 0.6630
# after looking at 27232 images, running_loss is 0.6617
# after looking at 28832 images, running_loss is 0.6590
# after looking at 30432 images, running_loss is 0.6617
# after looking at 32032 images, running_loss is 0.6609
# after looking at 33632 images, running_loss is 0.6572
# after looking at 35232 images, running_loss is 0.6560
# after looking at 36832 images, running_loss is 0.6559
# after looking at 38432 images, running_loss is 0.6555
# after looking at 40032 images, running_loss is 0.6571
# after looking at 41632 images, running_loss is 0.6556
# after looking at 43232 images, running_loss is 0.6574
# after looking at 44832 images, running_loss is 0.6562
# after looking at 46432 images, running_loss is 0.6542
# after looking at 48032 images, running_loss is 0.6539
# after looking at 49632 images, running_loss is 0.6533
# epoch 10 : loss 0.6535
# after looking at 32 images, running_acc is 0.8438
# after looking at 1632 images, running_acc is 0.7929
# after looking at 3232 images, running_acc is 0.7856
# after looking at 4832 images, running_acc is 0.7875
# after looking at 6432 images, running_acc is 0.7858
# after looking at 8032 images, running_acc is 0.7819
# after looking at 9632 images, running_acc is 0.7837
# epoch 10 : acc 0.7824
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.6755
# after looking at 1632 images, running_loss is 0.6688
# after looking at 3232 images, running_loss is 0.6192
# after looking at 4832 images, running_loss is 0.6203
# after looking at 6432 images, running_loss is 0.6030
# after looking at 8032 images, running_loss is 0.6064
# after looking at 9632 images, running_loss is 0.6119
# after looking at 11232 images, running_loss is 0.6179
# after looking at 12832 images, running_loss is 0.6171
# after looking at 14432 images, running_loss is 0.6241
# after looking at 16032 images, running_loss is 0.6226
# after looking at 17632 images, running_loss is 0.6224
# after looking at 19232 images, running_loss is 0.6210
# after looking at 20832 images, running_loss is 0.6209
# after looking at 22432 images, running_loss is 0.6231
# after looking at 24032 images, running_loss is 0.6216
# after looking at 25632 images, running_loss is 0.6211
# after looking at 27232 images, running_loss is 0.6244
# after looking at 28832 images, running_loss is 0.6245
# after looking at 30432 images, running_loss is 0.6250
# after looking at 32032 images, running_loss is 0.6246
# after looking at 33632 images, running_loss is 0.6239
# after looking at 35232 images, running_loss is 0.6239
# after looking at 36832 images, running_loss is 0.6240
# after looking at 38432 images, running_loss is 0.6248
# after looking at 40032 images, running_loss is 0.6241
# after looking at 41632 images, running_loss is 0.6214
# after looking at 43232 images, running_loss is 0.6211
# after looking at 44832 images, running_loss is 0.6201
# after looking at 46432 images, running_loss is 0.6200
# after looking at 48032 images, running_loss is 0.6188
# after looking at 49632 images, running_loss is 0.6175
# epoch 11 : loss 0.6178
# after looking at 32 images, running_acc is 0.7812
# after looking at 1632 images, running_acc is 0.7812
# after looking at 3232 images, running_acc is 0.7766
# after looking at 4832 images, running_acc is 0.7796
# after looking at 6432 images, running_acc is 0.7812
# after looking at 8032 images, running_acc is 0.7821
# after looking at 9632 images, running_acc is 0.7819
# epoch 11 : acc 0.7812
# after looking at 32 images, running_loss is 0.9735
# after looking at 1632 images, running_loss is 0.5419
# after looking at 3232 images, running_loss is 0.5524
# after looking at 4832 images, running_loss is 0.5623
# after looking at 6432 images, running_loss is 0.5610
# after looking at 8032 images, running_loss is 0.5686
# after looking at 9632 images, running_loss is 0.5697
# after looking at 11232 images, running_loss is 0.5745
# after looking at 12832 images, running_loss is 0.5764
# after looking at 14432 images, running_loss is 0.5763
# after looking at 16032 images, running_loss is 0.5784
# after looking at 17632 images, running_loss is 0.5729
# after looking at 19232 images, running_loss is 0.5777
# after looking at 20832 images, running_loss is 0.5815
# after looking at 22432 images, running_loss is 0.5808
# after looking at 24032 images, running_loss is 0.5825
# after looking at 25632 images, running_loss is 0.5842
# after looking at 27232 images, running_loss is 0.5811
# after looking at 28832 images, running_loss is 0.5794
# after looking at 30432 images, running_loss is 0.5803
# after looking at 32032 images, running_loss is 0.5790
# after looking at 33632 images, running_loss is 0.5799
# after looking at 35232 images, running_loss is 0.5779
# after looking at 36832 images, running_loss is 0.5773
# after looking at 38432 images, running_loss is 0.5754
# after looking at 40032 images, running_loss is 0.5735
# after looking at 41632 images, running_loss is 0.5731
# after looking at 43232 images, running_loss is 0.5743
# after looking at 44832 images, running_loss is 0.5729
# after looking at 46432 images, running_loss is 0.5733
# after looking at 48032 images, running_loss is 0.5739
# after looking at 49632 images, running_loss is 0.5741
# epoch 12 : loss 0.5742
# after looking at 32 images, running_acc is 0.8125
# after looking at 1632 images, running_acc is 0.8021
# after looking at 3232 images, running_acc is 0.7992
# after looking at 4832 images, running_acc is 0.8019
# after looking at 6432 images, running_acc is 0.7994
# after looking at 8032 images, running_acc is 0.7987
# after looking at 9632 images, running_acc is 0.7980
# epoch 12 : acc 0.7964
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.2995
# after looking at 1632 images, running_loss is 0.5497
# after looking at 3232 images, running_loss is 0.5810
# after looking at 4832 images, running_loss is 0.5616
# after looking at 6432 images, running_loss is 0.5636
# after looking at 8032 images, running_loss is 0.5513
# after looking at 9632 images, running_loss is 0.5613
# after looking at 11232 images, running_loss is 0.5627
# after looking at 12832 images, running_loss is 0.5622
# after looking at 14432 images, running_loss is 0.5612
# after looking at 16032 images, running_loss is 0.5594
# after looking at 17632 images, running_loss is 0.5562
# after looking at 19232 images, running_loss is 0.5553
# after looking at 20832 images, running_loss is 0.5536
# after looking at 22432 images, running_loss is 0.5525
# after looking at 24032 images, running_loss is 0.5528
# after looking at 25632 images, running_loss is 0.5479
# after looking at 27232 images, running_loss is 0.5527
# after looking at 28832 images, running_loss is 0.5516
# after looking at 30432 images, running_loss is 0.5510
# after looking at 32032 images, running_loss is 0.5503
# after looking at 33632 images, running_loss is 0.5513
# after looking at 35232 images, running_loss is 0.5532
# after looking at 36832 images, running_loss is 0.5537
# after looking at 38432 images, running_loss is 0.5533
# after looking at 40032 images, running_loss is 0.5529
# after looking at 41632 images, running_loss is 0.5541
# after looking at 43232 images, running_loss is 0.5533
# after looking at 44832 images, running_loss is 0.5536
# after looking at 46432 images, running_loss is 0.5556
# after looking at 48032 images, running_loss is 0.5559
# after looking at 49632 images, running_loss is 0.5564
# epoch 13 : loss 0.5570
# after looking at 32 images, running_acc is 0.9062
# after looking at 1632 images, running_acc is 0.8125
# after looking at 3232 images, running_acc is 0.8079
# after looking at 4832 images, running_acc is 0.8125
# after looking at 6432 images, running_acc is 0.8123
# after looking at 8032 images, running_acc is 0.8134
# after looking at 9632 images, running_acc is 0.8132
# epoch 13 : acc 0.8132
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.1926
# after looking at 1632 images, running_loss is 0.4972
# after looking at 3232 images, running_loss is 0.4817
# after looking at 4832 images, running_loss is 0.4982
# after looking at 6432 images, running_loss is 0.4983
# after looking at 8032 images, running_loss is 0.4952
# after looking at 9632 images, running_loss is 0.5114
# after looking at 11232 images, running_loss is 0.5162
# after looking at 12832 images, running_loss is 0.5208
# after looking at 14432 images, running_loss is 0.5240
# after looking at 16032 images, running_loss is 0.5318
# after looking at 17632 images, running_loss is 0.5330
# after looking at 19232 images, running_loss is 0.5327
# after looking at 20832 images, running_loss is 0.5322
# after looking at 22432 images, running_loss is 0.5298
# after looking at 24032 images, running_loss is 0.5284
# after looking at 25632 images, running_loss is 0.5298
# after looking at 27232 images, running_loss is 0.5286
# after looking at 28832 images, running_loss is 0.5271
# after looking at 30432 images, running_loss is 0.5246
# after looking at 32032 images, running_loss is 0.5249
# after looking at 33632 images, running_loss is 0.5246
# after looking at 35232 images, running_loss is 0.5237
# after looking at 36832 images, running_loss is 0.5244
# after looking at 38432 images, running_loss is 0.5261
# after looking at 40032 images, running_loss is 0.5282
# after looking at 41632 images, running_loss is 0.5280
# after looking at 43232 images, running_loss is 0.5268
# after looking at 44832 images, running_loss is 0.5273
# after looking at 46432 images, running_loss is 0.5283
# after looking at 48032 images, running_loss is 0.5273
# after looking at 49632 images, running_loss is 0.5268
# epoch 14 : loss 0.5269
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8272
# after looking at 3232 images, running_acc is 0.8246
# after looking at 4832 images, running_acc is 0.8299
# after looking at 6432 images, running_acc is 0.8304
# after looking at 8032 images, running_acc is 0.8294
# after looking at 9632 images, running_acc is 0.8295
# epoch 14 : acc 0.8280
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5460
# after looking at 1632 images, running_loss is 0.5025
# after looking at 3232 images, running_loss is 0.4802
# after looking at 4832 images, running_loss is 0.4867
# after looking at 6432 images, running_loss is 0.4882
# after looking at 8032 images, running_loss is 0.4934
# after looking at 9632 images, running_loss is 0.4969
# after looking at 11232 images, running_loss is 0.5035
# after looking at 12832 images, running_loss is 0.5053
# after looking at 14432 images, running_loss is 0.5027
# after looking at 16032 images, running_loss is 0.5016
# after looking at 17632 images, running_loss is 0.5030
# after looking at 19232 images, running_loss is 0.5040
# after looking at 20832 images, running_loss is 0.5054
# after looking at 22432 images, running_loss is 0.5052
# after looking at 24032 images, running_loss is 0.5046
# after looking at 25632 images, running_loss is 0.5019
# after looking at 27232 images, running_loss is 0.5052
# after looking at 28832 images, running_loss is 0.5045
# after looking at 30432 images, running_loss is 0.5036
# after looking at 32032 images, running_loss is 0.5029
# after looking at 33632 images, running_loss is 0.5028
# after looking at 35232 images, running_loss is 0.5026
# after looking at 36832 images, running_loss is 0.5042
# after looking at 38432 images, running_loss is 0.5046
# after looking at 40032 images, running_loss is 0.5063
# after looking at 41632 images, running_loss is 0.5058
# after looking at 43232 images, running_loss is 0.5061
# after looking at 44832 images, running_loss is 0.5059
# after looking at 46432 images, running_loss is 0.5057
# after looking at 48032 images, running_loss is 0.5047
# after looking at 49632 images, running_loss is 0.5039
# epoch 15 : loss 0.5038
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8382
# after looking at 3232 images, running_acc is 0.8301
# after looking at 4832 images, running_acc is 0.8344
# after looking at 6432 images, running_acc is 0.8388
# after looking at 8032 images, running_acc is 0.8394
# after looking at 9632 images, running_acc is 0.8400
# epoch 15 : acc 0.8392
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5209
# after looking at 1632 images, running_loss is 0.4538
# after looking at 3232 images, running_loss is 0.4726
# after looking at 4832 images, running_loss is 0.4784
# after looking at 6432 images, running_loss is 0.4760
# after looking at 8032 images, running_loss is 0.4831
# after looking at 9632 images, running_loss is 0.4855
# after looking at 11232 images, running_loss is 0.4864
# after looking at 12832 images, running_loss is 0.4838
# after looking at 14432 images, running_loss is 0.4892
# after looking at 16032 images, running_loss is 0.4874
# after looking at 17632 images, running_loss is 0.4867
# after looking at 19232 images, running_loss is 0.4857
# after looking at 20832 images, running_loss is 0.4842
# after looking at 22432 images, running_loss is 0.4856
# after looking at 24032 images, running_loss is 0.4844
# after looking at 25632 images, running_loss is 0.4816
# after looking at 27232 images, running_loss is 0.4843
# after looking at 28832 images, running_loss is 0.4854
# after looking at 30432 images, running_loss is 0.4873
# after looking at 32032 images, running_loss is 0.4890
# after looking at 33632 images, running_loss is 0.4878
# after looking at 35232 images, running_loss is 0.4883
# after looking at 36832 images, running_loss is 0.4875
# after looking at 38432 images, running_loss is 0.4871
# after looking at 40032 images, running_loss is 0.4858
# after looking at 41632 images, running_loss is 0.4855
# after looking at 43232 images, running_loss is 0.4870
# after looking at 44832 images, running_loss is 0.4852
# after looking at 46432 images, running_loss is 0.4859
# after looking at 48032 images, running_loss is 0.4854
# after looking at 49632 images, running_loss is 0.4872
# epoch 16 : loss 0.4870
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8468
# after looking at 3232 images, running_acc is 0.8345
# after looking at 4832 images, running_acc is 0.8384
# after looking at 6432 images, running_acc is 0.8411
# after looking at 8032 images, running_acc is 0.8406
# after looking at 9632 images, running_acc is 0.8386
# epoch 16 : acc 0.8373
# after looking at 32 images, running_loss is 0.4414
# after looking at 1632 images, running_loss is 0.4416
# after looking at 3232 images, running_loss is 0.4555
# after looking at 4832 images, running_loss is 0.4557
# after looking at 6432 images, running_loss is 0.4503
# after looking at 8032 images, running_loss is 0.4444
# after looking at 9632 images, running_loss is 0.4458
# after looking at 11232 images, running_loss is 0.4514
# after looking at 12832 images, running_loss is 0.4462
# after looking at 14432 images, running_loss is 0.4424
# after looking at 16032 images, running_loss is 0.4454
# after looking at 17632 images, running_loss is 0.4524
# after looking at 19232 images, running_loss is 0.4563
# after looking at 20832 images, running_loss is 0.4568
# after looking at 22432 images, running_loss is 0.4598
# after looking at 24032 images, running_loss is 0.4584
# after looking at 25632 images, running_loss is 0.4631
# after looking at 27232 images, running_loss is 0.4671
# after looking at 28832 images, running_loss is 0.4655
# after looking at 30432 images, running_loss is 0.4659
# after looking at 32032 images, running_loss is 0.4670
# after looking at 33632 images, running_loss is 0.4668
# after looking at 35232 images, running_loss is 0.4659
# after looking at 36832 images, running_loss is 0.4646
# after looking at 38432 images, running_loss is 0.4645
# after looking at 40032 images, running_loss is 0.4653
# after looking at 41632 images, running_loss is 0.4659
# after looking at 43232 images, running_loss is 0.4655
# after looking at 44832 images, running_loss is 0.4646
# after looking at 46432 images, running_loss is 0.4648
# after looking at 48032 images, running_loss is 0.4658
# after looking at 49632 images, running_loss is 0.4662
# epoch 17 : loss 0.4655
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8272
# after looking at 3232 images, running_acc is 0.8274
# after looking at 4832 images, running_acc is 0.8338
# after looking at 6432 images, running_acc is 0.8380
# after looking at 8032 images, running_acc is 0.8378
# after looking at 9632 images, running_acc is 0.8382
# epoch 17 : acc 0.8374
# after looking at 32 images, running_loss is 0.3400
# after looking at 1632 images, running_loss is 0.4094
# after looking at 3232 images, running_loss is 0.4481
# after looking at 4832 images, running_loss is 0.4448
# after looking at 6432 images, running_loss is 0.4471
# after looking at 8032 images, running_loss is 0.4557
# after looking at 9632 images, running_loss is 0.4559
# after looking at 11232 images, running_loss is 0.4541
# after looking at 12832 images, running_loss is 0.4572
# after looking at 14432 images, running_loss is 0.4526
# after looking at 16032 images, running_loss is 0.4515
# after looking at 17632 images, running_loss is 0.4541
# after looking at 19232 images, running_loss is 0.4556
# after looking at 20832 images, running_loss is 0.4530
# after looking at 22432 images, running_loss is 0.4528
# after looking at 24032 images, running_loss is 0.4515
# after looking at 25632 images, running_loss is 0.4500
# after looking at 27232 images, running_loss is 0.4504
# after looking at 28832 images, running_loss is 0.4524
# after looking at 30432 images, running_loss is 0.4504
# after looking at 32032 images, running_loss is 0.4498
# after looking at 33632 images, running_loss is 0.4521
# after looking at 35232 images, running_loss is 0.4522
# after looking at 36832 images, running_loss is 0.4509
# after looking at 38432 images, running_loss is 0.4514
# after looking at 40032 images, running_loss is 0.4529
# after looking at 41632 images, running_loss is 0.4536
# after looking at 43232 images, running_loss is 0.4523
# after looking at 44832 images, running_loss is 0.4533
# after looking at 46432 images, running_loss is 0.4521
# after looking at 48032 images, running_loss is 0.4529
# after looking at 49632 images, running_loss is 0.4528
# epoch 18 : loss 0.4529
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8223
# after looking at 3232 images, running_acc is 0.8199
# after looking at 4832 images, running_acc is 0.8206
# after looking at 6432 images, running_acc is 0.8218
# after looking at 8032 images, running_acc is 0.8240
# after looking at 9632 images, running_acc is 0.8241
# epoch 18 : acc 0.8239
# after looking at 32 images, running_loss is 0.6362
# after looking at 1632 images, running_loss is 0.4611
# after looking at 3232 images, running_loss is 0.4472
# after looking at 4832 images, running_loss is 0.4461
# after looking at 6432 images, running_loss is 0.4346
# after looking at 8032 images, running_loss is 0.4277
# after looking at 9632 images, running_loss is 0.4283
# after looking at 11232 images, running_loss is 0.4354
# after looking at 12832 images, running_loss is 0.4382
# after looking at 14432 images, running_loss is 0.4327
# after looking at 16032 images, running_loss is 0.4331
# after looking at 17632 images, running_loss is 0.4328
# after looking at 19232 images, running_loss is 0.4347
# after looking at 20832 images, running_loss is 0.4367
# after looking at 22432 images, running_loss is 0.4390
# after looking at 24032 images, running_loss is 0.4366
# after looking at 25632 images, running_loss is 0.4393
# after looking at 27232 images, running_loss is 0.4404
# after looking at 28832 images, running_loss is 0.4399
# after looking at 30432 images, running_loss is 0.4396
# after looking at 32032 images, running_loss is 0.4386
# after looking at 33632 images, running_loss is 0.4380
# after looking at 35232 images, running_loss is 0.4351
# after looking at 36832 images, running_loss is 0.4350
# after looking at 38432 images, running_loss is 0.4362
# after looking at 40032 images, running_loss is 0.4354
# after looking at 41632 images, running_loss is 0.4359
# after looking at 43232 images, running_loss is 0.4362
# after looking at 44832 images, running_loss is 0.4364
# after looking at 46432 images, running_loss is 0.4369
# after looking at 48032 images, running_loss is 0.4365
# after looking at 49632 images, running_loss is 0.4370
# epoch 19 : loss 0.4367
# after looking at 32 images, running_acc is 0.8750
# after looking at 1632 images, running_acc is 0.8352
# after looking at 3232 images, running_acc is 0.8171
# after looking at 4832 images, running_acc is 0.8181
# after looking at 6432 images, running_acc is 0.8206
# after looking at 8032 images, running_acc is 0.8207
# after looking at 9632 images, running_acc is 0.8206
# epoch 19 : acc 0.8203
# after looking at 32 images, running_loss is 0.6128
# after looking at 1632 images, running_loss is 0.3683
# after looking at 3232 images, running_loss is 0.3975
# after looking at 4832 images, running_loss is 0.3992
# after looking at 6432 images, running_loss is 0.4117
# after looking at 8032 images, running_loss is 0.4121
# after looking at 9632 images, running_loss is 0.4088
# after looking at 11232 images, running_loss is 0.4109
# after looking at 12832 images, running_loss is 0.4165
# after looking at 14432 images, running_loss is 0.4269
# after looking at 16032 images, running_loss is 0.4264
# after looking at 17632 images, running_loss is 0.4217
# after looking at 19232 images, running_loss is 0.4209
# after looking at 20832 images, running_loss is 0.4179
# after looking at 22432 images, running_loss is 0.4183
# after looking at 24032 images, running_loss is 0.4186
# after looking at 25632 images, running_loss is 0.4187
# after looking at 27232 images, running_loss is 0.4217
# after looking at 28832 images, running_loss is 0.4194
# after looking at 30432 images, running_loss is 0.4206
# after looking at 32032 images, running_loss is 0.4211
# after looking at 33632 images, running_loss is 0.4194
# after looking at 35232 images, running_loss is 0.4207
# after looking at 36832 images, running_loss is 0.4218
# after looking at 38432 images, running_loss is 0.4235
# after looking at 40032 images, running_loss is 0.4244
# after looking at 41632 images, running_loss is 0.4249
# after looking at 43232 images, running_loss is 0.4251
# after looking at 44832 images, running_loss is 0.4255
# after looking at 46432 images, running_loss is 0.4239
# after looking at 48032 images, running_loss is 0.4236
# after looking at 49632 images, running_loss is 0.4237
# epoch 20 : loss 0.4241
# after looking at 32 images, running_acc is 0.9062
# after looking at 1632 images, running_acc is 0.8511
# after looking at 3232 images, running_acc is 0.8422
# after looking at 4832 images, running_acc is 0.8452
# after looking at 6432 images, running_acc is 0.8424
# after looking at 8032 images, running_acc is 0.8434
# after looking at 9632 images, running_acc is 0.8434
# epoch 20 : acc 0.8429
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.2874
# after looking at 1632 images, running_loss is 0.3785
# after looking at 3232 images, running_loss is 0.3894
# after looking at 4832 images, running_loss is 0.3951
# after looking at 6432 images, running_loss is 0.4005
# after looking at 8032 images, running_loss is 0.3983
# after looking at 9632 images, running_loss is 0.3973
# after looking at 11232 images, running_loss is 0.4003
# after looking at 12832 images, running_loss is 0.3999
# after looking at 14432 images, running_loss is 0.4010
# after looking at 16032 images, running_loss is 0.4037
# after looking at 17632 images, running_loss is 0.4012
# after looking at 19232 images, running_loss is 0.4028
# after looking at 20832 images, running_loss is 0.4027
# after looking at 22432 images, running_loss is 0.4082
# after looking at 24032 images, running_loss is 0.4121
# after looking at 25632 images, running_loss is 0.4119
# after looking at 27232 images, running_loss is 0.4134
# after looking at 28832 images, running_loss is 0.4113
# after looking at 30432 images, running_loss is 0.4097
# after looking at 32032 images, running_loss is 0.4128
# after looking at 33632 images, running_loss is 0.4157
# after looking at 35232 images, running_loss is 0.4150
# after looking at 36832 images, running_loss is 0.4150
# after looking at 38432 images, running_loss is 0.4153
# after looking at 40032 images, running_loss is 0.4144
# after looking at 41632 images, running_loss is 0.4131
# after looking at 43232 images, running_loss is 0.4127
# after looking at 44832 images, running_loss is 0.4131
# after looking at 46432 images, running_loss is 0.4117
# after looking at 48032 images, running_loss is 0.4134
# after looking at 49632 images, running_loss is 0.4148
# epoch 21 : loss 0.4152
# after looking at 32 images, running_acc is 0.7812
# after looking at 1632 images, running_acc is 0.8487
# after looking at 3232 images, running_acc is 0.8475
# after looking at 4832 images, running_acc is 0.8504
# after looking at 6432 images, running_acc is 0.8521
# after looking at 8032 images, running_acc is 0.8523
# after looking at 9632 images, running_acc is 0.8515
# epoch 21 : acc 0.8506
# ### saving current model...###
#
# after looking at 32 images, running_loss is 0.5322
# after looking at 1632 images, running_loss is 0.3637
# after looking at 3232 images, running_loss is 0.3827
# after looking at 4832 images, running_loss is 0.3740
# after looking at 6432 images, running_loss is 0.3895
# after looking at 8032 images, running_loss is 0.3948
# after looking at 9632 images, running_loss is 0.3921
# after looking at 11232 images, running_loss is 0.3873
# after looking at 12832 images, running_loss is 0.3941
# after looking at 14432 images, running_loss is 0.3946
# after looking at 16032 images, running_loss is 0.3906
# after looking at 17632 images, running_loss is 0.3903
# ...
# after looking at 32032 images, running_loss is 0.0296
# after looking at 33632 images, running_loss is 0.0297
# after looking at 35232 images, running_loss is 0.0307
# after looking at 36832 images, running_loss is 0.0309
# after looking at 38432 images, running_loss is 0.0309
# after looking at 40032 images, running_loss is 0.0307
# after looking at 41632 images, running_loss is 0.0305
# after looking at 43232 images, running_loss is 0.0307
# after looking at 44832 images, running_loss is 0.0307
# after looking at 46432 images, running_loss is 0.0305
# after looking at 48032 images, running_loss is 0.0301
# after looking at 49632 images, running_loss is 0.0301
# epoch 66 : loss 0.0303
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9124
# after looking at 3232 images, running_acc is 0.9097
# after looking at 4832 images, running_acc is 0.9123
# after looking at 6432 images, running_acc is 0.9139
# after looking at 8032 images, running_acc is 0.9150
# after looking at 9632 images, running_acc is 0.9162
# epoch 66 : acc 0.9165
# after looking at 32 images, running_loss is 0.0031
# after looking at 1632 images, running_loss is 0.0382
# after looking at 3232 images, running_loss is 0.0305
# after looking at 4832 images, running_loss is 0.0355
# after looking at 6432 images, running_loss is 0.0331
# after looking at 8032 images, running_loss is 0.0313
# after looking at 9632 images, running_loss is 0.0309
# after looking at 11232 images, running_loss is 0.0293
# after looking at 12832 images, running_loss is 0.0289
# after looking at 14432 images, running_loss is 0.0298
# after looking at 16032 images, running_loss is 0.0289
# after looking at 17632 images, running_loss is 0.0285
# after looking at 19232 images, running_loss is 0.0285
# after looking at 20832 images, running_loss is 0.0290
# after looking at 22432 images, running_loss is 0.0287
# after looking at 24032 images, running_loss is 0.0294
# after looking at 25632 images, running_loss is 0.0285
# after looking at 27232 images, running_loss is 0.0288
# after looking at 28832 images, running_loss is 0.0290
# after looking at 30432 images, running_loss is 0.0290
# after looking at 32032 images, running_loss is 0.0292
# after looking at 33632 images, running_loss is 0.0293
# after looking at 35232 images, running_loss is 0.0292
# after looking at 36832 images, running_loss is 0.0289
# after looking at 38432 images, running_loss is 0.0292
# after looking at 40032 images, running_loss is 0.0293
# after looking at 41632 images, running_loss is 0.0295
# after looking at 43232 images, running_loss is 0.0297
# after looking at 44832 images, running_loss is 0.0302
# after looking at 46432 images, running_loss is 0.0301
# after looking at 48032 images, running_loss is 0.0301
# after looking at 49632 images, running_loss is 0.0301
# epoch 67 : loss 0.0302
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9130
# after looking at 3232 images, running_acc is 0.9093
# after looking at 4832 images, running_acc is 0.9110
# after looking at 6432 images, running_acc is 0.9128
# after looking at 8032 images, running_acc is 0.9136
# after looking at 9632 images, running_acc is 0.9149
# epoch 67 : acc 0.9154
# after looking at 32 images, running_loss is 0.0281
# after looking at 1632 images, running_loss is 0.0271
# after looking at 3232 images, running_loss is 0.0288
# after looking at 4832 images, running_loss is 0.0314
# after looking at 6432 images, running_loss is 0.0297
# after looking at 8032 images, running_loss is 0.0329
# after looking at 9632 images, running_loss is 0.0319
# after looking at 11232 images, running_loss is 0.0311
# after looking at 12832 images, running_loss is 0.0312
# after looking at 14432 images, running_loss is 0.0304
# after looking at 16032 images, running_loss is 0.0294
# after looking at 17632 images, running_loss is 0.0311
# after looking at 19232 images, running_loss is 0.0306
# after looking at 20832 images, running_loss is 0.0302
# after looking at 22432 images, running_loss is 0.0295
# after looking at 24032 images, running_loss is 0.0293
# after looking at 25632 images, running_loss is 0.0303
# after looking at 27232 images, running_loss is 0.0301
# after looking at 28832 images, running_loss is 0.0300
# after looking at 30432 images, running_loss is 0.0298
# after looking at 32032 images, running_loss is 0.0300
# after looking at 33632 images, running_loss is 0.0303
# after looking at 35232 images, running_loss is 0.0299
# after looking at 36832 images, running_loss is 0.0302
# after looking at 38432 images, running_loss is 0.0297
# after looking at 40032 images, running_loss is 0.0294
# after looking at 41632 images, running_loss is 0.0296
# after looking at 43232 images, running_loss is 0.0296
# after looking at 44832 images, running_loss is 0.0297
# after looking at 46432 images, running_loss is 0.0299
# after looking at 48032 images, running_loss is 0.0296
# after looking at 49632 images, running_loss is 0.0293
# epoch 68 : loss 0.0293
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9161
# after looking at 3232 images, running_acc is 0.9127
# after looking at 4832 images, running_acc is 0.9137
# after looking at 6432 images, running_acc is 0.9151
# after looking at 8032 images, running_acc is 0.9156
# after looking at 9632 images, running_acc is 0.9162
# epoch 68 : acc 0.9163
# after looking at 32 images, running_loss is 0.0103
# after looking at 1632 images, running_loss is 0.0288
# after looking at 3232 images, running_loss is 0.0284
# after looking at 4832 images, running_loss is 0.0257
# after looking at 6432 images, running_loss is 0.0262
# after looking at 8032 images, running_loss is 0.0267
# after looking at 9632 images, running_loss is 0.0274
# after looking at 11232 images, running_loss is 0.0278
# after looking at 12832 images, running_loss is 0.0288
# after looking at 14432 images, running_loss is 0.0287
# after looking at 16032 images, running_loss is 0.0288
# after looking at 17632 images, running_loss is 0.0278
# after looking at 19232 images, running_loss is 0.0277
# after looking at 20832 images, running_loss is 0.0273
# after looking at 22432 images, running_loss is 0.0276
# after looking at 24032 images, running_loss is 0.0278
# after looking at 25632 images, running_loss is 0.0281
# after looking at 27232 images, running_loss is 0.0279
# after looking at 28832 images, running_loss is 0.0282
# after looking at 30432 images, running_loss is 0.0275
# after looking at 32032 images, running_loss is 0.0278
# after looking at 33632 images, running_loss is 0.0279
# after looking at 35232 images, running_loss is 0.0281
# after looking at 36832 images, running_loss is 0.0279
# after looking at 38432 images, running_loss is 0.0280
# after looking at 40032 images, running_loss is 0.0285
# after looking at 41632 images, running_loss is 0.0287
# after looking at 43232 images, running_loss is 0.0286
# after looking at 44832 images, running_loss is 0.0284
# after looking at 46432 images, running_loss is 0.0283
# after looking at 48032 images, running_loss is 0.0282
# after looking at 49632 images, running_loss is 0.0282
# epoch 69 : loss 0.0281
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9130
# after looking at 3232 images, running_acc is 0.9112
# after looking at 4832 images, running_acc is 0.9135
# after looking at 6432 images, running_acc is 0.9151
# after looking at 8032 images, running_acc is 0.9153
# after looking at 9632 images, running_acc is 0.9161
# epoch 69 : acc 0.9164
# after looking at 32 images, running_loss is 0.1058
# after looking at 1632 images, running_loss is 0.0271
# after looking at 3232 images, running_loss is 0.0288
# after looking at 4832 images, running_loss is 0.0331
# after looking at 6432 images, running_loss is 0.0349
# after looking at 8032 images, running_loss is 0.0338
# after looking at 9632 images, running_loss is 0.0347
# after looking at 11232 images, running_loss is 0.0326
# after looking at 12832 images, running_loss is 0.0329
# after looking at 14432 images, running_loss is 0.0314
# after looking at 16032 images, running_loss is 0.0312
# after looking at 17632 images, running_loss is 0.0320
# after looking at 19232 images, running_loss is 0.0328
# after looking at 20832 images, running_loss is 0.0324
# after looking at 22432 images, running_loss is 0.0317
# after looking at 24032 images, running_loss is 0.0310
# after looking at 25632 images, running_loss is 0.0305
# after looking at 27232 images, running_loss is 0.0302
# after looking at 28832 images, running_loss is 0.0304
# after looking at 30432 images, running_loss is 0.0295
# after looking at 32032 images, running_loss is 0.0296
# after looking at 33632 images, running_loss is 0.0294
# after looking at 35232 images, running_loss is 0.0293
# after looking at 36832 images, running_loss is 0.0291
# after looking at 38432 images, running_loss is 0.0289
# after looking at 40032 images, running_loss is 0.0291
# after looking at 41632 images, running_loss is 0.0289
# after looking at 43232 images, running_loss is 0.0291
# after looking at 44832 images, running_loss is 0.0290
# after looking at 46432 images, running_loss is 0.0289
# after looking at 48032 images, running_loss is 0.0290
# after looking at 49632 images, running_loss is 0.0288
# epoch 70 : loss 0.0288
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9148
# after looking at 3232 images, running_acc is 0.9124
# after looking at 4832 images, running_acc is 0.9129
# after looking at 6432 images, running_acc is 0.9145
# after looking at 8032 images, running_acc is 0.9150
# after looking at 9632 images, running_acc is 0.9160
# epoch 70 : acc 0.9164
# after looking at 32 images, running_loss is 0.0025
# after looking at 1632 images, running_loss is 0.0195
# after looking at 3232 images, running_loss is 0.0223
# after looking at 4832 images, running_loss is 0.0238
# after looking at 6432 images, running_loss is 0.0265
# after looking at 8032 images, running_loss is 0.0268
# after looking at 9632 images, running_loss is 0.0271
# after looking at 11232 images, running_loss is 0.0276
# after looking at 12832 images, running_loss is 0.0274
# after looking at 14432 images, running_loss is 0.0276
# after looking at 16032 images, running_loss is 0.0280
# after looking at 17632 images, running_loss is 0.0283
# after looking at 19232 images, running_loss is 0.0301
# after looking at 20832 images, running_loss is 0.0306
# after looking at 22432 images, running_loss is 0.0296
# after looking at 24032 images, running_loss is 0.0294
# after looking at 25632 images, running_loss is 0.0296
# after looking at 27232 images, running_loss is 0.0298
# after looking at 28832 images, running_loss is 0.0300
# after looking at 30432 images, running_loss is 0.0296
# after looking at 32032 images, running_loss is 0.0296
# after looking at 33632 images, running_loss is 0.0296
# after looking at 35232 images, running_loss is 0.0291
# after looking at 36832 images, running_loss is 0.0291
# after looking at 38432 images, running_loss is 0.0291
# after looking at 40032 images, running_loss is 0.0288
# after looking at 41632 images, running_loss is 0.0289
# after looking at 43232 images, running_loss is 0.0289
# after looking at 44832 images, running_loss is 0.0290
# after looking at 46432 images, running_loss is 0.0288
# after looking at 48032 images, running_loss is 0.0287
# after looking at 49632 images, running_loss is 0.0288
# epoch 71 : loss 0.0287
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9136
# after looking at 3232 images, running_acc is 0.9109
# after looking at 4832 images, running_acc is 0.9116
# after looking at 6432 images, running_acc is 0.9132
# after looking at 8032 images, running_acc is 0.9143
# after looking at 9632 images, running_acc is 0.9156
# Epoch    72: reducing learning rate of group 0 to 1.0000e-05.
# epoch 71 : acc 0.9161
# after looking at 32 images, running_loss is 0.0049
# after looking at 1632 images, running_loss is 0.0341
# after looking at 3232 images, running_loss is 0.0267
# after looking at 4832 images, running_loss is 0.0255
# after looking at 6432 images, running_loss is 0.0253
# after looking at 8032 images, running_loss is 0.0260
# after looking at 9632 images, running_loss is 0.0259
# after looking at 11232 images, running_loss is 0.0271
# after looking at 12832 images, running_loss is 0.0279
# after looking at 14432 images, running_loss is 0.0275
# after looking at 16032 images, running_loss is 0.0283
# after looking at 17632 images, running_loss is 0.0277
# after looking at 19232 images, running_loss is 0.0284
# after looking at 20832 images, running_loss is 0.0288
# after looking at 22432 images, running_loss is 0.0292
# after looking at 24032 images, running_loss is 0.0290
# after looking at 25632 images, running_loss is 0.0292
# after looking at 27232 images, running_loss is 0.0291
# after looking at 28832 images, running_loss is 0.0285
# after looking at 30432 images, running_loss is 0.0287
# after looking at 32032 images, running_loss is 0.0290
# after looking at 33632 images, running_loss is 0.0291
# after looking at 35232 images, running_loss is 0.0290
# after looking at 36832 images, running_loss is 0.0289
# after looking at 38432 images, running_loss is 0.0288
# after looking at 40032 images, running_loss is 0.0288
# after looking at 41632 images, running_loss is 0.0289
# after looking at 43232 images, running_loss is 0.0289
# after looking at 44832 images, running_loss is 0.0287
# after looking at 46432 images, running_loss is 0.0285
# after looking at 48032 images, running_loss is 0.0286
# after looking at 49632 images, running_loss is 0.0282
# epoch 72 : loss 0.0281
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9142
# after looking at 3232 images, running_acc is 0.9118
# after looking at 4832 images, running_acc is 0.9125
# after looking at 6432 images, running_acc is 0.9140
# after looking at 8032 images, running_acc is 0.9150
# after looking at 9632 images, running_acc is 0.9159
# epoch 72 : acc 0.9164
# after looking at 32 images, running_loss is 0.0023
# after looking at 1632 images, running_loss is 0.0172
# after looking at 3232 images, running_loss is 0.0179
# after looking at 4832 images, running_loss is 0.0202
# after looking at 6432 images, running_loss is 0.0206
# after looking at 8032 images, running_loss is 0.0219
# after looking at 9632 images, running_loss is 0.0226
# after looking at 11232 images, running_loss is 0.0220
# after looking at 12832 images, running_loss is 0.0226
# after looking at 14432 images, running_loss is 0.0219
# after looking at 16032 images, running_loss is 0.0224
# after looking at 17632 images, running_loss is 0.0223
# after looking at 19232 images, running_loss is 0.0223
# after looking at 20832 images, running_loss is 0.0223
# after looking at 22432 images, running_loss is 0.0226
# after looking at 24032 images, running_loss is 0.0227
# after looking at 25632 images, running_loss is 0.0232
# after looking at 27232 images, running_loss is 0.0231
# after looking at 28832 images, running_loss is 0.0232
# after looking at 30432 images, running_loss is 0.0236
# after looking at 32032 images, running_loss is 0.0236
# after looking at 33632 images, running_loss is 0.0235
# after looking at 35232 images, running_loss is 0.0233
# after looking at 36832 images, running_loss is 0.0232
# after looking at 38432 images, running_loss is 0.0235
# after looking at 40032 images, running_loss is 0.0238
# after looking at 41632 images, running_loss is 0.0240
# after looking at 43232 images, running_loss is 0.0242
# after looking at 44832 images, running_loss is 0.0244
# after looking at 46432 images, running_loss is 0.0244
# after looking at 48032 images, running_loss is 0.0246
# after looking at 49632 images, running_loss is 0.0247
# epoch 73 : loss 0.0246
# after looking at 32 images, running_acc is 1.0000
# after looking at 1632 images, running_acc is 0.9130
# after looking at 3232 images, running_acc is 0.9115
# after looking at 4832 images, running_acc is 0.9129
# after looking at 6432 images, running_acc is 0.9139
# after looking at 8032 images, running_acc is 0.9146
# after looking at 9632 images, running_acc is 0.9159
# epoch 73 : acc 0.9163

# %%
vgga.conv1a[0].weight
# Out:
# Parameter containing:
# tensor([[[[-0.1039, -0.1102, -0.0840],
#           [-0.1604, -0.0915, -0.0803],
#           [-0.0209, -0.1084, -0.1262]],
#
#          [[-0.0790, -0.1193, -0.0935],
#           [-0.1338, -0.0580, -0.1076],
#           [-0.1196, -0.1626, -0.2085]],
#
#          [[ 0.1898,  0.1961,  0.0513],
#           [ 0.2762,  0.3360,  0.1776],
#           [ 0.2267,  0.2033, -0.0027]]],
#
#
#         [[[ 0.2340,  0.3044,  0.0883],
#           [-0.4805, -0.3992, -0.2240],
#           [ 0.2776,  0.2693,  0.1132]],
#
#          [[ 0.2495,  0.3380,  0.1244],
#           [-0.5178, -0.4596, -0.3034],
#           [ 0.2331,  0.3271,  0.1517]],
#
#          [[ 0.2508,  0.3377,  0.0289],
#           [-0.4754, -0.4418, -0.3419],
#           [ 0.1847,  0.2318,  0.1293]]],
#
#
#         [[[-0.8474, -0.6592, -0.0918],
#           [-0.5865, -0.0143,  0.6711],
#           [ 0.0698,  0.6664,  1.0181]],
#
#          [[ 0.2758,  0.1460,  0.0014],
#           [ 0.0694, -0.0748, -0.2133],
#           [-0.0822, -0.1868, -0.2524]],
#
#          [[ 0.6557,  0.5279,  0.0432],
#           [ 0.5599,  0.0951, -0.3939],
#           [ 0.0518, -0.4531, -0.8022]]],
#
#
#         ...,
#
#
#         [[[-0.3301,  0.2619,  0.2264],
#           [ 0.3747,  0.4733, -0.3303],
#           [ 0.1671, -0.4596, -0.1524]],
#
#          [[-0.2224,  0.2256,  0.1882],
#           [ 0.2912,  0.3894, -0.3391],
#           [ 0.0527, -0.4942, -0.0735]],
#
#          [[-0.5257, -0.0018,  0.1096],
#           [ 0.0941,  0.4446, -0.1527],
#           [ 0.1065, -0.1718,  0.1093]]],
#
#
#         [[[-0.1204, -0.1924, -0.0856],
#           [ 0.0154, -0.0450, -0.0090],
#           [-0.0899, -0.1647, -0.0060]],
#
#          [[-0.0553, -0.0559,  0.0180],
#           [ 0.0382,  0.0837,  0.0752],
#           [-0.2515, -0.2221, -0.0337]],
#
#          [[ 0.0621,  0.0849,  0.0847],
#           [ 0.2534,  0.3008,  0.2906],
#           [-0.1993, -0.0924, -0.0095]]],
#
#
#         [[[ 0.0362, -0.2926, -0.5061],
#           [ 0.2258,  0.0955, -0.3357],
#           [ 0.3087,  0.3034,  0.0178]],
#
#          [[ 0.0679,  0.0831, -0.0732],
#           [ 0.0033,  0.1827, -0.0063],
#           [-0.1984,  0.0457,  0.0088]],
#
#          [[ 0.0909,  0.2597,  0.2533],
#           [-0.2564,  0.1667,  0.2429],
#           [-0.4985, -0.2063,  0.0511]]]], device='cuda:0', requires_grad=True)
